# %% [markdown]
# # Text Analysis - Word Documents & Web Pages
#
# Skip to:
#
# * [Web Pages](#web)
# * [Word Documents](#word)
#
# ## __Copy Me!__
#
# First things first - more than one person working with a particular notebook will cause problems. For the purposes of this workshop, please make a copy and rename to prevent confusion.
#
# 1. From the _File_ menu, select _Make a copy_
# 2. This will open up a new notebook - please rename it before proceeding
# 3. From the _File_ menu, select _Rename..._.
# 4. Make the new name as unambiguous as possible.
#
# ## Credit
#
# Thanks to Wendy Pedersen for the sample data!
#
# Some of the code which follows has been adapted from:
#
# _Collocations_, accessed June 8, 2017. http://www.nltk.org/howto/collocations.html
#
# ## Install Dependencies
#
# If you are using Anaconda, which is recommended, many useful extensions are pre-installed. One of these extensions is _Pip_, which is a commonly used installer for Python libraries and modules.
#
# If necessary, you can also install Pip manually: [https://packaging.python.org/tutorials/installing-packages/](https://packaging.python.org/tutorials/installing-packages/)
#
# All of the libraries we will be using today have already been installed on the server. In your local or desktop environment, you may need to install any that are not provided by Anaconda. As needed, uncomment the pip commands in the next cell and run it before proceeding.

# %%
# !pip install beautifulsoup4
# !pip install nltk
# !pip install wordcloud
# !pip install python-docx
# !pip install requests

# %% [markdown]
# ## About the Dependencies
#
# ### BeautifulSoup
#
# BeautifulSoup is a library for parsing HTML. While it does not retrieve web pages, in combination with an HTTP utility such as _requests_, it is useful for screens-scraping and analysing web content. Specifically, BeautifulSoup provides methods for navigating and extracting text, attributes, and other features from structured (but often messy) HTML.
#
# Documentation: [https://www.crummy.com/software/BeautifulSoup/bs4/doc/](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# ### NLTK
#
# _NTLK_ stands for _Natural Language Toolkit_. This is a robust suite of utilities and methods for analysing unstructured text, with capabilities for machine learning, classification, and sentiment analysis.
#
# Documentation: [http://www.nltk.org/](http://www.nltk.org/)
#
# ### Wordcloud
#
# An easy to use wordcloud generator. Includes support for bigrams.
#
# Documentation: [https://github.com/amueller/word_cloud](https://github.com/amueller/word_cloud)
#
# ### Python-Docx
#
# A library for reading and writing MS Word files. Just as BeautifulSoup understands the structure of HTML, Docx provides methods for parsing and manipulating the different elements of a Word file (headers, font styles, paragraphs, etc.)
#
# Documentation: [https://python-docx.readthedocs.io/en/latest/](https://python-docx.readthedocs.io/en/latest/)
#
# ### Requests
#
# As noted on the website, _HTTP for Humans_. This is a well documented resource for interacting with static web pages, APIs, etc.
#
# Documentation: [http://docs.python-requests.org/en/master/](http://docs.python-requests.org/en/master/)
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Doing Stuff
#
# Now that our environment has been set up, we can begin analyzing text. Please note that the for the most part the code provided here is oriented toward analyzing single documents or, at most, a handful of web pages.
#
# In the next cell, we import the first of several libraries. Note that NLTK utilizes multiple extensions and resources such as example corpora and stopword lists. Some of these are not installed with the module and must be installed separately - as above, this has already been done on the server. If using this notebook on a workstation, uncomment the second line before running the next cell.

# %%
import nltk
#nltk.download('all')

# %% [markdown]
# In the next cell, we import the remaining libraries and modules. Note that import statements are generally provided in the available documentation.

# %%
import requests
from bs4 import BeautifulSoup
import string
from nltk.collocations import *
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.util import ngrams
from operator import itemgetter
from scipy.misc import imread
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from collections import Counter
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys
from scipy.misc import imread
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# # <a name="web"></a> Web Pages
#
# **NOTE: If you skipped here from the top of the page, you may still need to load libraries and etc. From the _Cell_ menu, select _Run All Above_**.
#
# From here on, more useful information may be presented in comments in the code blocks. But as an overview, the next several cells provide a process for harvesting HTML from web pages - screen scraping - separating the text from the HTML element tags, and doing a basic text analysis of the content. The analysis consists of:
#
# 1. Word count
# 2. Bigram (two word phrase or collocation) and trigram (three word phrase or collocation) analysis
# 3. Word cloud
#
# The process makes use of the following libraries: Requests, BeautifulSoup, NLTK, Wordcloud.

# %%
# The 'libguides' variable is a comma separated list of the web pages we want to scrape. Even if we only want to harvest
# a single web page, using a list is a good idea because it simplifies the process of adding or updating pages later.

libguides = ['http://libguides.unm.edu/Special_LatinAmerican_Collections/Colonial_Spanish_American_Manuscripts',
            'http://libguides.unm.edu/Special_LatinAmerican_Collections/Modern_Mexico_Guatemala_Manuscripts',
            'http://libguides.unm.edu/Special_LatinAmerican_Collections/Visual_Manuscripts']

# The 'collDescriptions' variable is also a list. List items will consist of text from the web page, specifically in the
# example case, list items will be link description fields as utilized in Springer's Libguides platform.

# For our purposes we could have used other data structures, but I like a list because it allows us to keep the individual
# descriptions separate from each other yet makes it easy to combine them as needed. Note also that the list is empty - it's
# often useful to initialize an empty list and add items to it later.

collDescriptions = []

# The next block of code is a 'for' loop. In plain language, it says:
# for each libguide/web page in the list of libguide pages...
#      request the page and store the response in a new 'libguide' variable
#      parse the response into HTML and store in a new 'soup' variable
#      extract out just the link descriptions and store in a new 'descriptions' variable (which is a list!)
#      for each collection description in the list of descriptions:
#           append the collection description to the global list of collection descriptions

# Why do we have two lists of collection descriptions? Context - "collDescriptions" is a list of all of the 
# collection descriptions across all of the web pages we're harvesting. "descriptions" is a list of collection
# descriptions from a single page. Because of the 'for' loop, every time we harvest a new page, the 'descriptions'
# list is overwritten.

for guide in libguides:
    libguide = requests.get(guide)
    soup = BeautifulSoup(libguide.text, 'html.parser')
    # To harvest a different kind of page than a libguide, or to get some other
    # info out of a libguide, the next line needs to be edited.
    # A generic option is provided in the next line - uncomment and comment the libguide specific line as needed.
    #descriptions = soup.find('p').getText() # If this line is used, remove '.string' from the last line below.
    descriptions = soup.find_all(attrs={"class": "s-lg-link-desc"})
    for collection in descriptions:
        collDescriptions.append(collection.string)
#collDescriptions

# %% [markdown]
# ## Single Word Count
#
# All of our text is currently in a list. To do basic word and ngram analysis, we need to convert the list into a text corpus. There are various ways to do this, but for simplicity's sake we are going to combine all of the descriptions into one long string. "String" is a data type - think of it as generic text.

# %%
# Declare a new "collCorpus" variable. At first it is an empty string. 
# The 'for' loop iterates through the global list of collection descriptions and appends the text
# to the "collCorpus" string. If we were to print or view "collCorpus" afterwardss, it would look
# like a long, unformatted paragraph.

collCorpus = ''
for description in collDescriptions:
    collCorpus = collCorpus + str(description)

# The next two lines tokenize the corpus - that is, the long unformatted string is converted into
# a list of individual words. The process also removes additional whitespace. The tokenized text data
# are stored in a new variable, 'cDataNoWS' ('corpus data, no whitespace').

tokenizer = RegexpTokenizer(r'\w+')
cDataNoWS = tokenizer.tokenize(collCorpus)

# The next two lines use methods from the Counter module to normalize words (tokens) in the corpus
# and bypass stopwords. The second line generates the word count.

word_count_dict = Counter(w.title() for w in cDataNoWS if w.lower() not in stopwords.words())
word_count_dict.most_common()
# Out:
# [('Collection', 65),
#  ('Mexico', 64),
#  ('Contains', 30),
#  ('Documents', 25),
#  ('Materials', 24),
#  ('Mexican', 23),
#  ('Spanish', 22),
#  ('America', 19),
#  ('New', 17),
#  ('Latin', 17),
#  ('Consists', 15),
#  ('Include', 15),
#  ('Political', 14),
#  ('Photographs', 14),
#  ('Research', 14),
#  ('Material', 12),
#  ('Posters', 12),
#  ('Century', 12),
#  ('Colonial', 11),
#  ('Included', 11),
#  ('Art', 11),
#  ('Correspondence', 11),
#  ('Archivo', 11),
#  ('Spain', 11),
#  ('Prints', 10),
#  ('Government', 10),
#  ('Book', 9),
#  ('Series', 9),
#  ('Many', 9),
#  ('Notes', 9),
#  ('Years', 8),
#  ('Photos', 8),
#  ('Land', 8),
#  ('One', 8),
#  ('Social', 8),
#  ('Life', 8),
#  ('Including', 8),
#  ('Posada', 7),
#  ('Nicaragua', 7),
#  ('General', 7),
#  ('José', 7),
#  ('City', 7),
#  ('History', 7),
#  ('American', 7),
#  ('Related', 7),
#  ('Guatemala', 6),
#  ('Variety', 6),
#  ('Central', 6),
#  ('Records', 6),
#  ('Information', 6),
#  ('Religious', 6),
#  ('Randall', 6),
#  ('Others', 6),
#  ('Events', 6),
#  ('Cuba', 6),
#  ('Transcriptions', 6),
#  ('Music', 6),
#  ('Masses', 6),
#  ('Papers', 6),
#  ('School', 6),
#  ('Manuscripts', 6),
#  ('Archives', 6),
#  ('Number', 6),
#  ('Mapa', 6),
#  ('Legal', 6),
#  ('Includes', 6),
#  ('Various', 6),
#  ('Contain', 5),
#  ('Antonio', 5),
#  ('Flyers', 5),
#  ('Works', 5),
#  ('Represented', 5),
#  ('Illustrations', 5),
#  ('United', 5),
#  ('Postcards', 5),
#  ('Subjects', 5),
#  ('States', 5),
#  ('Well', 5),
#  ('Indians', 5),
#  ('Focus', 5),
#  ('Made', 5),
#  ('Pueblo', 5),
#  ('Broadsides', 5),
#  ('Majority', 5),
#  ('Publications', 5),
#  ('Wide', 5),
#  ('Early', 5),
#  ('Tice', 4),
#  ('White', 4),
#  ('Personal', 4),
#  ('Primarily', 4),
#  ('Mining', 4),
#  ('Mid', 4),
#  ('Digitized', 4),
#  ('Late', 4),
#  ('Original', 4),
#  ('Military', 4),
#  ('Cards', 4),
#  ('Themes', 4),
#  ('Real', 4),
#  ('Range', 4),
#  ('Pamphlets', 4),
#  ('Studies', 4),
#  ('Kelemen', 4),
#  ('Printed', 4),
#  ('Work', 4),
#  ('Revolution', 4),
#  ('Margaret', 4),
#  ('Artist', 4),
#  ('Artists', 4),
#  ('Economic', 4),
#  ('Mainly', 4),
#  ('Oaxaca', 4),
#  ('Architecture', 4),
#  ('Santa', 4),
#  ('Medina', 4),
#  ('Zarzuelas', 4),
#  ('Caribbean', 4),
#  ('Used', 4),
#  ('Period', 4),
#  ('Translations', 4),
#  ('Rights', 4),
#  ('Puerto', 4),
#  ('Black', 4),
#  ('Codex', 4),
#  ('According', 4),
#  ('Scores', 4),
#  ('National', 4),
#  ('Guadalupe', 4),
#  ('South', 4),
#  ('Indian', 4),
#  ('Topics', 4),
#  ('Collected', 4),
#  ('Part', 4),
#  ('Maps', 4),
#  ('Campos', 4),
#  ('Written', 4),
#  ('Macy', 3),
#  ('Terán', 3),
#  ('Gathered', 3),
#  ('Rosen', 3),
#  ('Beltran', 3),
#  ('Villa', 3),
#  ('Padre', 3),
#  ('Party', 3),
#  ('Produced', 3),
#  ('Issues', 3),
#  ('Handwritten', 3),
#  ('Canción', 3),
#  ('Numerous', 3),
#  ('Solidarity', 3),
#  ('Relating', 3),
#  ('Pueblos', 3),
#  ('Properties', 3),
#  ('San', 3),
#  ('Examples', 3),
#  ('Civil', 3),
#  ('Cover', 3),
#  ('Registry', 3),
#  ('Two', 3),
#  ('Landscapes', 3),
#  ('Etc', 3),
#  ('Nineteenth', 3),
#  ('State', 3),
#  ('Seventeenth', 3),
#  ('Convent', 3),
#  ('Americans', 3),
#  ('Mier', 3),
#  ('Compiled', 3),
#  ('Available', 3),
#  ('Twentieth', 3),
#  ('Articles', 3),
#  ('Portraits', 3),
#  ('González', 3),
#  ('Journal', 3),
#  ('Judicial', 3),
#  ('Europe', 3),
#  ('Human', 3),
#  ('Commercial', 3),
#  ('European', 3),
#  ('Sites', 3),
#  ('Photocopies', 3),
#  ('Around', 3),
#  ('Eighteenth', 3),
#  ('Published', 3),
#  ('Provides', 3),
#  ('Village', 3),
#  ('Introduction', 3),
#  ('Created', 3),
#  ('Names', 3),
#  ('Paper', 3),
#  ('Images', 3),
#  ('Reports', 3),
#  ('Photographers', 3),
#  ('Family', 3),
#  ('Dealing', 3),
#  ('Casino', 3),
#  ('Purchase', 3),
#  ('Bound', 3),
#  ('Bulk', 3),
#  ('Mendoza', 3),
#  ('Administrative', 3),
#  ('Experiences', 3),
#  ('Madrid', 3),
#  ('Rican', 3),
#  ('Photomechanical', 3),
#  ('Zacatecas', 3),
#  ('Politics', 3),
#  ('Revolt', 3),
#  ('Fe', 3),
#  ('John', 3),
#  ('English', 3),
#  ('Oil', 3),
#  ('Groups', 3),
#  ('Small', 3),
#  ('Native', 3),
#  ('Agriculture', 3),
#  ('Divided', 3),
#  ('Address', 3),
#  ('Selected', 3),
#  ('Discovered', 3),
#  ('Teatro', 3),
#  ('Luís', 3),
#  ('Half', 3),
#  ('Newspaper', 3),
#  ('Writings', 3),
#  ('Communist', 3),
#  ('Zulauf', 2),
#  ('Third', 2),
#  ('Coahuila', 2),
#  ('Negatives', 2),
#  ('Paul', 2),
#  ('Valuable', 2),
#  ('Industry', 2),
#  ('Claims', 2),
#  ('Area', 2),
#  ('Quality', 2),
#  ('Worked', 2),
#  ('Specific', 2),
#  ('Author', 2),
#  ('Sheet', 2),
#  ('Film', 2),
#  ('Letters', 2),
#  ('1960S', 2),
#  ('Named', 2),
#  ('Crime', 2),
#  ('Local', 2),
#  ('Travels', 2),
#  ('Source', 2),
#  ('Unm', 2),
#  ('Paintings', 2),
#  ('Consisting', 2),
#  ('Acquired', 2),
#  ('Called', 2),
#  ('Containing', 2),
#  ('Hispanics', 2),
#  ('Engraving', 2),
#  ('Story', 2),
#  ('Mm', 2),
#  ('Law', 2),
#  ('Miscellaneous', 2),
#  ('Addressed', 2),
#  ('Archival', 2),
#  ('Baroque', 2),
#  ('French', 2),
#  ('Business', 2),
#  ('Vicente', 2),
#  ('Decades', 2),
#  ('Second', 2),
#  ('Reconquest', 2),
#  ('Calera', 2),
#  ('Academic', 2),
#  ('Took', 2),
#  ('Classes', 2),
#  ('Covers', 2),
#  ('1940', 2),
#  ('Cm', 2),
#  ('Career', 2),
#  ('Labor', 2),
#  ('Teaching', 2),
#  ('Vargas', 2),
#  ('Smaller', 2),
#  ('Along', 2),
#  ('Loose', 2),
#  ('Juárez', 2),
#  ('Although', 2),
#  ('Primary', 2),
#  ('Photography', 2),
#  ('Jane', 2),
#  ('Copied', 2),
#  ('Feminism', 2),
#  ('Proposed', 2),
#  ('Diplomatic', 2),
#  ('Arroyo', 2),
#  ('Relate', 2),
#  ('Revolutionary', 2),
#  ('International', 2),
#  ('Domestic', 2),
#  ('Gen', 2),
#  ('Tenure', 2),
#  ('Belgian', 2),
#  ('Notarías', 2),
#  ('Calaveras', 2),
#  ('Histórico', 2),
#  ('Violence', 2),
#  ('Addition', 2),
#  ('40', 2),
#  ('Elisabeth', 2),
#  ('19Th', 2),
#  ('Recordings', 2),
#  ('Elections', 2),
#  ('Tepoztecatzin', 2),
#  ('Women', 2),
#  ('44', 2),
#  ('Salvador', 2),
#  ('Badly', 2),
#  ('Dr', 2),
#  ('Velde', 2),
#  ('2', 2),
#  ('Cause', 2),
#  ('Three', 2),
#  ('Noted', 2),
#  ('Northern', 2),
#  ('30', 2),
#  ('Consequently', 2),
#  ('Photographer', 2),
#  ('Tianity', 2),
#  ('Indias', 2),
#  ('Term', 2),
#  ('Officials', 2),
#  ('Depict', 2),
#  ('Panama', 2),
#  ('Petroleum', 2),
#  ('Bunzl', 2),
#  ('Pershing', 2),
#  ('Still', 2),
#  ('Paint', 2),
#  ('Vanegas', 2),
#  ('Several', 2),
#  ('Culture', 2),
#  ('Clients', 2),
#  ('Friends', 2),
#  ('Cityscapes', 2),
#  ('Albino', 2),
#  ('1', 2),
#  ('Borderlands', 2),
#  ('Protests', 2),
#  ('Martinez', 2),
#  ('Conquest', 2),
#  ('Water', 2),
#  ('Medicine', 2),
#  ('Independence', 2),
#  ('April', 2),
#  ('Library', 2),
#  ('World', 2),
#  ('Format', 2),
#  ('Santos', 2),
#  ('Text', 2),
#  ('Faded', 2),
#  ('Reproductions', 2),
#  ('Folk', 2),
#  ('Building', 2),
#  ('Cuauhtlantzinco', 2),
#  ('Dates', 2),
#  ('Historian', 2),
#  ('Rare', 2),
#  ('Poetry', 2),
#  ('Nación', 2),
#  ('Regarding', 2),
#  ('Month', 2),
#  ('Nationalization', 2),
#  ('Photo', 2),
#  ('Rococco', 2),
#  ('1821', 2),
#  ('Items', 2),
#  ('Figure', 2),
#  ('Dence', 2),
#  ('Spent', 2),
#  ('Service', 2),
#  ('Tradition', 2),
#  ('Type', 2),
#  ('Relations', 2),
#  ('Date', 2),
#  ('Relevant', 2),
#  ('Focused', 2),
#  ('Sung', 2),
#  ('Prominently', 2),
#  ('35', 2),
#  ('Reflect', 2),
#  ('Town', 2),
#  ('Four', 2),
#  ('1693', 2),
#  ('Pre', 2),
#  ('1910', 2),
#  ('Historical', 2),
#  ('Musicians', 2),
#  ('Musical', 2),
#  ('Southwest', 2),
#  ('Parts', 2),
#  ('Tells', 2),
#  ('People', 2),
#  ('Pál', 2),
#  ('Ing', 2),
#  ('Greenleaf', 2),
#  ('Register', 2),
#  ('1794', 2),
#  ('Complete', 2),
#  ('1980S', 2),
#  ('Exhibition', 2),
#  ('Honduras', 2),
#  ('Project', 2),
#  ('Conductors', 2),
#  ('Organizations', 2),
#  ('Clippings', 2),
#  ('Lesbianism', 2),
#  ('Chris', 2),
#  ('Popular', 2),
#  ('1836', 2),
#  ('Publication', 2),
#  ('Additional', 2),
#  ('Children', 2),
#  ('X', 2),
#  ('Silver', 2),
#  ('Dance', 2),
#  ('Taken', 2),
#  ('Major', 2),
#  ('Signed', 2),
#  ('Cacique', 2),
#  ('Digital', 2),
#  ('Cuban', 2),
#  ('Correspon', 2),
#  ('Sculpture', 2),
#  ('Essay', 1),
#  ('Rico', 1),
#  ('June', 1),
#  ('Tourism', 1),
#  ('Formulated', 1),
#  ('Tics', 1),
#  ('Encountered', 1),
#  ('21', 1),
#  ('Fox', 1),
#  ('Extensive', 1),
#  ('Slides', 1),
#  ('Weston', 1),
#  ('1647', 1),
#  ('Bibliographical', 1),
#  ('Republic', 1),
#  ('Five', 1),
#  ('Document', 1),
#  ('Ecuador', 1),
#  ('Comets', 1),
#  ('Areas', 1),
#  ('Descriptions', 1),
#  ('Property', 1),
#  ('Anthropological', 1),
#  ('Criminal', 1),
#  ('System', 1),
#  ('Comprise', 1),
#  ('Popularized', 1),
#  ('Conditions', 1),
#  ('Brutality', 1),
#  ('Socio', 1),
#  ('Squads', 1),
#  ('Visual', 1),
#  ('Rooms', 1),
#  ('Mestizos', 1),
#  ('Blue', 1),
#  ('Blueprint', 1),
#  ('Hard', 1),
#  ('Uses', 1),
#  ('Convento', 1),
#  ('Ephemera', 1),
#  ('Mosquera', 1),
#  ('Criteria', 1),
#  ('Focuses', 1),
#  ('Autonomous', 1),
#  ('Mariana', 1),
#  ('Nine', 1),
#  ('Owners', 1),
#  ('Robb', 1),
#  ('Prevention', 1),
#  ('Find', 1),
#  ('Ranging', 1),
#  ('Daily', 1),
#  ('Issuesincludes', 1),
#  ('Ornamentation', 1),
#  ('Activist', 1),
#  ('1798', 1),
#  ('Logo', 1),
#  ('Post', 1),
#  ('Affiliated', 1),
#  ('Difficult', 1),
#  ('Felipe', 1),
#  ('Declarations', 1),
#  ('George', 1),
#  ('Fishermen', 1),
#  ('Famous', 1),
#  ('Troubles', 1),
#  ('Attached', 1),
#  ('Workable', 1),
#  ('Huntington', 1),
#  ('Intrigue', 1),
#  ('Danza', 1),
#  ('Guanajuato', 1),
#  ('Establishment', 1),
#  ('Productionsas', 1),
#  ('Movie', 1),
#  ('Straight', 1),
#  ('Dozen', 1),
#  ('Chronologize', 1),
#  ('Barnuevo', 1),
#  ('Librettists', 1),
#  ('23', 1),
#  ('Involved', 1),
#  ('591', 1),
#  ('Servants', 1),
#  ('Protocolos', 1),
#  ('Craven', 1),
#  ('Enumeration', 1),
#  ('Make', 1),
#  ('Satirical', 1),
#  ('Hospicio', 1),
#  ('Picture', 1),
#  ('Worker', 1),
#  ('Plus', 1),
#  ('Next', 1),
#  ('Corresponding', 1),
#  ('Affidavit', 1),
#  ('Camino', 1),
#  ('Monasterio', 1),
#  ('Columbian', 1),
#  ('Growing', 1),
#  ('Theatre', 1),
#  ('Immigration', 1),
#  ('Books', 1),
#  ('Masonry', 1),
#  ('Styles', 1),
#  ('Parangaricutiro', 1),
#  ('Verse', 1),
#  ('1697', 1),
#  ('Insight', 1),
#  ('Woodcut', 1),
#  ('Alaska', 1),
#  ('Mostly', 1),
#  ('Literary', 1),
#  ('Modeled', 1),
#  ('Pictures', 1),
#  ('Ortega', 1),
#  ('Bolero', 1),
#  ('Unam', 1),
#  ('Transcription', 1),
#  ('Ciudad', 1),
#  ('Firing', 1),
#  ('Orchestras', 1),
#  ('Mothers', 1),
#  ('Activities', 1),
#  ('15', 1),
#  ('Ortiz', 1),
#  ('Famed', 1),
#  ('Archive', 1),
#  ('Journey', 1),
#  ('Schottisch', 1),
#  ('Francisco', 1),
#  ('Xochimilco', 1),
#  ('Motion', 1),
#  ('Stone', 1),
#  ('Comanche', 1),
#  ('Section', 1),
#  ('Oral', 1),
#  ('Stencils', 1),
#  ('Together', 1),
#  ('Impossible', 1),
#  ('10', 1),
#  ('Intellectuals', 1),
#  ('Vals', 1),
#  ('Mariano', 1),
#  ('Philippines', 1),
#  ('Natural', 1),
#  ('Newspapers', 1),
#  ('Translation', 1),
#  ('Piña', 1),
#  ('Existing', 1),
#  ('Box', 1),
#  ('Plates', 1),
#  ('Vietnam', 1),
#  ('Disasters', 1),
#  ('Geological', 1),
#  ('View', 1),
#  ('Mesoamerican', 1),
#  ('Murals', 1),
#  ('Diego', 1),
#  ('Corrido', 1),
#  ('Signs', 1),
#  ('Eniac', 1),
#  ('Engagement', 1),
#  ('Particularly', 1),
#  ('Acts', 1),
#  ('Marcha', 1),
#  ('Storylines', 1),
#  ('Influenced', 1),
#  ('Deal', 1),
#  ('Ateneo', 1),
#  ('Playwright', 1),
#  ('1974', 1),
#  ('Organized', 1),
#  ('Completed', 1),
#  ('Borders', 1),
#  ('Caricatures', 1),
#  ('Costa', 1),
#  ('Composers', 1),
#  ('Botas', 1),
#  ('1900S', 1),
#  ('Variations', 1),
#  ('Documentation', 1),
#  ('Common', 1),
#  ('Marqués', 1),
#  ('Grants', 1),
#  ('Unbound', 1),
#  ('Subsequently', 1),
#  ('Governmental', 1),
#  ('France', 1),
#  ('Forgotten', 1),
#  ('Dating', 1),
#  ('Frederick', 1),
#  ('Contact', 1),
#  ('Cardenas', 1),
#  ('1916', 1),
#  ('Associates', 1),
#  ('Revealing', 1),
#  ('Revolu', 1),
#  ('Figures', 1),
#  ('Deals', 1),
#  ('Gua', 1),
#  ('Italian', 1),
#  ('Countries', 1),
#  ('File', 1),
#  ('Struggles', 1),
#  ('Equipment', 1),
#  ('Vocational', 1),
#  ('Dorado', 1),
#  ('1825', 1),
#  ('Historians', 1),
#  ('Sacraments', 1),
#  ('170', 1),
#  ('Defender', 1),
#  ('Rule', 1),
#  ('Acuteness', 1),
#  ('Marx', 1),
#  ('1857', 1),
#  ('1895', 1),
#  ('Lenora', 1),
#  ('Bookplate', 1),
#  ('Likely', 1),
#  ('Receipts', 1),
#  ('Inheritance', 1),
#  ('Cavalry', 1),
#  ('Types', 1),
#  ('1759', 1),
#  ('Zinc', 1),
#  ('Informal', 1),
#  ('Gamboa', 1),
#  ('Print', 1),
#  ('Large', 1),
#  ('Eight', 1),
#  ('Ministerio', 1),
#  ('Agricultural', 1),
#  ('Illuminate', 1),
#  ('Historic', 1),
#  ('Safety', 1),
#  ('Parades', 1),
#  ('G', 1),
#  ('1893', 1),
#  ('Huapango', 1),
#  ('Disease', 1),
#  ('Wills', 1),
#  ('Digitally', 1),
#  ('Soil', 1),
#  ('Lava', 1),
#  ('Colorado', 1),
#  ('Church', 1),
#  ('Exiled', 1),
#  ('Expedition', 1),
#  ('Color', 1),
#  ('Initial', 1),
#  ('Commissioned', 1),
#  ('Ana', 1),
#  ('Clergy', 1),
#  ('Cabildo', 1),
#  ('Toluca', 1),
#  ('Orozco', 1),
#  ('Reflects', 1),
#  ('Point', 1),
#  ('Mos', 1),
#  ('Budgets', 1),
#  ('Waite', 1),
#  ('Indigenous', 1),
#  ('Loteria', 1),
#  ('Notably', 1),
#  ('Modern', 1),
#  ('County', 1),
#  ('Regional', 1),
#  ('Center', 1),
#  ('Could', 1),
#  ('Provincial', 1),
#  ('Norling', 1),
#  ('Politicians', 1),
#  ('Recited', 1),
#  ('1980', 1),
#  ('Eski', 1),
#  ('Greeting', 1),
#  ('Manuscript', 1),
#  ('Punishment', 1),
#  ('Disputes', 1),
#  ('Report', 1),
#  ('Postcard', 1),
#  ('Jose', 1),
#  ('Serials', 1),
#  ('Compositional', 1),
#  ('Kessell', 1),
#  ('Exhibitions', 1),
#  ('North', 1),
#  ('Notable', 1),
#  ('Medical', 1),
#  ('Performers', 1),
#  ('Locales', 1),
#  ('Secondary', 1),
#  ('Situations', 1),
#  ('Name', 1),
#  ('Traditional', 1),
#  ('Vogue', 1),
#  ('Length', 1),
#  ('Folklore', 1),
#  ('Campaigns', 1),
#  ('Justicia', 1),
#  ('Titles', 1),
#  ('Calendars', 1),
#  ('Kingdoms', 1),
#  ('Child', 1),
#  ('Peru', 1),
#  ('Hugo', 1),
#  ('Interior', 1),
#  ('Photographsthe', 1),
#  ('Socialism', 1),
#  ('Architectural', 1),
#  ('Unrest', 1),
#  ('Broad', 1),
#  ('Fliers', 1),
#  ('Distrito', 1),
#  ('Patzcuaro', 1),
#  ('Bibliographies', 1),
#  ('Barcinas', 1),
#  ('Subsequent', 1),
#  ('Characteristics', 1),
#  ('Catacombs', 1),
#  ('Either', 1),
#  ('6', 1),
#  ('Viennese', 1),
#  ('Resources', 1),
#  ('Broadside', 1),
#  ('Pyramid', 1),
#  ('20Th', 1),
#  ('Located', 1),
#  ('Agricultura', 1),
#  ('Charges', 1),
#  ('Father', 1),
#  ('Ings', 1),
#  ('131', 1),
#  ('Briquet', 1),
#  ('Lists', 1),
#  ('Advertising', 1),
#  ('Halls', 1),
#  ('Davis', 1),
#  ('Contained', 1),
#  ('1680', 1),
#  ('Contemporary', 1),
#  ('1892', 1),
#  ('Artifacts', 1),
#  ('Fuente', 1),
#  ('Politicans', 1),
#  ('Accusations', 1),
#  ('Chapter', 1),
#  ('Buildings', 1),
#  ('Graffiti', 1),
#  ('Plays', 1),
#  ('Access', 1),
#  ('1962', 1),
#  ('Ecclesiastical', 1),
#  ('Sun', 1),
#  ('Drawn', 1),
#  ('Photographscollection', 1),
#  ('Emphasis', 1),
#  ('Dust', 1),
#  ('Cases', 1),
#  ('Norte', 1),
#  ('53', 1),
#  ('Translated', 1),
#  ('Set', 1),
#  ('Tax', 1),
#  ('Secretaria', 1),
#  ('Typed', 1),
#  ('Oldest', 1),
#  ('Chihuahua', 1),
#  ('Iconography', 1),
#  ('Settlers', 1),
#  ('Parral', 1),
#  ('Gerardo', 1),
#  ('Uruguay', 1),
#  ('1978', 1),
#  ('Boats', 1),
#  ('Club', 1),
#  ('Presence', 1),
#  ('Blueprints', 1),
#  ('Accumulation', 1),
#  ('Officers', 1),
#  ('Build', 1),
#  ('Songs', 1),
#  ('Handbills', 1),
#  ('Bookplates', 1),
#  ('Teachers', 1),
#  ('Health', 1),
#  ('Affairs', 1),
#  ('Lancandon', 1),
#  ('Design', 1),
#  ('Pedro', 1),
#  ('Represents', 1),
#  ('Co', 1),
#  ('Trot', 1),
#  ('Saltillo', 1),
#  ('100', 1),
#  ('Otermin', 1),
#  ('Southern', 1),
#  ('Largely', 1),
#  ('Single', 1),
#  ('1944', 1),
#  ('Demonstrations', 1),
#  ('Leadville', 1),
#  ('Shown', 1),
#  ('Scenes', 1),
#  ('Performing', 1),
#  ('Files', 1),
#  ('Valley', 1),
#  ('Nava', 1),
#  ('Englishthe', 1),
#  ('Visite', 1),
#  ('Data', 1),
#  ('Attribute', 1),
#  ('Much', 1),
#  ('Performances', 1),
#  ('Communities', 1),
#  ('1970S', 1),
#  ('1964', 1),
#  ('Constitution', 1),
#  ('Formats', 1),
#  ('Prisoners', 1),
#  ('Construction', 1),
#  ('Arratia', 1),
#  ('Fernando', 1),
#  ('Video', 1),
#  ('Operettas', 1),
#  ('Wife', 1),
#  ('Magic', 1),
#  ('Citations', 1),
#  ('Geographically', 1),
#  ('Romance', 1),
#  ('Particular', 1),
#  ('Luis', 1),
#  ('Elsa', 1),
#  ('Histories', 1),
#  ('Publisher', 1),
#  ('Received', 1),
#  ('1966', 1),
#  ('Mation', 1),
#  ('Fotografia', 1),
#  ('Losses', 1),
#  ('Guillermo', 1),
#  ('Kahlo', 1),
#  ('Complex', 1),
#  ('Said', 1),
#  ('1960', 1),
#  ('Forest', 1),
#  ('Bernalillo', 1),
#  ('Dedicated', 1),
#  ('Seligman', 1),
#  ('Public', 1),
#  ('Certificates', 1),
#  ('Actual', 1),
#  ('Policy', 1),
#  ('Reproduced', 1),
#  ('Volcanoes', 1),
#  ('Theatrical', 1),
#  ('Periodicals', 1),
#  ('Edward', 1),
#  ('Mass', 1),
#  ('Eighty', 1),
#  ('Within', 1),
#  ('Priests', 1),
#  ('Placitas', 1),
#  ('Arnulfo', 1),
#  ('Incan', 1),
#  ('1940S', 1),
#  ('1920', 1),
#  ('Metal', 1),
#  ('Suggestions', 1),
#  ('Questions', 1),
#  ('Lake', 1),
#  ('Temalan', 1),
#  ('Artillery', 1),
#  ('Round', 1),
#  ('Documentary', 1),
#  ('Promoting', 1),
#  ('Monrreal', 1),
#  ('Unavailability', 1),
#  ('Anglo', 1),
#  ('Serve', 1),
#  ('Residential', 1),
#  ('Contrast', 1),
#  ('Attempted', 1),
#  ('Gasset', 1),
#  ('Billboards', 1),
#  ('Strike', 1),
#  ('Roy', 1),
#  ('Mess', 1),
#  ('1925', 1),
#  ('Market', 1),
#  ('120', 1),
#  ('Transactions', 1),
#  ('Scholes', 1),
#  ('Show', 1),
#  ('Romanza', 1),
#  ('Relation', 1),
#  ('Origi', 1),
#  ('Genres', 1),
#  ('Ruben', 1),
#  ('1985', 1),
#  ('Demographic', 1),
#  ('Nichols', 1),
#  ('Hygiene', 1),
#  ('Brother', 1),
#  ('Mr', 1),
#  ('Wealth', 1),
#  ('Algodones', 1),
#  ('Offer', 1),
#  ('Holy', 1),
#  ('Archaeologist', 1),
#  ('Consulting', 1),
#  ('Oversize', 1),
#  ('Richard', 1),
#  ('Turmoil', 1),
#  ('Performed', 1),
#  ('Cused', 1),
#  ('Imperialism', 1),
#  ('Continually', 1),
#  ('Sandoval', 1),
#  ('Guides', 1),
#  ('1872', 1),
#  ('Narrative', 1),
#  ('Headers', 1),
#  ('Running', 1),
#  ('Electronic', 1),
#  ('Maintained', 1),
#  ('Etchings', 1),
#  ('Dispositions', 1),
#  ('Cruces', 1),
#  ('Professor', 1),
#  ('1951', 1),
#  ('Perhaps', 1),
#  ('Jemez', 1),
#  ('Filing', 1),
#  ('Visit', 1),
#  ('Webpage', 1),
#  ('Provide', 1),
#  ('Cartoonists', 1),
#  ('Remedies', 1),
#  ('Peoples', 1),
#  ('Printer', 1),
#  ('Registered', 1),
#  ('Lifes', 1),
#  ('Army', 1),
#  ('Photograph', 1),
#  ('Added', 1),
#  ('Contracts', 1),
#  ('Compare', 1),
#  ('Yucatan', 1),
#  ('Environment', 1),
#  ('Librettos', 1),
#  ('Air', 1),
#  ('Collections', 1),
#  ('Place', 1),
#  ('Described', 1),
#  ('Operations', 1),
#  ('270', 1),
#  ('Numbered', 1),
#  ('Levels', 1),
#  ('Police', 1),
#  ('Beautiful', 1),
#  ('Certifying', 1),
#  ('Documenting', 1),
#  ('Field', 1),
#  ('Light', 1),
#  ('Advocacy', 1),
#  ...]

# %% [markdown]
# ## Bigram Analysis
#
# A bigram is a two-word phrase. Below, we analyze the tokenized corpus data for bigrams and filter out stopwords. The stopword list is whatever is provided by default by NLTK.
#
# Results are further filtered to limit the list of bigrams to those which occur three or more times.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(cDataNoWS)
finder.apply_freq_filter(3)
ignored_words = nltk.corpus.stopwords.words('english')
finder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in ignored_words)
finder.nbest(bigram_measures.likelihood_ratio, 100)
# Out:
# [('Latin', 'America'),
#  ('collection', 'contains'),
#  ('New', 'Mexico'),
#  ('United', 'States'),
#  ('Archivo', 'General'),
#  ('Also', 'included'),
#  ('colonial', 'history'),
#  ('Margaret', 'Randall'),
#  ('Guadalupe', 'Posada'),
#  ('José', 'Guadalupe'),
#  ('Mexico', 'City'),
#  ('Casino', 'Luís'),
#  ('Communist', 'Party'),
#  ('Luís', 'Mier'),
#  ('Teatro', 'Casino'),
#  ('Puerto', 'Rican'),
#  ('human', 'rights'),
#  ('South', 'America'),
#  ('writings', 'focus'),
#  ('Madrid', 'Archivo'),
#  ('nineteenth', 'century'),
#  ('Latin', 'American'),
#  ('wide', 'variety'),
#  ('collection', 'consists'),
#  ('century', 'Mexican'),
#  ('research', 'materials'),
#  ('contains', 'material'),
#  ('Spanish', 'documents')]

# %% [markdown]
# ## Trigram Analysis
#
# A trigram is a three-word phrase. Below, we analyze the tokenized corpus data for trigrams and filter out stopwords. The stopword list is whatever is provided by default by NLTK.
#
# Results are further filtered to limit the list of trigrams to those which occur three or more times.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
triFinder = TrigramCollocationFinder.from_words(cDataNoWS)
triFinder.apply_freq_filter(3)
ignored_words = nltk.corpus.stopwords.words('english')
triFinder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in ignored_words)
triFinder.nbest(trigram_measures.likelihood_ratio, 50)
# Out:
# [('José', 'Guadalupe', 'Posada'),
#  ('Casino', 'Luís', 'Mier'),
#  ('Teatro', 'Casino', 'Luís')]

# %% [markdown]
# ## Word Cloud
#
# Here we generate a word cloud, which as noted can include bigrams (see 'New Mexico' and "Latin America' in our example).
#
# For those interested in exploring and working with an API, the Wordcloud reference at [http://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud](http://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud) is thorough yet manageable.

# %%
# The next block create a WordCloud object and passes multiple arguments including the number of words to include in the
# word cloud ('max_words'). All of the arguments have defaults, which for practical purposes means that none are required.

# Also note - a 'mask' is not needed, but the resulting word cloud is less aesthectically pleasing.

wordcloud = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png')
                     )
wordcloud.generate_from_text(collCorpus)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7FF066A2ED30>

# %% [markdown]
# ### A Note on Stopwords
#
# The Wordcloud module comes with its own set of stopwords (note here that 'set' is a specific data structure and shouldn't be confused with a list). For some purposes we want to be able to expand or customize the set of stopwords - see in the example above, 'collection contains,' which is common to our collection descriptions but not of particular interest in our results.
#
# In the next cell, we create another word cloud but this time we're going to use NLTK's defaul set of English stopwords and add some of our own. (Thanks to Karl for the code!)

# %%
from nltk.corpus import stopwords
from operator import itemgetter

# Get NLTK set of English stopwords
stop = set(stopwords.words('english'))

# Define some additional characters to exclude. Note that these are sets.
punctuation = set(u".,;:()'\"[]{}<>?!=/#%&$12345678910")
annoyances = set({u'``',u"''",u'\x9d',u"'s"})

# Declare a set of stopwords specific to our example.
# It is likely that stemming is supported, so we wouldn't have to include every variation of
# words like contain, contains, etc. 
additional = set({'collection', 'contains', 'also', 'contain', 'consists', 'include', 'includes', 'de'})

# Create a new set which includes all of the stopword sets above.
fullstop = sorted((stop | punctuation | annoyances | additional), key=itemgetter(0))

# The rest is the same as above, except that we reference our customized stopword list.
wordcloud = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png'),
                      stopwords=fullstop
                     )
wordcloud.generate_from_text(collCorpus)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7FF066A4E748>

# %% [markdown]
# # <a name="word"></a> Word Documents
#
# **NOTE: If you skipped here from the top of the page, you may still need to load libraries and etc. From the _Cell_ menu, select _Run All Above_**.
#
#
# From here on, more useful information may be presented in comments in the code blocks. But as an overview, the next several cells provide a process for a basic text analysis of the content of a MS Word document. The analysis consists of:
#
# 1. Word count
# 2. Bigram (two word phrase or collocation) and trigram (three word phrase or collocation) analysis
# 3. Word cloud
#
# The process makes use of the following libraries: Python-Docx, NLTK, Wordcloud.
#
# As noted above, the python-docx library is able to parse out the many elements of a Word document - formatting info, fonts, headers, etc. As with our HTML example above, for demo purposes we will keep things simple and only use paragraph text.

# %%
# Import the library and load a Word file into memory. Thanks to Wendy for the sample Word file!

import docx
doc = docx.Document('staying-smart.docx')

# %%
# Similar to the process used above, create an empty list. Iterate through the paragraphs in the document
# and append the paragraph text to the list.

fullText = []
for para in doc.paragraphs:
    fullText.append(para.text)
fullText
# Out:
# ['S T A Y I N G S M A R T: How Today’s Graduates Continue to Learn Once They Complete College BY ALISON J. HEAD, PH.D. PROJECT INFORMATION LITERACY RESEARCH REPORT THE PASSAGE STUDIES JANUARY 5, 2016 PROJECT INFORMATION LITERACY http://projectinfolit.org THE UNIVERSITY OF WASHINGTON INFORMATION SCHOOL RESEARCH SPONSORED BY THE INSTITUTE OF MUSEUM AND LIBRARIES (IMLS) Abstract: This report presents findings about the information-seeking behavior of relatively recent college graduates used for lifelong learning in personal life, the workplace, and the local communities where they lived. Included are results from online surveys of 1,651 respondents and telephone interviews with 126 study participants who graduated from one of 10 US colleges and universities between 2007 and 2012. Findings indicated that most graduates needed to learn a combination of basic and complex life skills during the past year, such as money-management, how to make household repairs, and how to advance in their careers and communicate better on the job. They consulted friends, family, and coworkers almost as much as the Web. Graduates preferred information sources that had currency, utility, and interactivity. They also placed a high premium on curated information systems that were organized and kept up-to-date, such as libraries, museums, and bookstores. A model of shared utility is introduced for explaining graduates’ use of contemporary social media technologies as well as personal connections they had established with trusted allies. Graduates reported four barriers to their continued learning efforts: lack of time, finding affordable learning sources, staying on top of everything they needed to know, and staying motivated to keep learning after college. As a whole, graduates prided themselves on their ability to search, evaluate, and present information, skills they honed during college. Yet, far fewer said that their college experience had helped them develop the critical thinking skill of framing and asking questions of their own, which is a skill they inevitably needed in their post-college lives. Ten recommendations are presented for improving educational strategies, resources, and services that foster lifelong learning. Project Information Literacy Research Report: “Staying Smart” | January 5, 2016 | Alison J. Head 2 Introduction Jessica received her baccalaureate degree in finance from one of the best schools in the US in 2010.1 The endless hours she spent studying had paid off. Unlike many of her classmates struggling to find entry-level career jobs in the worst job market for college hires in 20 years, she quickly landed a good job. 2 She put the books away and focused her energy on doing rather than learning. Like most of today’s young graduates, Jessica soon discovered that questions do not end with college assignments. Real life requires constant learning. Within months of leaving campus, she found herself needing to figure out how to schedule student loan payments, negotiate a salary increase, brush up on a couple of spreadsheet functions, plan a sightseeing trip to New York, and learn how to cook for herself. Without a second thought, she grabbed her iPad, did a Google search, and visited the sites she usually frequented, like YouTube, Pinterest, and Hipmunk. She also turned to a trusted friend for advice. These are the tools for lifelong learning in the 21st century, a flood of Internet- and humanmediated sources that help recent graduates solve basic to complex information problems. Even though Jessica, and others in the Google Generation, may have more information outlets than all previous generations combined, today\'s graduates are finding that staying informed, knowledgeable, and skilled may be more daunting than ever before. Adding to this challenge, most graduates fight to carve out time to keep learning. Some cannot afford the expertise they want from professionals like contractors, attorneys, accountants, or career advisors. Oth ...

# %% [markdown]
# ## Single Word Count
#
# All of our text is currently in a list. To do basic word and ngram analysis, we need to convert the list into a text corpus. There are various ways to do this, but for simplicity's sake we are going to combine all of the descriptions into one long string. "String" is a data type - think of it as generic text.

# %%
# Build a corpus string, also similar to the above HTML example. Because the source document includes several
# additional carriage returns between paragraphs, add a condition to check for and bypass empty paragraphs.

collCorpus2 = ''
for p in range(0, len(fullText)):
    t = fullText[p]
    if t != ' ':
        collCorpus2 = collCorpus2 + str(t)

# The next two lines tokenize the corpus - that is, the long unformatted string is converted into
# a list of individual words. The process also removes additional whitespace. The tokenized text data
# are stored in a new variable, 'wordDataNoWS' ('word data, no whitespace').
        
tokenizer = RegexpTokenizer(r'\w+')
wordDataNoWS = tokenizer.tokenize(collCorpus2)

# The next two lines use methods from the Counter module to normalize words (tokens) in the corpus
# and bypass stopwords. The second line generates the word count.

word_count_dict = Counter(w.title() for w in wordDataNoWS if w.lower() not in stopwords.words())
word_count_dict.most_common()
# Out:
# [('Graduates', 192),
#  ('Learning', 153),
#  ('Information', 139),
#  ('College', 78),
#  ('Needs', 67),
#  ('Personal', 61),
#  ('Skills', 55),
#  ('Research', 53),
#  ('Said', 52),
#  ('Lives', 51),
#  ('Report', 47),
#  ('5', 46),
#  ('1', 46),
#  ('0', 45),
#  ('Workplace', 44),
#  ('Recent', 43),
#  ('One', 43),
#  ('Needed', 42),
#  ('Literacy', 41),
#  ('Life', 41),
#  ('Respondents', 40),
#  ('Sources', 39),
#  ('Used', 38),
#  ('Learn', 38),
#  ('Staying', 38),
#  ('Online', 37),
#  ('2', 36),
#  ('Blogs', 36),
#  ('Alison', 35),
#  ('Use', 35),
#  ('Figure', 35),
#  ('Head', 34),
#  ('Project', 34),
#  ('10', 33),
#  ('Others', 33),
#  ('Continued', 33),
#  ('Like', 33),
#  ('Past', 32),
#  ('Lifelong', 32),
#  ('Community', 31),
#  ('Time', 31),
#  ('2016', 30),
#  ('Smart', 29),
#  ('Year', 29),
#  ('January', 29),
#  ('Today', 29),
#  ('Three', 28),
#  ('New', 28),
#  ('Survey', 27),
#  ('Local', 27),
#  ('3', 27),
#  ('Professional', 26),
#  ('Findings', 26),
#  ('Study', 24),
#  ('Communication', 24),
#  ('Sample', 23),
#  ('Interviews', 23),
#  ('9', 23),
#  ('8', 23),
#  ('Public', 23),
#  ('Working', 22),
#  ('Many', 22),
#  ('Could', 21),
#  ('Finding', 21),
#  ('Http', 21),
#  ('Find', 20),
#  ('Results', 20),
#  ('Still', 20),
#  ('Follow', 20),
#  ('Interpersonal', 20),
#  ('Two', 19),
#  ('Interviewed', 19),
#  ('Blog', 19),
#  ('Us', 19),
#  ('12', 19),
#  ('Found', 19),
#  ('Google', 19),
#  ('Wanted', 19),
#  ('Civic', 19),
#  ('Sites', 19),
#  ('Libraries', 19),
#  ('Analysis', 19),
#  ('Search', 18),
#  ('14', 18),
#  ('Young', 18),
#  ('Data', 18),
#  ('Library', 18),
#  ('Communities', 18),
#  ('Responses', 17),
#  ('Social', 17),
#  ('25', 17),
#  ('Web', 17),
#  ('May', 17),
#  ('G', 16),
#  ('13', 16),
#  ('Need', 16),
#  ('Making', 15),
#  ('20', 15),
#  ('6', 15),
#  ('Reported', 15),
#  ('Based', 15),
#  ('Career', 15),
#  ('Especially', 15),
#  ('4', 15),
#  ('Current', 14),
#  ('Question', 14),
#  ('Half', 14),
#  ('2015', 14),
#  ('Business', 14),
#  ('24', 14),
#  ('Development', 14),
#  ('Students', 14),
#  ('Questions', 14),
#  ('Graduate', 14),
#  ('Seeking', 14),
#  ('Youtube', 14),
#  ('Part', 14),
#  ('First', 13),
#  ('Involved', 13),
#  ('Knowledge', 13),
#  ('Www', 13),
#  ('Total', 13),
#  ('Books', 13),
#  ('Facebook', 13),
#  ('Almost', 13),
#  ('Different', 13),
#  ('Percentages', 12),
#  ('Family', 12),
#  ('Colleges', 12),
#  ('Fewer', 12),
#  ('2014', 12),
#  ('Set', 12),
#  ('19', 12),
#  ('According', 12),
#  ('Age', 12),
#  ('Universities', 12),
#  ('Work', 12),
#  ('Far', 11),
#  ('7', 11),
#  ('Friends', 11),
#  ('100', 11),
#  ('Education', 11),
#  ('Major', 11),
#  ('Users', 11),
#  ('Volunteering', 11),
#  ('Using', 11),
#  ('Org', 11),
#  ('Digital', 11),
#  ('Campus', 10),
#  ('Competencies', 10),
#  ('Higher', 10),
#  ('28', 10),
#  ('2012', 10),
#  ('16', 10),
#  ('Across', 10),
#  ('Arenas', 10),
#  ('Job', 10),
#  ('Model', 10),
#  ('Money', 10),
#  ('Opportunities', 10),
#  ('Months', 10),
#  ('Mobile', 10),
#  ('Apply', 10),
#  ('Well', 10),
#  ('Four', 10),
#  ('Coworkers', 10),
#  ('651', 9),
#  ('27', 9),
#  ('Resources', 9),
#  ('Access', 9),
#  ('Engines', 9),
#  ('Majority', 9),
#  ('56', 9),
#  ('21', 9),
#  ('Turned', 9),
#  ('See', 9),
#  ('69', 9),
#  ('Slightly', 9),
#  ('Degree', 9),
#  ('Field', 9),
#  ('Statistics', 9),
#  ('Often', 9),
#  ('Solutions', 9),
#  ('Hobbies', 9),
#  ('Bookstores', 9),
#  ('People', 9),
#  ('Employable', 9),
#  ('Things', 8),
#  ('Strategies', 8),
#  ('Section', 8),
#  ('Date', 8),
#  ('Quick', 8),
#  ('Top', 8),
#  ('Studies', 8),
#  ('Talk', 8),
#  ('Educational', 8),
#  ('Internet', 8),
#  ('Studied', 8),
#  ('School', 8),
#  ('Problems', 8),
#  ('Older', 8),
#  ('Twitter', 8),
#  ('Action', 8),
#  ('Complete', 8),
#  ('Presented', 8),
#  ('Given', 8),
#  ('Devices', 8),
#  ('Post', 8),
#  ('Less', 8),
#  ('Improving', 8),
#  ('Utility', 8),
#  ('Know', 8),
#  ('Discussed', 8),
#  ('Best', 8),
#  ('Another', 8),
#  ('30', 8),
#  ('Guidance', 8),
#  ('Budget', 8),
#  ('Ability', 8),
#  ('50', 8),
#  ('75', 8),
#  ('Go', 8),
#  ('Place', 8),
#  ('Get', 8),
#  ('Everyday', 8),
#  ('Learners', 8),
#  ('Instance', 8),
#  ('Much', 8),
#  ('Good', 8),
#  ('University', 8),
#  ('Formal', 8),
#  ('Stay', 8),
#  ('Keep', 8),
#  ('Read', 7),
#  ('Improve', 7),
#  ('Source', 7),
#  ('Ways', 7),
#  ('Looking', 7),
#  ('Professionals', 7),
#  ('Usage', 7),
#  ('Live', 7),
#  ('Databases', 7),
#  ('Appears', 7),
#  ('18', 7),
#  ('Ideas', 7),
#  ('Relied', 7),
#  ('Lived', 7),
#  ('Summarizing', 7),
#  ('Appendix', 7),
#  ('Enrolled', 7),
#  ('Jobs', 7),
#  ('National', 7),
#  ('Programs', 7),
#  ('Explained', 7),
#  ('Housing', 7),
#  ('York', 7),
#  ('Washington', 7),
#  ('Posts', 7),
#  ('11', 7),
#  ('37', 7),
#  ('Extent', 7),
#  ('Finances', 7),
#  ('Children', 7),
#  ('Needing', 7),
#  ('Licensed', 7),
#  ('Ongoing', 7),
#  ('Pil', 7),
#  ('Pick', 7),
#  ('Spent', 7),
#  ('Check', 7),
#  ('Learned', 7),
#  ('Physical', 7),
#  ('Looked', 7),
#  ('Participants', 7),
#  ('Conducted', 7),
#  ('Museums', 7),
#  ('House', 6),
#  ('23', 6),
#  ('Interest', 6),
#  ('Trusted', 6),
#  ('Ever', 6),
#  ('Though', 6),
#  ('Informal', 6),
#  ('Critical', 6),
#  ('Else', 6),
#  ('Fifths', 6),
#  ('Wikipedia', 6),
#  ('Living', 6),
#  ('Times', 6),
#  ('Student', 6),
#  ('Buying', 6),
#  ('Whether', 6),
#  ('Anything', 6),
#  ('Say', 6),
#  ('Going', 6),
#  ('60', 6),
#  ('Make', 6),
#  ('Next', 6),
#  ('Options', 6),
#  ('Discussions', 6),
#  ('Likely', 6),
#  ('Services', 6),
#  ('Forums', 6),
#  ('Process', 6),
#  ('Hours', 6),
#  ('Managing', 6),
#  ('72', 6),
#  ('Pdf', 6),
#  ('Helped', 6),
#  ('Tasks', 6),
#  ('Employed', 6),
#  ('Additional', 6),
#  ('Lesser', 6),
#  ('Develop', 6),
#  ('Purchases', 6),
#  ('Former', 6),
#  ('Computer', 6),
#  ('Advice', 6),
#  ('Groups', 6),
#  ('Small', 6),
#  ('Thirds', 6),
#  ('Daily', 6),
#  ('Behavior', 6),
#  ('Five', 5),
#  ('Average', 5),
#  ('Network', 5),
#  ('Accessed', 5),
#  ('Attention', 5),
#  ('Something', 5),
#  ('Content', 5),
#  ('Would', 5),
#  ('Concluded', 5),
#  ('Years', 5),
#  ('Received', 5),
#  ('Available', 5),
#  ('Traditional', 5),
#  ('38', 5),
#  ('Thinking', 5),
#  ('Help', 5),
#  ('Worked', 5),
#  ('Boss', 5),
#  ('Difficult', 5),
#  ('Travel', 5),
#  ('26', 5),
#  ('70', 5),
#  ('Expertise', 5),
#  ('Nearly', 5),
#  ('Fix', 5),
#  ('However', 5),
#  ('Number', 5),
#  ('Pinterest', 5),
#  ('Media', 5),
#  ('15', 5),
#  ('Meet', 5),
#  ('R', 5),
#  ('57', 5),
#  ('Spiritual', 5),
#  ('Rather', 5),
#  ('Institutions', 5),
#  ('Began', 5),
#  ('48', 5),
#  ('Better', 5),
#  ('Kept', 5),
#  ('Class', 5),
#  ('Together', 5),
#  ('Short', 5),
#  ('Important', 5),
#  ('Quality', 5),
#  ('Employment', 5),
#  ('Alumni', 5),
#  ('Apps', 5),
#  ('Technology', 5),
#  ('Desktop', 5),
#  ('Starting', 5),
#  ('Websites', 5),
#  ('Instructors', 5),
#  ('Continue', 5),
#  ('Understand', 5),
#  ('Whole', 5),
#  ('Sought', 5),
#  ('Moreover', 5),
#  ('Expand', 5),
#  ('79', 5),
#  ('Engage', 5),
#  ('Laptops', 5),
#  ('Participation', 5),
#  ('Informed', 5),
#  ('Answer', 5),
#  ('Motivated', 5),
#  ('Adults', 5),
#  ('B', 5),
#  ('Taken', 5),
#  ('Complex', 5),
#  ('Schools', 4),
#  ('Little', 4),
#  ('32', 4),
#  ('Asked', 4),
#  ('33', 4),
#  ('Cost', 4),
#  ('Repairs', 4),
#  ('Called', 4),
#  ('Surveyed', 4),
#  ('Supporting', 4),
#  ('Librarians', 4),
#  ('Specialized', 4),
#  ('Methods', 4),
#  ('Setting', 4),
#  ('Program', 4),
#  ('Volunteer', 4),
#  ('Advance', 4),
#  ('Systems', 4),
#  ('Every', 4),
#  ('Events', 4),
#  ('Fixes', 4),
#  ('Videos', 4),
#  ('Purpose', 4),
#  ('Interviewees', 4),
#  ('Present', 4),
#  ('44', 4),
#  ('News', 4),
#  ('Depth', 4),
#  ('Always', 4),
#  ('Networking', 4),
#  ('Cook', 4),
#  ('Discussion', 4),
#  ('Third', 4),
#  ('88', 4),
#  ('2011', 4),
#  ('Back', 4),
#  ('Changing', 4),
#  ('2013', 4),
#  ('Management', 4),
#  ('Recommendations', 4),
#  ('Conversations', 4),
#  ('List', 4),
#  ('Quickly', 4),
#  ('Mentioned', 4),
#  ('34', 4),
#  ('Variables', 4),
#  ('Focused', 4),
#  ('Consulted', 4),
#  ('Financial', 4),
#  ('Affordable', 4),
#  ('Household', 4),
#  ('Checks', 4),
#  ('Self', 4),
#  ('Required', 4),
#  ('Communicate', 4),
#  ('Yet', 4),
#  ('Nine', 4),
#  ('Health', 4),
#  ('55', 4),
#  ('Interviewee', 4),
#  ('Political', 4),
#  ('Religious', 4),
#  ('Followed', 4),
#  ('Careers', 4),
#  ('Way', 4),
#  ('59', 4),
#  ('Identified', 4),
#  ('Engagement', 4),
#  ('Deal', 4),
#  ('Gender', 4),
#  ('Relationship', 4),
#  ('Shared', 4),
#  ('Challenges', 4),
#  ('Interested', 4),
#  ('Large', 4),
#  ('Within', 4),
#  ('Dead', 4),
#  ('Described', 4),
#  ('Cases', 4),
#  ('Become', 4),
#  ('Useful', 4),
#  ('Human', 4),
#  ('Asking', 4),
#  ('Files', 4),
#  ('Computers', 4),
#  ('45', 4),
#  ('Relatively', 4),
#  ('Graduated', 4),
#  ('Reasons', 4),
#  ('Divided', 4),
#  ('Efforts', 4),
#  ('Sometimes', 4),
#  ('Provide', 4),
#  ('Science', 4),
#  ('17', 4),
#  ('Lot', 4),
#  ('Jessica', 4),
#  ('Availability', 4),
#  ('Currently', 4),
#  ('Assigned', 4),
#  ('Open', 4),
#  ('Courses', 4),
#  ('126', 4),
#  ('Decisions', 4),
#  ('Topic', 4),
#  ('Becoming', 4),
#  ('Collected', 4),
#  ('December', 4),
#  ('Neighborhood', 4),
#  ('Finance', 3),
#  ('Examined', 3),
#  ('Survival', 3),
#  ('Ratio', 3),
#  ('Beyond', 3),
#  ('Specific', 3),
#  ('Got', 3),
#  ('Ages', 3),
#  ('Food', 3),
#  ('Known', 3),
#  ('Form', 3),
#  ('Numerous', 3),
#  ('Basic', 3),
#  ('Whatever', 3),
#  ('Contacts', 3),
#  ('Activities', 3),
#  ('Importance', 3),
#  ('Shop', 3),
#  ('Second', 3),
#  ('Knew', 3),
#  ('Completed', 3),
#  ('Academic', 3),
#  ('Fifth', 3),
#  ('Allies', 3),
#  ('Hard', 3),
#  ('Cambridge', 3),
#  ('Getting', 3),
#  ('Women', 3),
#  ('Trip', 3),
#  ('Perform', 3),
#  ('Came', 3),
#  ('Articles', 3),
#  ('Since', 3),
#  ('Parents', 3),
#  ('Real', 3),
#  ('Imls', 3),
#  ('High', 3),
#  ('Figuring', 3),
#  ('Either', 3),
#  ('Fields', 3),
#  ('Even', 3),
#  ('Developed', 3),
#  ('Meetups', 3),
#  ('77', 3),
#  ('Meals', 3),
#  ('Scholarly', 3),
#  ('Desktops', 3),
#  ('Preferred', 3),
#  ('Buy', 3),
#  ('300', 3),
#  ('71', 3),
#  ('Settings', 3),
#  ('Workers', 3),
#  ('Investigated', 3),
#  ('Six', 3),
#  ('Market', 3),
#  ('April', 3),
#  ('Started', 3),
#  ('Building', 3),
#  ('74', 3),
#  ('61', 3),
#  ('Friend', 3),
#  ('Volunteered', 3),
#  ('Searches', 3),
#  ('Acquire', 3),
#  ('Introduced', 3),
#  ('Believed', 3),
#  ('Reading', 3),
#  ('Proquest', 3),
#  ('Majored', 3),
#  ('Made', 3),
#  ('Ultimately', 3),
#  ('Purchase', 3),
#  ('Applied', 3),
#  ('Separate', 3),
#  ('2007', 3),
#  ('Moved', 3),
#  ('Collect', 3),
#  ('Experiences', 3),
#  ('Coursera', 3),
#  ('Regression', 3),
#  ('Odds', 3),
#  ('Hear', 3),
#  ('Add', 3),
#  ('Ups', 3),
#  ('Days', 3),
#  ('Directly', 3),
#  ('Result', 3),
#  ('Ground', 3),
#  ('Someone', 3),
#  ('Week', 3),
#  ('Writers', 3),
#  ('Without', 3),
#  ('Documentaries', 3),
#  ('Industry', 3),
#  ('Evaluate', 3),
#  ('Experts', 3),
#  ('Cultures', 3),
#  ('Manage', 3),
#  ('Loan', 3),
#  ('Team', 3),
#  ('America', 3),
#  ('Telephone', 3),
#  ('Step', 3),
#  ('Put', 3),
#  ('Ask', 3),
#  ('Advisors', 3),
#  ('Remaining', 3),
#  ('Occur', 3),
#  ('Attorneys', 3),
#  ('Organized', 3),
#  ('Searching', 3),
#  ('Despite', 3),
#  ('Https', 3),
#  ('Interactivity', 3),
#  ('Virtual', 3),
#  ('Processes', 3),
#  ('Generation', 3),
#  ('Fourth', 3),
#  ('Projectinfolit', 3),
#  ('Domestic', 3),
#  ('Skill', 3),
#  ('Able', 3),
#  ('Situations', 3),
#  ('Rely', 3),
#  ('Remain', 3),
#  ('Receive', 3),
#  ('Messages', 3),
#  ('Rounding', 3),
#  ('31', 3),
#  ('Honed', 3),
#  ('Plans', 3),
#  ('Look', 3),
#  ('Investigate', 3),
#  ('Design', 3),
#  ('Company', 3),
#  ('Video', 3),
#  ('Great', 3),
#  ('Peers', 3),
#  ('000', 3),
#  ('Eric', 3),
#  ('Suggest', 3),
#  ('Coding', 3),
#  ('Meeting', 3),
#  ('Hotel', 3),
#  ('22', 3),
#  ('Agree', 3),
#  ('Kind', 3),
#  ('Matter', 3),
#  ('Detailed', 3),
#  ('Individuals', 3),
#  ('Mix', 3),
#  ('01', 3),
#  ('Locate', 3),
#  ('Association', 3),
#  ('35', 3),
#  ('Really', 3),
#  ('Comes', 3),
#  ('Specifics', 3),
#  ('Went', 3),
#  ('Level', 3),
#  ('P', 3),
#  ('Home', 3),
#  ('Generations', 3),
#  ('Payments', 3),
#  ('Group', 3),
#  ('Saying', 3),
#  ('Brush', 3),
#  ('Due', 3),
#  ('Topics', 3),
#  ('Indebted', 3),
#  ('Arena', 3),
#  ('Connections', 3),
#  ('Popular', 3),
#  ('Following', 3),
#  ('Seven', 3),
#  ('Context', 3),
#  ('29', 3),
#  ('Adapted', 3),
#  ('Last', 3),
#  ('Significant', 3),
#  ('Everything', 2),
#  ('Immediately', 2),
#  ('Leads', 2),
#  ('Struggling', 2),
#  ('Areas', 2),
#  ('Area', 2),
#  ('Department', 2),
#  ('Minute', 2),
#  ('Spill', 2),
#  ('Variety', 2),
#  ('Framing', 2),
#  ('Longer', 2),
#  ('Applicable', 2),
#  ('Determine', 2),
#  ('Adding', 2),
#  ('Paper', 2),
#  ('Central', 2),
#  ('Account', 2),
#  ('Categories', 2),
#  ('Baby', 2),
#  ('Trying', 2),
#  ('Ph', 2),
#  ('Show', 2),
#  ('Trouble', 2),
#  ('Jstor', 2),
#  ('Easy', 2),
#  ('Review', 2),
#  ('View', 2),
#  ('Cannot', 2),
#  ('Earlier', 2),
#  ('Series', 2),
#  ('Day', 2),
#  ('Institute', 2),
#  ('Lower', 2),
#  ('Puzzled', 2),
#  ('Uncertain', 2),
#  ('Bloomberg', 2),
#  ('Enjoyed', 2),
#  ('Afford', 2),
#  ('Common', 2),
#  ('Took', 2),
#  ('Campuses', 2),
#  ('Feel', 2),
#  ('Plan', 2),
#  ('Labor', 2),
#  ('Volume', 2),
#  ('Satisfy', 2),
#  ('Church', 2),
#  ('Modes', 2),
#  ('Watched', 2),
#  ('Monday', 2),
#  ('Center', 2),
#  ('Offered', 2),
#  ('Failure', 2),
#  ('Summary', 2),
#  ('Delegate', 2),
#  ('Voices', 2),
#  ('Congratulations', 2),
#  ('Demands', 2),
#  ('Associations', 2),
#  ('Arise', 2),
#  ('65', 2),
#  ('Sphere', 2),
#  ('Worlds', 2),
#  ('Crucible', 2),
#  ('Classmates', 2),
#  ('Cause', 2),
#  ('Century', 2),
#  ('52', 2),
#  ('Curated', 2),
#  ('Competitive', 2),
#  ('Indicated', 2),
#  ('Calculated', 2),
#  ('Hoped', 2),
#  ('Values', 2),
#  ('Conducting', 2),
#  ('Outcomes', 2),
#  ('Matters', 2),
#  ('Realized', 2),
#  ('Surveys', 2),
#  ('089', 2),
#  ('Preparing', 2),
#  ('Baccalaureate', 2),
#  ('Succeed', 2),
#  ('Practical', 2),
#  ('Paid', 2),
#  ('Pay', 2),
#  ('Numerator', 2),
#  ('Sparked', 2),
#  ('73', 2),
#  ('Grads', 2),
#  ('Scientists', 2),
#  ('Think', 2),
#  ('Venues', 2),
#  ('Motivations', 2),
#  ('Valued', 2),
#  ('Librarian', 2),
#  ('Breakdown', 2),
#  ('2010', 2),
#  ('Electronic', 2),
#  ('Lectures', 2),
#  ('Ina', 2),
#  ('Relevant', 2),
#  ('Turn', 2),
#  ('Landscape', 2),
#  ('Format', 2),
#  ('Monitor', 2),
#  ('Watching', 2),
#  ('Apathetic', 2),
#  ('Done', 2),
#  ('Curriculum', 2),
#  ('Analyses', 2),
#  ('Institutional', 2),
#  ('Creative', 2),
#  ('353', 2),
#  ('Situation', 2),
#  ('Purposes', 2),
#  ('Reports', 2),
#  ('Recently', 2),
#  ('Fill', 2),
#  ('Assignments', 2),
#  ('Experienced', 2),
#  ('Throughout', 2),
#  ('February', 2),
#  ('03', 2),
#  ('Statistically', 2),
#  ('Point', 2),
#  ('Greater', 2),
#  ('Leave', 2),
#  ('Preliminary', 2),
#  ('Closer', 2),
#  ('Declined', 2),
#  ('Period', 2),
#  ('Taxes', 2),
#  ('Clergy', 2),
#  ('Michele', 2),
#  ('Conduct', 2),
#  ('Deep', 2),
#  ('036', 2),
#  ('Verbal', 2),
#  ('838', 2),
#  ('Low', 2),
#  ('Outlets', 2),
#  ('Paperbacks', 2),
#  ('Diffuse', 2),
#  ('Laptop', 2),
#  ('Value', 2),
#  ('Sharing', 2),
#  ('Crisis', 2),
#  ('Grateful', 2),
#  ('Quarter', 2),
#  ('Resource', 2),
#  ('Newsweek', 2),
#  ('Kate', 2),
#  ('Necessarily', 2),
#  ('Increased', 2),
#  ('Curiosity', 2),
#  ('Tweets', 2),
#  ('Visitors', 2),
#  ('Consumer', 2),
#  ('Technorati', 2),
#  ('Combination', 2),
#  ('Stayed', 2),
#  ('Posed', 2),
#  ('Fulfilled', 2),
#  ('Training', 2),
#  ('Writing', 2),
#  ('Sections', 2),
#  ('Defines', 2),
#  ('Salary', 2),
#  ('Seek', 2),
#  ('Early', 2),
#  ('Bring', 2),
#  ('March', 2),
#  ('Professors', 2),
#  ('Related', 2),
#  ('Evaluating', 2),
#  ('Commitment', 2),
#  ('Explaining', 2),
#  ('Adaptive', 2),
#  ('Rapidly', 2),
#  ('Free', 2),
#  ('Mind', 2),
#  ('Mattered', 2),
#  ('Saving', 2),
#  ('Interact', 2),
#  ('Opportunity', 2),
#  ('Multiple', 2),
#  ('Grocery', 2),
#  ('Abreast', 2),
#  ('Harvard', 2),
#  ('Already', 2),
#  ('Instrument', 2),
#  ('Exploring', 2),
#  ('Sheer', 2),
#  ('Groceries', 2),
#  ('67', 2),
#  ('Committees', 2),
#  ('Enriched', 2),
#  ('Giving', 2),
#  ('Piqued', 2),
#  ('Denominator', 2),
#  ('Movie', 2),
#  ('Moocs', 2),
#  ('Bolded', 2),
#  ('Schedule', 2),
#  ('Summaries', 2),
#  ('Mainstream', 2),
#  ('Museum', 2),
#  ('Individual', 2),
#  ('Currency', 2),
#  ('5210', 2),
#  ('Among', 2),
#  ('Recognized', 2),
#  ('Krontiris', 2),
#  ('Prepare', 2),
#  ('Later', 2),
#  ('Pew', 2),
#  ('Internetlivestats', 2),
#  ('Nature', 2),
#  ('Technical', 2),
#  ('Fall', 2),
#  ('Constant', 2),
#  ('Cognitive', 2),
#  ('Associated', 2),
#  ('Childbirth', 2),
#  ('Dating', 2),
#  ('21St', 2),
#  ('Figures', 2),
#  ('Passage', 2),
#  ('Bystanders', 2),
#  ('06', 2),
#  ('Teaching', 2),
#  ('Percentage', 2),
#  ('Along', 2),
#  ('Profile', 2),
#  ('State', 2),
#  ('Experience', 2),
#  ('Qualitative', 2),
#  ('Divide', 2),
#  ('Placed', 2),
#  ('Marketing', 2),
#  ('Founded', 2),
#  ('Specifically', 2),
#  ('Budgets', 2),
#  ('Weekly', 2),
#  ('Hoeck', 2),
#  ('Highly', 2),
#  ('Engaged', 2),
#  ('Faced', 2),
#  ('Repairing', 2),
#  ('Credible', 2),
#  ('Members', 2),
#  ('Wellness', 2),
#  ('Focus', 2),
#  ('Track', 2),
#  ('Applying', 2),
#  ('Take', 2),
#  ('Tools', 2),
#  ('Larger', 2),
#  ('Perceptions', 2),
#  ('36', 2),
#  ('Knowledgeable', 2),
#  ('Logistic', 2),
#  ('Code', 2),
#  ('Investigating', 2),
#  ('Gallup', 2),
#  ('Comments', 2),
#  ('Ted', 2),
#  ('Consumed', 2),
#  ('42', 2),
#  ('Proficiency', 2),
#  ('Co', 2),
#  ('Tended', 2),
#  ('Engaging', 2),
#  ('Forbes', 2),
#  ('Move', 2),
#  ('Degrees', 2),
#  ('Gain', 2),
#  ('39', 2),
#  ('Objective', 2),
#  ('Kinds', 2),
#  ('Standards', 2),
#  ('Accountants', 2),
#  ('Documentary', 2),
#  ('Cooking', 2),
#  ('Literature', 2),
#  ('Told', 2),
#  ('Independent', 2),
#  ('Premium', 2),
#  ('Shelf', 2),
#  ('Centers', 2),
#  ('Pace', 2),
#  ('Fm', 2),
#  ('Researchers', 2),
#  ('Enrichment', 2),
#  ('Formulating', 2),
#  ('Task', 2),
#  ('Hires', 2),
#  ('Array', 2),
#  ('Probability', 2),
#  ('Conclude', 2),
#  ('Provided', 2),
#  ('Knowing', 2),
#  ('Managers', 2),
#  ('June', 2),
#  ('Bookstore', 2),
#  ('Credits', 2),
#  ('Success', 2),
#  ('05', 2),
#  ('Myriad', 2),
#  ('Ceos', 2),
#  ('Fashion', 2),
#  ('Feasible', 2),
#  ('Felt', 2),
#  ('Sponsored', 2),
#  ('Case', 2),
#  ...]

# %% [markdown]
# ## Bigram Analysis
#
# A bigram is a two-word phrase. Below, we analyze the tokenized corpus data for bigrams and filter out stopwords. The stopword list is whatever is provided by default by NLTK.
#
# Results are further filtered to limit the list of bigrams to those which occur three or more times.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(wordDataNoWS)
finder.apply_freq_filter(3)
ignored_words = nltk.corpus.stopwords.words('english')
finder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in ignored_words)
finder.nbest(bigram_measures.likelihood_ratio, 100)
# Out:
# [('Information', 'Literacy'),
#  ('Project', 'Information'),
#  ('Smart', 'January'),
#  ('Staying', 'Smart'),
#  ('Report', 'Staying'),
#  ('2016', 'Alison'),
#  ('learning', 'needs'),
#  ('Research', 'Report'),
#  ('Literacy', 'Research'),
#  ('past', 'year'),
#  ('continued', 'learning'),
#  ('personal', 'lives'),
#  ('recent', 'graduates'),
#  ('Learning', 'Needs'),
#  ('http', 'www'),
#  ('lifelong', 'learning'),
#  ('Still', 'others'),
#  ('Percentages', 'based'),
#  ('Personal', 'Life'),
#  ('interpersonal', 'communication'),
#  ('public', 'libraries'),
#  ('New', 'York'),
#  ('Lifelong', 'Learning'),
#  ('communication', 'skills'),
#  ('lesser', 'extent'),
#  ('public', 'library'),
#  ('information', 'seeking'),
#  ('search', 'engines'),
#  ('two', 'thirds'),
#  ('volunteering', 'opportunities'),
#  ('quick', 'fix'),
#  ('fix', 'solutions'),
#  ('local', 'community'),
#  ('seeking', 'behavior'),
#  ('651', 'recent'),
#  ('apply', 'responses'),
#  ('higher', 'education'),
#  ('Licensed', 'professionals'),
#  ('York', 'Times'),
#  ('graduates', 'said'),
#  ('digital', 'age'),
#  ('question', 'appears'),
#  ('far', 'fewer'),
#  ('anything', 'else'),
#  ('information', 'literacy'),
#  ('complete', 'data'),
#  ('young', 'graduates'),
#  ('Taken', 'together'),
#  ('domestic', 'survival'),
#  ('loan', 'payments'),
#  ('personal', 'life'),
#  ('local', 'communities'),
#  ('mobile', 'devices'),
#  ('next', 'section'),
#  ('lifelong', 'learners'),
#  ('recent', 'college'),
#  ('physical', 'place'),
#  ('Social', 'contacts'),
#  ('data', 'set'),
#  ('2014', 'http'),
#  ('student', 'loan'),
#  ('Professional', 'development'),
#  ('professional', 'development'),
#  ('Making', 'purchases'),
#  ('trusted', 'allies'),
#  ('college', 'graduates'),
#  ('2015', 'http'),
#  ('post', 'college'),
#  ('household', 'repairs'),
#  ('almost', 'half'),
#  ('Interpersonal', 'communication'),
#  ('Managing', 'finances'),
#  ('friends', 'family'),
#  ('Local', 'Community'),
#  ('desktop', 'computers'),
#  ('higher', 'ups'),
#  ('interviewed', 'said'),
#  ('make', 'household'),
#  ('religious', 'groups'),
#  ('100', 'due'),
#  ('projectinfolit', 'org'),
#  ('non', 'formal'),
#  ('shared', 'utility'),
#  ('information', 'sources'),
#  ('critical', 'thinking'),
#  ('Mobile', 'devices'),
#  ('quick', 'fixes'),
#  ('large', 'majority'),
#  ('three', 'arenas'),
#  ('sites', 'like'),
#  ('findings', 'suggest'),
#  ('telephone', 'interviews'),
#  ('becoming', 'involved'),
#  ('library', 'usage'),
#  ('place', 'online'),
#  ('interpersonal', 'skills'),
#  ('Google', 'search'),
#  ('Civic', 'action'),
#  ('good', 'source'),
#  ('total', 'number')]

# %% [markdown]
# ## Trigram Analysis
#
# A trigram is a three-word phrase. Below, we analyze the tokenized corpus data for trigrams and filter out stopwords. The stopword list is whatever is provided by default by NLTK.
#
# Results are further filtered to limit the list of trigrams to those which occur three or more times.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
triFinder = TrigramCollocationFinder.from_words(wordDataNoWS)
triFinder.apply_freq_filter(3)
ignored_words = nltk.corpus.stopwords.words('english')
triFinder.apply_word_filter(lambda w: len(w) < 3 or w.lower() in ignored_words)
triFinder.nbest(trigram_measures.likelihood_ratio, 50)
# Out:
# [('Project', 'Information', 'Literacy'),
#  ('Staying', 'Smart', 'January'),
#  ('Report', 'Staying', 'Smart'),
#  ('Information', 'Literacy', 'Research'),
#  ('Research', 'Report', 'Staying'),
#  ('Literacy', 'Research', 'Report'),
#  ('continued', 'learning', 'needs'),
#  ('learning', 'needs', 'today'),
#  ('major', 'learning', 'needs'),
#  ('651', 'recent', 'graduates'),
#  ('interpersonal', 'communication', 'skills'),
#  ('2014', 'http', 'www'),
#  ('Learning', 'Needs', 'Personal'),
#  ('New', 'York', 'Times'),
#  ('Still', 'others', 'said'),
#  ('information', 'seeking', 'behavior'),
#  ('quick', 'fix', 'solutions'),
#  ('Needs', 'Personal', 'Life'),
#  ('recent', 'college', 'graduates'),
#  ('complete', 'data', 'set'),
#  ('public', 'library', 'usage'),
#  ('used', 'search', 'engines'),
#  ('student', 'loan', 'payments'),
#  ('physical', 'place', 'online'),
#  ('make', 'household', 'repairs'),
#  ('domestic', 'survival', 'skills'),
#  ('post', 'college', 'lives')]

# %% [markdown]
# ## Word Cloud
#
# Here we generate a word cloud, which as noted can include bigrams (see 'New Mexico' and "Latin America' in our example).
#
# For those interested in exploring and working with an API, the Wordcloud reference at [http://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud](http://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html#wordcloud.WordCloud) is thorough yet manageable.

# %%
# The next block create a WordCloud object and passes multiple arguments including the number of words to include in the
# word cloud ('max_words'). All of the arguments have defaults, which for practical purposes means that none are required.

# Also note - a 'mask' is not needed, but the resulting word cloud is less aesthectically pleasing.

wordcloud = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png')
                     )
wordcloud.generate_from_text(collCorpus2)
wordcloud.to_image()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-538edb22d3fb> in <module>()
#       9                       mask=imread('cloud_mask_1.png')
#      10                      )
# ---> 11 wordcloud.generate_from_text(collCorpus2)
#      12 wordcloud.to_image()
#
# /opt/conda/lib/python3.5/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     540         """
#     541         words = self.process_text(text)
# --> 542         self.generate_from_frequencies(words)
#     543         return self
#     544
#
# /opt/conda/lib/python3.5/site-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     351         if len(frequencies) <= 0:
#     352             raise ValueError("We need at least 1 word to plot a word cloud, "
# --> 353                              "got %d." % len(frequencies))
#     354         frequencies = frequencies[:self.max_words]
#     355
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %% [markdown]
# ### A Note on Stopwords
#
# The Wordcloud module comes with its own set of stopwords (note here that 'set' is a specific data structure and shouldn't be confused with a list). For some purposes we want to be able to expand or customize the set of stopwords - see in the example above, 'collection contains,' which is common to our collection descriptions but not of particular interest in our results.
#
# In the next cell, we create another word cloud but this time we're going to use NLTK's defaul set of English stopwords and add some of our own. (Thanks to Karl for the code!)

# %%
from nltk.corpus import stopwords
from operator import itemgetter

# Get NLTK set of English stopwords
stop = set(stopwords.words('english'))

# Define some additional characters to exclude. Note that these are sets.
punctuation = set(u".,;:()'\"[]{}<>?!=/#%&$12345678910")
annoyances = set({u'``',u"''",u'\x9d',u"'s"})

# Declare a set of stopwords specific to our example.
# It is likely that stemming is supported, so we wouldn't have to include every variation of
# words like contain, contains, etc. 
additional = set({'collection', 'contains', 'also', 'contain', 'consists', 'include', 'includes', 'de'})

# Create a new set which includes all of the stopword sets above.
fullstop = sorted((stop | punctuation | annoyances | additional), key=itemgetter(0))

# The rest is the same as above, except that we reference our customized stopword list.
wordcloud = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png'),
                      stopwords=fullstop
                     )
wordcloud.generate_from_text(collCorpus)
wordcloud.to_image()
