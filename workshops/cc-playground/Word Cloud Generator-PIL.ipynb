# %% [markdown]
# # Word Cloud Generator
#
# ## __Copy Me!__
#
# First things first - more than one person working with a particular notebook will cause problems. For the purposes of this workshop, please make a copy and rename to prevent confusion.
#
# 1. From the _File_ menu, select _Make a copy_
# 2. This will open up a new notebook - please rename it before proceeding
# 3. From the _File_ menu, select _Rename..._.
# 4. Make the new name as unambiguous as possible.

# %%
# Uncomment the next two lines to install dependencies as needed.

#!pip install wordcloud
#!pip install python-docx
# Out:
# Requirement already satisfied (use --upgrade to upgrade): wordcloud in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.6.1 in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pillow in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): matplotlib in /opt/conda/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pytz in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): cycler in /opt/conda/lib/python3.5/site-packages/cycler-0.10.0-py3.5.egg (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): pyparsing!=2.0.4,>=1.5.6 in /opt/conda/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5 in /opt/conda/lib/python3.5/site-packages (from python-dateutil->matplotlib->wordcloud)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied (use --upgrade to upgrade): python-docx in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): lxml>=2.3.2 in /opt/conda/lib/python3.5/site-packages (from python-docx)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Load dependencies.

from wordcloud import WordCloud, STOPWORDS
from scipy.misc import imread
import docx

# %% [markdown]
# ## From a Word File

# %%
# Replace the empty string with the name of your Word file.
# To avoid errors, make sure the Word file is in the same directory as this notebook!

doc = docx.Document('staying-smart.docx')
fullText = []
for para in doc.paragraphs:
    fullText.append(para.text)

# %%
# Extract paragraph text.

corpus = ''
for p in fullText:
    corpus = corpus + str(p)
    
#corpus

# %%
# Generate the word cloud!

wordcloud = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png')
                     )
wordcloud.generate_from_text(corpus)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F737EE92DA0>

# %% [markdown]
# ## From a Text File

# %%
# Replace the given file name with yours.

wc = WordCloud(max_words=50,
                      min_font_size=6,
                      background_color='#ffffff',
                      mask=imread('cloud_mask_1.png')
                     )

with open('darwin_origin.txt', 'r') as data:
    wc.generate_from_text(data.read())
    data.close()

wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F737C92DB70>
