# %%
import requests as rq
import json
import time

# %%
# Define some shared variables

# determines if the script will drop and recreate the indices for the indices that will be refreshed
dropIndices = True

# run a limited test
testMode = False
testCount = 5

# Elastic Search Host
esHost = "http://es:9200"

# define headers for requests
headers = {'Content-Type':'application/json'}


# Index Names, Sources, and mapping definitions
# Set 'refresh' to True for the indices that you want to rebuild
indexInfo = [
    {
        'refresh':False,
        'indexName':"watersheds", 
        'dataSource':"https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/wbdhu2_PR_1hundthDD.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/wbdhu2_PR_1hundthDD-mapping.json"
    },
    {
        'refresh':True,
        'indexName':"triballands", 
        'dataSource':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/tl_2016_us_aiannh_Subset_.001_.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/tl_2016_us_aiannh_Subset_.001-mapping.json"
    },
    {
        'refresh':False,
        'indexName':"usstates", 
        'dataSource':"https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/us_state_BS_5hundthDD.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/us_state_BS_5hundthDD-mapping.json"
    }
]

def writelog(logfileName,message):
    timestr = time.strftime("%Y%m%d-%H%M%S")
    with open(logfileName,"a") as f:
        f.write(timestr + ": "+ message + "\n")

# %%
# test to see if the host is responding
reqString = esHost
r = rq.get(reqString)
print(r.status_code)
print(r.json())
# Out:
# 200
# {'tagline': 'You Know, for Search', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'NRcv8IVgRiGUjDbbZX95sw', 'name': 'edBz89I', 'version': {'lucene_version': '6.3.0', 'build_date': '2016-12-06T12:36:15.409Z', 'number': '5.1.1', 'build_hash': '5395e21', 'build_snapshot': False}}

# %%
# Drop and Create the indices

if dropIndices:
    for index in indexInfo:
        if index['refresh']:
            requestURL = esHost+"/"+index['indexName']
            indexMapping = rq.get(index['mapping']).json()[index['indexName']]
            #print(indexMapping)

            print("Deleting index: "+requestURL)
            r = rq.delete(requestURL)
            print("\tStatus Code: "+str(r.status_code))

            #print("Creating index: "+requestURL)
            #r = rq.put(requestURL, headers=headers)
            #print("\tStatus Code: "+str(r.status_code)+": "+str(r.json()))

            print("Adding index and mapping: "+requestURL)
            r = rq.put(requestURL, headers=headers, data=json.dumps(indexMapping))
            print("\tStatus Code: "+str(r.status_code)+": "+str(r.json()))
else:
    print("Indices were retained")
# Out:
# Deleting index: http://es:9200/triballands
# 	Status Code: 200
# Adding index and mapping: http://es:9200/triballands
# 	Status Code: 200: {'shards_acknowledged': True, 'acknowledged': True}

# %%
# load a GeoJSON files for processing
timestr = time.strftime("%Y%m%d-%H%M%S")
logfileName = "logs/rebuildIndices_"+timestr+".txt"

for sourceFile in indexInfo:
    if sourceFile['refresh']:
        r = rq.get(sourceFile['dataSource'])
        workingGeoString = r.json() # r.text
        workingGeo = workingGeoString # json.loads(workingGeoString)
        docType = workingGeo['type']
        docCRS = workingGeo['crs']
        #print(workingGeo['features'][0].keys())

        i = 1
        for feature in workingGeo['features']:
            logMessage = ''
            writelog(logfileName,logMessage)
            logMessage = "Processing: ("+str(i)+") "+sourceFile['indexName']
            writelog(logfileName,logMessage)
            print(logMessage)

            docFeatureType = feature['type']
            docFeatureProperties = feature['properties']
            docFeatureGeometry = feature['geometry']

            builtDoc = '{"type":\"%s\","crs":%s,"features":{"type":\"%s\","properties":%s,"geometry":%s}}'%(docType,json.dumps(docCRS),docFeatureType,json.dumps(docFeatureProperties),json.dumps(docFeatureGeometry))
            #builtDoc = builtDoc.replace("\'",'*--*')
            #builtDoc = builtDoc.replace("'",'"')
            #builtDoc = builtDoc.replace("*--*","'")


            try:
                docJSON = json.loads(builtDoc)
            except:
                print("\tFailed to create the GeoJSON document")
                print("==========================================")
                print(builtDoc)
                print("==========================================")
                print()

            # put the document into the index
            requestURL = esHost+"/"+sourceFile['indexName']+"/geojson/"+str(i)
            logMessage = "Adding Document: "+requestURL
            writelog(logfileName,logMessage)
            print(logMessage)
            r = rq.post(requestURL, data=json.dumps(docJSON), headers=headers)
            try:
                resultText = str(r.json()['result'])
            except:
                resultText = "ERROR\n\n==========================" + builtDoc + "\n"

            logMessage = "\tResult: "+str(r.status_code)+": "+resultText + "\n" + str(r.json())
            writelog(logfileName,logMessage)
            print(logMessage)
            print()


            i += 1

            if testMode:
                if i > testCount: break
    else:
        print("skipping: "+sourceFile['indexName'])
# Out:
# skipping: watersheds
# Processing: (1) triballands
# Adding Document: http://es:9200/triballands/geojson/1
# 	Result: 201: created
# {'_id': '1', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (2) triballands
# Adding Document: http://es:9200/triballands/geojson/2
# 	Result: 201: created
# {'_id': '2', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (3) triballands
# Adding Document: http://es:9200/triballands/geojson/3
# 	Result: 201: created
# {'_id': '3', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (4) triballands
# Adding Document: http://es:9200/triballands/geojson/4
# 	Result: 201: created
# {'_id': '4', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (5) triballands
# Adding Document: http://es:9200/triballands/geojson/5
# 	Result: 201: created
# {'_id': '5', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (6) triballands
# Adding Document: http://es:9200/triballands/geojson/6
# 	Result: 201: created
# {'_id': '6', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (7) triballands
# Adding Document: http://es:9200/triballands/geojson/7
# 	Result: 201: created
# {'_id': '7', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (8) triballands
# Adding Document: http://es:9200/triballands/geojson/8
# 	Result: 201: created
# {'_id': '8', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (9) triballands
# Adding Document: http://es:9200/triballands/geojson/9
# 	Result: 201: created
# {'_id': '9', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (10) triballands
# Adding Document: http://es:9200/triballands/geojson/10
# 	Result: 201: created
# {'_id': '10', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (11) triballands
# Adding Document: http://es:9200/triballands/geojson/11
# 	Result: 201: created
# {'_id': '11', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (12) triballands
# Adding Document: http://es:9200/triballands/geojson/12
# 	Result: 201: created
# {'_id': '12', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (13) triballands
# Adding Document: http://es:9200/triballands/geojson/13
# 	Result: 201: created
# {'_id': '13', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (14) triballands
# Adding Document: http://es:9200/triballands/geojson/14
# 	Result: 201: created
# {'_id': '14', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (15) triballands
# Adding Document: http://es:9200/triballands/geojson/15
# 	Result: 201: created
# {'_id': '15', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (16) triballands
# Adding Document: http://es:9200/triballands/geojson/16
# 	Result: 201: created
# {'_id': '16', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (17) triballands
# Adding Document: http://es:9200/triballands/geojson/17
# 	Result: 201: created
# {'_id': '17', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (18) triballands
# Adding Document: http://es:9200/triballands/geojson/18
# 	Result: 201: created
# {'_id': '18', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (19) triballands
# Adding Document: http://es:9200/triballands/geojson/19
# 	Result: 201: created
# {'_id': '19', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (20) triballands
# Adding Document: http://es:9200/triballands/geojson/20
# 	Result: 201: created
# {'_id': '20', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (21) triballands
# Adding Document: http://es:9200/triballands/geojson/21
# 	Result: 201: created
# {'_id': '21', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (22) triballands
# Adding Document: http://es:9200/triballands/geojson/22
# 	Result: 201: created
# {'_id': '22', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (23) triballands
# Adding Document: http://es:9200/triballands/geojson/23
# 	Result: 201: created
# {'_id': '23', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (24) triballands
# Adding Document: http://es:9200/triballands/geojson/24
# 	Result: 201: created
# {'_id': '24', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (25) triballands
# Adding Document: http://es:9200/triballands/geojson/25
# 	Result: 201: created
# {'_id': '25', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (26) triballands
# Adding Document: http://es:9200/triballands/geojson/26
# 	Result: 201: created
# {'_id': '26', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (27) triballands
# Adding Document: http://es:9200/triballands/geojson/27
# 	Result: 201: created
# {'_id': '27', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (28) triballands
# Adding Document: http://es:9200/triballands/geojson/28
# 	Result: 201: created
# {'_id': '28', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (29) triballands
# Adding Document: http://es:9200/triballands/geojson/29
# 	Result: 201: created
# {'_id': '29', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (30) triballands
# Adding Document: http://es:9200/triballands/geojson/30
# 	Result: 201: created
# {'_id': '30', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (31) triballands
# Adding Document: http://es:9200/triballands/geojson/31
# 	Result: 201: created
# {'_id': '31', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (32) triballands
# Adding Document: http://es:9200/triballands/geojson/32
# 	Result: 201: created
# {'_id': '32', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (33) triballands
# Adding Document: http://es:9200/triballands/geojson/33
# 	Result: 201: created
# {'_id': '33', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (34) triballands
# Adding Document: http://es:9200/triballands/geojson/34
# 	Result: 201: created
# {'_id': '34', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (35) triballands
# Adding Document: http://es:9200/triballands/geojson/35
# 	Result: 201: created
# {'_id': '35', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (36) triballands
# Adding Document: http://es:9200/triballands/geojson/36
# 	Result: 201: created
# {'_id': '36', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (37) triballands
# Adding Document: http://es:9200/triballands/geojson/37
# 	Result: 201: created
# {'_id': '37', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (38) triballands
# Adding Document: http://es:9200/triballands/geojson/38
# 	Result: 201: created
# {'_id': '38', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (39) triballands
# Adding Document: http://es:9200/triballands/geojson/39
# 	Result: 201: created
# {'_id': '39', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (40) triballands
# Adding Document: http://es:9200/triballands/geojson/40
# 	Result: 201: created
# {'_id': '40', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (41) triballands
# Adding Document: http://es:9200/triballands/geojson/41
# 	Result: 201: created
# {'_id': '41', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (42) triballands
# Adding Document: http://es:9200/triballands/geojson/42
# 	Result: 201: created
# {'_id': '42', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (43) triballands
# Adding Document: http://es:9200/triballands/geojson/43
# 	Result: 201: created
# {'_id': '43', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (44) triballands
# Adding Document: http://es:9200/triballands/geojson/44
# 	Result: 201: created
# {'_id': '44', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (45) triballands
# Adding Document: http://es:9200/triballands/geojson/45
# 	Result: 201: created
# {'_id': '45', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (46) triballands
# Adding Document: http://es:9200/triballands/geojson/46
# 	Result: 201: created
# {'_id': '46', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (47) triballands
# Adding Document: http://es:9200/triballands/geojson/47
# 	Result: 201: created
# {'_id': '47', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (48) triballands
# Adding Document: http://es:9200/triballands/geojson/48
# 	Result: 201: created
# {'_id': '48', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (49) triballands
# Adding Document: http://es:9200/triballands/geojson/49
# 	Result: 201: created
# {'_id': '49', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (50) triballands
# Adding Document: http://es:9200/triballands/geojson/50
# 	Result: 201: created
# {'_id': '50', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (51) triballands
# Adding Document: http://es:9200/triballands/geojson/51
# 	Result: 201: created
# {'_id': '51', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (52) triballands
# Adding Document: http://es:9200/triballands/geojson/52
# 	Result: 201: created
# {'_id': '52', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (53) triballands
# Adding Document: http://es:9200/triballands/geojson/53
# 	Result: 201: created
# {'_id': '53', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (54) triballands
# Adding Document: http://es:9200/triballands/geojson/54
# 	Result: 201: created
# {'_id': '54', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (55) triballands
# Adding Document: http://es:9200/triballands/geojson/55
# 	Result: 201: created
# {'_id': '55', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (56) triballands
# Adding Document: http://es:9200/triballands/geojson/56
# 	Result: 201: created
# {'_id': '56', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (57) triballands
# Adding Document: http://es:9200/triballands/geojson/57
# 	Result: 201: created
# {'_id': '57', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (58) triballands
# Adding Document: http://es:9200/triballands/geojson/58
# 	Result: 201: created
# {'_id': '58', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (59) triballands
# Adding Document: http://es:9200/triballands/geojson/59
# 	Result: 201: created
# {'_id': '59', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (60) triballands
# Adding Document: http://es:9200/triballands/geojson/60
# 	Result: 201: created
# {'_id': '60', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (61) triballands
# Adding Document: http://es:9200/triballands/geojson/61
# 	Result: 201: created
# {'_id': '61', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (62) triballands
# Adding Document: http://es:9200/triballands/geojson/62
# 	Result: 201: created
# {'_id': '62', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (63) triballands
# Adding Document: http://es:9200/triballands/geojson/63
# 	Result: 201: created
# {'_id': '63', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (64) triballands
# Adding Document: http://es:9200/triballands/geojson/64
# 	Result: 201: created
# {'_id': '64', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (65) triballands
# Adding Document: http://es:9200/triballands/geojson/65
# 	Result: 201: created
# {'_id': '65', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (66) triballands
# Adding Document: http://es:9200/triballands/geojson/66
# 	Result: 201: created
# {'_id': '66', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (67) triballands
# Adding Document: http://es:9200/triballands/geojson/67
# 	Result: 201: created
# {'_id': '67', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (68) triballands
# Adding Document: http://es:9200/triballands/geojson/68
# 	Result: 201: created
# {'_id': '68', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (69) triballands
# Adding Document: http://es:9200/triballands/geojson/69
# 	Result: 201: created
# {'_id': '69', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (70) triballands
# Adding Document: http://es:9200/triballands/geojson/70
# 	Result: 201: created
# {'_id': '70', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (71) triballands
# Adding Document: http://es:9200/triballands/geojson/71
# 	Result: 201: created
# {'_id': '71', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (72) triballands
# Adding Document: http://es:9200/triballands/geojson/72
# 	Result: 201: created
# {'_id': '72', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (73) triballands
# Adding Document: http://es:9200/triballands/geojson/73
# 	Result: 201: created
# {'_id': '73', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (74) triballands
# Adding Document: http://es:9200/triballands/geojson/74
# 	Result: 201: created
# {'_id': '74', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (75) triballands
# Adding Document: http://es:9200/triballands/geojson/75
# 	Result: 201: created
# {'_id': '75', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (76) triballands
# Adding Document: http://es:9200/triballands/geojson/76
# 	Result: 201: created
# {'_id': '76', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (77) triballands
# Adding Document: http://es:9200/triballands/geojson/77
# 	Result: 201: created
# {'_id': '77', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (78) triballands
# Adding Document: http://es:9200/triballands/geojson/78
# 	Result: 201: created
# {'_id': '78', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (79) triballands
# Adding Document: http://es:9200/triballands/geojson/79
# 	Result: 201: created
# {'_id': '79', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (80) triballands
# Adding Document: http://es:9200/triballands/geojson/80
# 	Result: 201: created
# {'_id': '80', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (81) triballands
# Adding Document: http://es:9200/triballands/geojson/81
# 	Result: 201: created
# {'_id': '81', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (82) triballands
# Adding Document: http://es:9200/triballands/geojson/82
# 	Result: 201: created
# {'_id': '82', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (83) triballands
# Adding Document: http://es:9200/triballands/geojson/83
# 	Result: 201: created
# {'_id': '83', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (84) triballands
# Adding Document: http://es:9200/triballands/geojson/84
# 	Result: 201: created
# {'_id': '84', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (85) triballands
# Adding Document: http://es:9200/triballands/geojson/85
# 	Result: 201: created
# {'_id': '85', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (86) triballands
# Adding Document: http://es:9200/triballands/geojson/86
# 	Result: 201: created
# {'_id': '86', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (87) triballands
# Adding Document: http://es:9200/triballands/geojson/87
# 	Result: 201: created
# {'_id': '87', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (88) triballands
# Adding Document: http://es:9200/triballands/geojson/88
# 	Result: 201: created
# {'_id': '88', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (89) triballands
# Adding Document: http://es:9200/triballands/geojson/89
# 	Result: 201: created
# {'_id': '89', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (90) triballands
# Adding Document: http://es:9200/triballands/geojson/90
# 	Result: 201: created
# {'_id': '90', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (91) triballands
# Adding Document: http://es:9200/triballands/geojson/91
# 	Result: 201: created
# {'_id': '91', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (92) triballands
# Adding Document: http://es:9200/triballands/geojson/92
# 	Result: 201: created
# {'_id': '92', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (93) triballands
# Adding Document: http://es:9200/triballands/geojson/93
# 	Result: 201: created
# {'_id': '93', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (94) triballands
# Adding Document: http://es:9200/triballands/geojson/94
# 	Result: 201: created
# {'_id': '94', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (95) triballands
# Adding Document: http://es:9200/triballands/geojson/95
# 	Result: 201: created
# {'_id': '95', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (96) triballands
# Adding Document: http://es:9200/triballands/geojson/96
# 	Result: 201: created
# {'_id': '96', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (97) triballands
# Adding Document: http://es:9200/triballands/geojson/97
# 	Result: 201: created
# {'_id': '97', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (98) triballands
# Adding Document: http://es:9200/triballands/geojson/98
# 	Result: 201: created
# {'_id': '98', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (99) triballands
# Adding Document: http://es:9200/triballands/geojson/99
# 	Result: 201: created
# {'_id': '99', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (100) triballands
# Adding Document: http://es:9200/triballands/geojson/100
# 	Result: 201: created
# {'_id': '100', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (101) triballands
# Adding Document: http://es:9200/triballands/geojson/101
# 	Result: 201: created
# {'_id': '101', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (102) triballands
# Adding Document: http://es:9200/triballands/geojson/102
# 	Result: 201: created
# {'_id': '102', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (103) triballands
# Adding Document: http://es:9200/triballands/geojson/103
# 	Result: 201: created
# {'_id': '103', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (104) triballands
# Adding Document: http://es:9200/triballands/geojson/104
# 	Result: 201: created
# {'_id': '104', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (105) triballands
# Adding Document: http://es:9200/triballands/geojson/105
# 	Result: 201: created
# {'_id': '105', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (106) triballands
# Adding Document: http://es:9200/triballands/geojson/106
# 	Result: 201: created
# {'_id': '106', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (107) triballands
# Adding Document: http://es:9200/triballands/geojson/107
# 	Result: 201: created
# {'_id': '107', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (108) triballands
# Adding Document: http://es:9200/triballands/geojson/108
# 	Result: 201: created
# {'_id': '108', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (109) triballands
# Adding Document: http://es:9200/triballands/geojson/109
# 	Result: 201: created
# {'_id': '109', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (110) triballands
# Adding Document: http://es:9200/triballands/geojson/110
# 	Result: 201: created
# {'_id': '110', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (111) triballands
# Adding Document: http://es:9200/triballands/geojson/111
# 	Result: 201: created
# {'_id': '111', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (112) triballands
# Adding Document: http://es:9200/triballands/geojson/112
# 	Result: 201: created
# {'_id': '112', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (113) triballands
# Adding Document: http://es:9200/triballands/geojson/113
# 	Result: 201: created
# {'_id': '113', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (114) triballands
# Adding Document: http://es:9200/triballands/geojson/114
# 	Result: 201: created
# {'_id': '114', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (115) triballands
# Adding Document: http://es:9200/triballands/geojson/115
# 	Result: 201: created
# {'_id': '115', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (116) triballands
# Adding Document: http://es:9200/triballands/geojson/116
# 	Result: 201: created
# {'_id': '116', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (117) triballands
# Adding Document: http://es:9200/triballands/geojson/117
# 	Result: 201: created
# {'_id': '117', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (118) triballands
# Adding Document: http://es:9200/triballands/geojson/118
# 	Result: 201: created
# {'_id': '118', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (119) triballands
# Adding Document: http://es:9200/triballands/geojson/119
# 	Result: 201: created
# {'_id': '119', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (120) triballands
# Adding Document: http://es:9200/triballands/geojson/120
# 	Result: 201: created
# {'_id': '120', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (121) triballands
# Adding Document: http://es:9200/triballands/geojson/121
# 	Result: 201: created
# {'_id': '121', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (122) triballands
# Adding Document: http://es:9200/triballands/geojson/122
# 	Result: 201: created
# {'_id': '122', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (123) triballands
# Adding Document: http://es:9200/triballands/geojson/123
# 	Result: 201: created
# {'_id': '123', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (124) triballands
# Adding Document: http://es:9200/triballands/geojson/124
# 	Result: 201: created
# {'_id': '124', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (125) triballands
# Adding Document: http://es:9200/triballands/geojson/125
# 	Result: 201: created
# {'_id': '125', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (126) triballands
# Adding Document: http://es:9200/triballands/geojson/126
# 	Result: 201: created
# {'_id': '126', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (127) triballands
# Adding Document: http://es:9200/triballands/geojson/127
# 	Result: 201: created
# {'_id': '127', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (128) triballands
# Adding Document: http://es:9200/triballands/geojson/128
# 	Result: 201: created
# {'_id': '128', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (129) triballands
# Adding Document: http://es:9200/triballands/geojson/129
# 	Result: 201: created
# {'_id': '129', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (130) triballands
# Adding Document: http://es:9200/triballands/geojson/130
# 	Result: 201: created
# {'_id': '130', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (131) triballands
# Adding Document: http://es:9200/triballands/geojson/131
# 	Result: 201: created
# {'_id': '131', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (132) triballands
# Adding Document: http://es:9200/triballands/geojson/132
# 	Result: 201: created
# {'_id': '132', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (133) triballands
# Adding Document: http://es:9200/triballands/geojson/133
# 	Result: 201: created
# {'_id': '133', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (134) triballands
# Adding Document: http://es:9200/triballands/geojson/134
# 	Result: 201: created
# {'_id': '134', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (135) triballands
# Adding Document: http://es:9200/triballands/geojson/135
# 	Result: 201: created
# {'_id': '135', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (136) triballands
# Adding Document: http://es:9200/triballands/geojson/136
# 	Result: 201: created
# {'_id': '136', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (137) triballands
# Adding Document: http://es:9200/triballands/geojson/137
# 	Result: 201: created
# {'_id': '137', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (138) triballands
# Adding Document: http://es:9200/triballands/geojson/138
# 	Result: 201: created
# {'_id': '138', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (139) triballands
# Adding Document: http://es:9200/triballands/geojson/139
# 	Result: 201: created
# {'_id': '139', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (140) triballands
# Adding Document: http://es:9200/triballands/geojson/140
# 	Result: 201: created
# {'_id': '140', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (141) triballands
# Adding Document: http://es:9200/triballands/geojson/141
# 	Result: 201: created
# {'_id': '141', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (142) triballands
# Adding Document: http://es:9200/triballands/geojson/142
# 	Result: 201: created
# {'_id': '142', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (143) triballands
# Adding Document: http://es:9200/triballands/geojson/143
# 	Result: 201: created
# {'_id': '143', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (144) triballands
# Adding Document: http://es:9200/triballands/geojson/144
# 	Result: 201: created
# {'_id': '144', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (145) triballands
# Adding Document: http://es:9200/triballands/geojson/145
# 	Result: 201: created
# {'_id': '145', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (146) triballands
# Adding Document: http://es:9200/triballands/geojson/146
# 	Result: 201: created
# {'_id': '146', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (147) triballands
# Adding Document: http://es:9200/triballands/geojson/147
# 	Result: 201: created
# {'_id': '147', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (148) triballands
# Adding Document: http://es:9200/triballands/geojson/148
# 	Result: 201: created
# {'_id': '148', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (149) triballands
# Adding Document: http://es:9200/triballands/geojson/149
# 	Result: 201: created
# {'_id': '149', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (150) triballands
# Adding Document: http://es:9200/triballands/geojson/150
# 	Result: 201: created
# {'_id': '150', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (151) triballands
# Adding Document: http://es:9200/triballands/geojson/151
# 	Result: 201: created
# {'_id': '151', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (152) triballands
# Adding Document: http://es:9200/triballands/geojson/152
# 	Result: 201: created
# {'_id': '152', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (153) triballands
# Adding Document: http://es:9200/triballands/geojson/153
# 	Result: 201: created
# {'_id': '153', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (154) triballands
# Adding Document: http://es:9200/triballands/geojson/154
# 	Result: 201: created
# {'_id': '154', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (155) triballands
# Adding Document: http://es:9200/triballands/geojson/155
# 	Result: 201: created
# {'_id': '155', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (156) triballands
# Adding Document: http://es:9200/triballands/geojson/156
# 	Result: 201: created
# {'_id': '156', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (157) triballands
# Adding Document: http://es:9200/triballands/geojson/157
# 	Result: 201: created
# {'_id': '157', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (158) triballands
# Adding Document: http://es:9200/triballands/geojson/158
# 	Result: 201: created
# {'_id': '158', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (159) triballands
# Adding Document: http://es:9200/triballands/geojson/159
# 	Result: 201: created
# {'_id': '159', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (160) triballands
# Adding Document: http://es:9200/triballands/geojson/160
# 	Result: 201: created
# {'_id': '160', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (161) triballands
# Adding Document: http://es:9200/triballands/geojson/161
# 	Result: 201: created
# {'_id': '161', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (162) triballands
# Adding Document: http://es:9200/triballands/geojson/162
# 	Result: 201: created
# {'_id': '162', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (163) triballands
# Adding Document: http://es:9200/triballands/geojson/163
# 	Result: 201: created
# {'_id': '163', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (164) triballands
# Adding Document: http://es:9200/triballands/geojson/164
# 	Result: 201: created
# {'_id': '164', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (165) triballands
# Adding Document: http://es:9200/triballands/geojson/165
# 	Result: 201: created
# {'_id': '165', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (166) triballands
# Adding Document: http://es:9200/triballands/geojson/166
# 	Result: 201: created
# {'_id': '166', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (167) triballands
# Adding Document: http://es:9200/triballands/geojson/167
# 	Result: 201: created
# {'_id': '167', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (168) triballands
# Adding Document: http://es:9200/triballands/geojson/168
# 	Result: 201: created
# {'_id': '168', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (169) triballands
# Adding Document: http://es:9200/triballands/geojson/169
# 	Result: 201: created
# {'_id': '169', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (170) triballands
# Adding Document: http://es:9200/triballands/geojson/170
# 	Result: 201: created
# {'_id': '170', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (171) triballands
# Adding Document: http://es:9200/triballands/geojson/171
# 	Result: 201: created
# {'_id': '171', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (172) triballands
# Adding Document: http://es:9200/triballands/geojson/172
# 	Result: 201: created
# {'_id': '172', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (173) triballands
# Adding Document: http://es:9200/triballands/geojson/173
# 	Result: 201: created
# {'_id': '173', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (174) triballands
# Adding Document: http://es:9200/triballands/geojson/174
# 	Result: 201: created
# {'_id': '174', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (175) triballands
# Adding Document: http://es:9200/triballands/geojson/175
# ...
# 	Result: 201: created
# {'_id': '495', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (496) triballands
# Adding Document: http://es:9200/triballands/geojson/496
# 	Result: 201: created
# {'_id': '496', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (497) triballands
# Adding Document: http://es:9200/triballands/geojson/497
# 	Result: 201: created
# {'_id': '497', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (498) triballands
# Adding Document: http://es:9200/triballands/geojson/498
# 	Result: 201: created
# {'_id': '498', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (499) triballands
# Adding Document: http://es:9200/triballands/geojson/499
# 	Result: 201: created
# {'_id': '499', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (500) triballands
# Adding Document: http://es:9200/triballands/geojson/500
# 	Result: 201: created
# {'_id': '500', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (501) triballands
# Adding Document: http://es:9200/triballands/geojson/501
# 	Result: 201: created
# {'_id': '501', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (502) triballands
# Adding Document: http://es:9200/triballands/geojson/502
# 	Result: 201: created
# {'_id': '502', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (503) triballands
# Adding Document: http://es:9200/triballands/geojson/503
# 	Result: 201: created
# {'_id': '503', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (504) triballands
# Adding Document: http://es:9200/triballands/geojson/504
# 	Result: 201: created
# {'_id': '504', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (505) triballands
# Adding Document: http://es:9200/triballands/geojson/505
# 	Result: 201: created
# {'_id': '505', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (506) triballands
# Adding Document: http://es:9200/triballands/geojson/506
# 	Result: 201: created
# {'_id': '506', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (507) triballands
# Adding Document: http://es:9200/triballands/geojson/507
# 	Result: 201: created
# {'_id': '507', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (508) triballands
# Adding Document: http://es:9200/triballands/geojson/508
# 	Result: 201: created
# {'_id': '508', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (509) triballands
# Adding Document: http://es:9200/triballands/geojson/509
# 	Result: 201: created
# {'_id': '509', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (510) triballands
# Adding Document: http://es:9200/triballands/geojson/510
# 	Result: 201: created
# {'_id': '510', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (511) triballands
# Adding Document: http://es:9200/triballands/geojson/511
# 	Result: 201: created
# {'_id': '511', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (512) triballands
# Adding Document: http://es:9200/triballands/geojson/512
# 	Result: 201: created
# {'_id': '512', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (513) triballands
# Adding Document: http://es:9200/triballands/geojson/513
# 	Result: 201: created
# {'_id': '513', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (514) triballands
# Adding Document: http://es:9200/triballands/geojson/514
# 	Result: 201: created
# {'_id': '514', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (515) triballands
# Adding Document: http://es:9200/triballands/geojson/515
# 	Result: 201: created
# {'_id': '515', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (516) triballands
# Adding Document: http://es:9200/triballands/geojson/516
# 	Result: 201: created
# {'_id': '516', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (517) triballands
# Adding Document: http://es:9200/triballands/geojson/517
# 	Result: 201: created
# {'_id': '517', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (518) triballands
# Adding Document: http://es:9200/triballands/geojson/518
# 	Result: 201: created
# {'_id': '518', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (519) triballands
# Adding Document: http://es:9200/triballands/geojson/519
# 	Result: 201: created
# {'_id': '519', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (520) triballands
# Adding Document: http://es:9200/triballands/geojson/520
# 	Result: 201: created
# {'_id': '520', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (521) triballands
# Adding Document: http://es:9200/triballands/geojson/521
# 	Result: 201: created
# {'_id': '521', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (522) triballands
# Adding Document: http://es:9200/triballands/geojson/522
# 	Result: 201: created
# {'_id': '522', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (523) triballands
# Adding Document: http://es:9200/triballands/geojson/523
# 	Result: 201: created
# {'_id': '523', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (524) triballands
# Adding Document: http://es:9200/triballands/geojson/524
# 	Result: 201: created
# {'_id': '524', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (525) triballands
# Adding Document: http://es:9200/triballands/geojson/525
# 	Result: 201: created
# {'_id': '525', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (526) triballands
# Adding Document: http://es:9200/triballands/geojson/526
# 	Result: 201: created
# {'_id': '526', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (527) triballands
# Adding Document: http://es:9200/triballands/geojson/527
# 	Result: 201: created
# {'_id': '527', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (528) triballands
# Adding Document: http://es:9200/triballands/geojson/528
# 	Result: 201: created
# {'_id': '528', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (529) triballands
# Adding Document: http://es:9200/triballands/geojson/529
# 	Result: 201: created
# {'_id': '529', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (530) triballands
# Adding Document: http://es:9200/triballands/geojson/530
# 	Result: 201: created
# {'_id': '530', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (531) triballands
# Adding Document: http://es:9200/triballands/geojson/531
# 	Result: 201: created
# {'_id': '531', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (532) triballands
# Adding Document: http://es:9200/triballands/geojson/532
# 	Result: 201: created
# {'_id': '532', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (533) triballands
# Adding Document: http://es:9200/triballands/geojson/533
# 	Result: 201: created
# {'_id': '533', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (534) triballands
# Adding Document: http://es:9200/triballands/geojson/534
# 	Result: 201: created
# {'_id': '534', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (535) triballands
# Adding Document: http://es:9200/triballands/geojson/535
# 	Result: 201: created
# {'_id': '535', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (536) triballands
# Adding Document: http://es:9200/triballands/geojson/536
# 	Result: 201: created
# {'_id': '536', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (537) triballands
# Adding Document: http://es:9200/triballands/geojson/537
# 	Result: 201: created
# {'_id': '537', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (538) triballands
# Adding Document: http://es:9200/triballands/geojson/538
# 	Result: 201: created
# {'_id': '538', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (539) triballands
# Adding Document: http://es:9200/triballands/geojson/539
# 	Result: 201: created
# {'_id': '539', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (540) triballands
# Adding Document: http://es:9200/triballands/geojson/540
# 	Result: 201: created
# {'_id': '540', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (541) triballands
# Adding Document: http://es:9200/triballands/geojson/541
# 	Result: 201: created
# {'_id': '541', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (542) triballands
# Adding Document: http://es:9200/triballands/geojson/542
# 	Result: 201: created
# {'_id': '542', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (543) triballands
# Adding Document: http://es:9200/triballands/geojson/543
# 	Result: 201: created
# {'_id': '543', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (544) triballands
# Adding Document: http://es:9200/triballands/geojson/544
# 	Result: 201: created
# {'_id': '544', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (545) triballands
# Adding Document: http://es:9200/triballands/geojson/545
# 	Result: 201: created
# {'_id': '545', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (546) triballands
# Adding Document: http://es:9200/triballands/geojson/546
# 	Result: 201: created
# {'_id': '546', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (547) triballands
# Adding Document: http://es:9200/triballands/geojson/547
# 	Result: 201: created
# {'_id': '547', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (548) triballands
# Adding Document: http://es:9200/triballands/geojson/548
# 	Result: 201: created
# {'_id': '548', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (549) triballands
# Adding Document: http://es:9200/triballands/geojson/549
# 	Result: 201: created
# {'_id': '549', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (550) triballands
# Adding Document: http://es:9200/triballands/geojson/550
# 	Result: 201: created
# {'_id': '550', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (551) triballands
# Adding Document: http://es:9200/triballands/geojson/551
# 	Result: 201: created
# {'_id': '551', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# Processing: (552) triballands
# Adding Document: http://es:9200/triballands/geojson/552
# 	Result: 201: created
# {'_id': '552', 'created': True, '_type': 'geojson', '_shards': {'failed': 0, 'successful': 1, 'total': 2}, '_version': 1, 'result': 'created', '_index': 'triballands'}
#
# skipping: usstates
