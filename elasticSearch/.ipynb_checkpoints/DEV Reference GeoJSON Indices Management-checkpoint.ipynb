# %%
import requests as rq
import json
import time

# %%
# Define some shared variables

# determines if the script will drop and recreate the indices for the indices that will be refreshed
dropIndices = True

# run a limited test
testMode = False
testCount = 5

# Elastic Search Host
esHost = "http://es:9200"

# define headers for requests
headers = {'Content-Type':'application/json'}


# Index Names, Sources, and mapping definitions
# Set 'refresh' to True for the indices that you want to rebuild
indexInfo = [
    {
        'refresh':True,
        'indexName':"watershedsdev", 
        'dataSource':"https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/wbdhu2_PR_1hundthDD.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/wbdhu2_PR_1hundthDD-mapping.json"
    },
    {
        'refresh':True,
        'indexName':"triballandsdev", 
        'dataSource':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/tl_2016_us_aiannh_Subset_.001_.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/tl_2016_us_aiannh_Subset_.001-mapping.json"
    },
    {
        'refresh':True,
        'indexName':"usstatesdev", 
        'dataSource':"https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/us_state_BS_5hundthDD.geojson",
        'mapping':"https://raw.githubusercontent.com/nawrs/nawrs/GeoJSON/JSON/ReferenceLayers/us_state_BS_5hundthDD-mapping.json"
    }
]

def writelog(logfileName,message):
    timestr = time.strftime("%Y%m%d-%H%M%S")
    with open(logfileName,"a") as f:
        f.write(timestr + ": "+ message + "\n")

# %%
# test to see if the host is responding
reqString = esHost
r = rq.get(reqString)
print(r.status_code)
print(r.json())
# Out:
# 200
# {'name': 'vhsgFJz', 'cluster_name': 'elasticsearch', 'cluster_uuid': '6c3Fi4HmSdKuhHf8GUgC0A', 'version': {'number': '5.1.1', 'build_hash': '5395e21', 'build_date': '2016-12-06T12:36:15.409Z', 'build_snapshot': False, 'lucene_version': '6.3.0'}, 'tagline': 'You Know, for Search'}

# %%
# Drop and Create the indices

if dropIndices:
    for index in indexInfo:
        if index['refresh']:
            requestURL = esHost+"/"+index['indexName']
            indexdevname = index['indexName'].replace('dev', '')
            indexMapping = rq.get(index['mapping']).json()[indexdevname]
            #print(indexMapping)

            print("Deleting index: "+requestURL)
            r = rq.delete(requestURL)
            print("\tStatus Code: "+str(r.status_code))

            #print("Creating index: "+requestURL)
            #r = rq.put(requestURL, headers=headers)
            #print("\tStatus Code: "+str(r.status_code)+": "+str(r.json()))

            print("Adding index and mapping: "+requestURL)
            r = rq.put(requestURL, headers=headers, data=json.dumps(indexMapping))
            print("\tStatus Code: "+str(r.status_code)+": "+str(r.json()))
else:
    print("Indices were retained")
# Out:
# Deleting index: http://localhost:9200/watershedsdev
# 	Status Code: 404
# Adding index and mapping: http://localhost:9200/watershedsdev
# 	Status Code: 200: {'acknowledged': True, 'shards_acknowledged': True}
# Deleting index: http://localhost:9200/triballandsdev
# 	Status Code: 404
# Adding index and mapping: http://localhost:9200/triballandsdev
# 	Status Code: 200: {'acknowledged': True, 'shards_acknowledged': True}
# Deleting index: http://localhost:9200/usstatesdev
# 	Status Code: 404
# Adding index and mapping: http://localhost:9200/usstatesdev
# 	Status Code: 200: {'acknowledged': True, 'shards_acknowledged': True}

# %%
# load a GeoJSON files for processing
timestr = time.strftime("%Y%m%d-%H%M%S")
logfileName = "logs/rebuildIndices_"+timestr+".txt"

for sourceFile in indexInfo:
    if sourceFile['refresh']:
        r = rq.get(sourceFile['dataSource'])
        workingGeoString = r.json() # r.text
        workingGeo = workingGeoString # json.loads(workingGeoString)
        docType = workingGeo['type']
        docCRS = workingGeo['crs']
        #print(workingGeo['features'][0].keys())

        i = 1
        for feature in workingGeo['features']:
            logMessage = ''
            writelog(logfileName,logMessage)
            logMessage = "Processing: ("+str(i)+") "+sourceFile['indexName']
            writelog(logfileName,logMessage)
            print(logMessage)

            docFeatureType = feature['type']
            docFeatureProperties = feature['properties']
            docFeatureGeometry = feature['geometry']

            builtDoc = '{"type":\"%s\","crs":%s,"features":{"type":\"%s\","properties":%s,"geometry":%s}}'%(docType,json.dumps(docCRS),docFeatureType,json.dumps(docFeatureProperties),json.dumps(docFeatureGeometry))
            #builtDoc = builtDoc.replace("\'",'*--*')
            #builtDoc = builtDoc.replace("'",'"')
            #builtDoc = builtDoc.replace("*--*","'")


            try:
                docJSON = json.loads(builtDoc)
            except:
                print("\tFailed to create the GeoJSON document")
                print("==========================================")
                print(builtDoc)
                print("==========================================")
                print()

            # put the document into the index
            requestURL = esHost+"/"+sourceFile['indexName']+"/geojson/"+str(i)
            logMessage = "Adding Document: "+requestURL
            writelog(logfileName,logMessage)
            print(logMessage)
            r = rq.post(requestURL, data=json.dumps(docJSON), headers=headers)
            try:
                resultText = str(r.json()['result'])
            except:
                resultText = "ERROR\n\n==========================" + builtDoc + "\n"

            logMessage = "\tResult: "+str(r.status_code)+": "+resultText + "\n" + str(r.json())
            writelog(logfileName,logMessage)
            print(logMessage)
            print()


            i += 1

            if testMode:
                if i > testCount: break
    else:
        print("skipping: "+sourceFile['indexName'])
# Out:
# Processing: (1) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/1
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (2) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/2
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (3) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/3
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (4) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/4
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (5) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/5
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (6) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/6
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (7) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/7
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (8) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/8
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (9) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/9
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (10) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/10
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (11) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/11
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (12) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/12
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (13) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/13
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (14) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/14
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (15) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson/15
# 	Result: 201: created
# {'_index': 'watershedsdev', '_type': 'geojson', '_id': '15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (16) watershedsdev
# Adding Document: http://localhost:9200/watershedsdev/geojson
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '77', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (78) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/78
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '78', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (79) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/79
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '79', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (80) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/80
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '80', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (81) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/81
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '81', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (82) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/82
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '82', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (83) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/83
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '83', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (84) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/84
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '84', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
# Processing: (85) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/85
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '85', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (86) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/86
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '86', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (87) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/87
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '87', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (88) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/88
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '88', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (89) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/89
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '89', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (90) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/90
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '90', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (91) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/91
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '91', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (92) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/92
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '92', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (93) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/93
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '93', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (94) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/94
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '94', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (95) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/95
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '95', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (96) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/96
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '96', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (97) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/97
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '97', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (98) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/98
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '98', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (99) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/99
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '99', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (100) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/100
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '100', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (101) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/101
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '101', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (102) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/102
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '102', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (103) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/103
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '103', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (104) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/104
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '104', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (105) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/105
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '105', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (106) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/106
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '106', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (107) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/107
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '107', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (108) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/108
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '108', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (109) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/109
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '109', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (110) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/110
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '110', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (111) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/111
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '111', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (112) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/112
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '112', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (113) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/113
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '113', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (114) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/114
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '114', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (115) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/115
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '115', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (116) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/116
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '116', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (117) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/117
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '117', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (118) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/118
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '118', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (119) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/119
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '119', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (120) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/120
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '120', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (121) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/121
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '121', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (122) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/122
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '122', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (123) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/123
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '123', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (124) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/124
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '124', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (125) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/125
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '125', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (126) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/126
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '126', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (127) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/127
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '127', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (128) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/128
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '128', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (129) triballandsdev
# Adding Document: http://localhost:9200/triballandsdev/geojson/129
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '129', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (130) triballandsdev
# ...
# Adding Document: http://localhost:9200/triballandsdev/geojson/552
# 	Result: 201: created
# {'_index': 'triballandsdev', '_type': 'geojson', '_id': '552', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (1) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/1
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (2) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/2
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (3) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/3
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (4) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/4
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (5) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/5
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (6) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/6
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (7) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/7
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (8) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/8
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (9) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/9
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (10) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/10
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (11) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/11
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (12) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/12
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (13) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/13
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (14) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/14
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (15) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/15
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (16) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/16
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '16', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (17) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/17
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '17', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (18) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/18
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '18', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (19) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/19
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '19', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (20) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/20
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '20', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (21) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/21
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '21', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (22) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/22
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '22', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (23) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/23
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '23', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (24) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/24
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '24', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (25) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/25
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '25', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (26) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/26
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '26', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (27) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/27
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '27', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (28) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/28
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '28', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (29) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/29
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '29', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (30) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/30
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '30', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (31) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/31
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '31', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (32) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/32
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '32', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (33) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/33
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '33', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (34) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/34
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '34', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (35) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/35
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '35', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (36) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/36
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '36', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (37) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/37
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '37', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (38) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/38
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '38', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (39) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/39
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '39', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (40) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/40
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '40', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (41) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/41
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '41', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (42) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/42
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '42', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (43) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/43
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '43', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (44) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/44
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '44', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (45) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/45
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '45', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (46) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/46
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '46', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (47) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/47
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '47', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (48) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/48
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '48', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (49) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/49
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '49', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (50) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/50
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '50', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (51) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/51
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '51', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (52) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/52
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '52', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (53) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/53
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '53', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (54) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/54
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '54', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (55) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/55
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '55', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
#
# Processing: (56) usstatesdev
# Adding Document: http://localhost:9200/usstatesdev/geojson/56
# 	Result: 201: created
# {'_index': 'usstatesdev', '_type': 'geojson', '_id': '56', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, 'created': True}
