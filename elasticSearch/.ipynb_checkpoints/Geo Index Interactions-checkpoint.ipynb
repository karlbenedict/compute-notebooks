# %%
import requests as rq
import json
import datetime

# %%
# Define some shared variables

# Elastic Search Host
esHost = "http://es:9200"

# Headers
headers = {'Content-Type': 'application/json'}

# Reference layers
usStates = "https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/us_state_BS_5hundthDD.geojson"
tribalLands = "https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/tl_2011_BS_5hundthDD.geojson"
watersheds = "https://github.com/nawrs/nawrs/raw/GeoJSON/JSON/ReferenceLayers/wbdhu2_PR_1hundthDD.geojson"
documents = ""

# Index Names and Sources
indexInfo = [
    {'indexName':"watersheds", 'dataSource':watersheds, 'typename':"geojson"},
    {'indexName':"triballands", 'dataSource':tribalLands, 'typename':"geojson"},
    {'indexName':"usstates", 'dataSource':usStates, 'typename':"geojson"},
    {'indexName':"nawrs", 'dataSource':documents, 'typeName':"item" }
]

# %%
# Get the mappings for the geo indices

for index in indexInfo:
    requestURL = esHost+"/"+index['indexName']+"/_mapping/geojson?pretty"
    print()
    print("Index mapping for: "+requestURL)
    r = rq.get(requestURL)
    print("\tResult: "+str(r.status_code))
    print(json.dumps(r.json(), sort_keys=True, indent=4))
# Out:
# Index mapping for: http://es:9200/watersheds/_mapping/geojson?pretty
# 	Result: 200
# {
#     "watersheds": {
#         "mappings": {
#             "geojson": {
#                 "properties": {
#                     "crs": {
#                         "properties": {
#                             "properties": {
#                                 "properties": {
#                                     "name": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "features": {
#                         "properties": {
#                             "geometry": {
#                                 "precision": "100.0m",
#                                 "strategy": "recursive",
#                                 "type": "geo_shape"
#                             },
#                             "properties": {
#                                 "properties": {
#                                     "AFFGEOID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "ALAND": {
#                                         "type": "float"
#                                     },
#                                     "AREAACRES": {
#                                         "type": "float"
#                                     },
#                                     "AREASQKM": {
#                                         "type": "float"
#                                     },
#                                     "AWATER": {
#                                         "type": "float"
#                                     },
#                                     "GEOID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "GNIS_ID": {
#                                         "type": "long"
#                                     },
#                                     "HUC2": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "LOADDATE": {
#                                         "format": "yyyy/MM/dd HH:mm:ss||yyyy/MM/dd||epoch_millis",
#                                         "type": "date"
#                                     },
#                                     "LSAD": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "METASOURCE": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "MaxSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "MinSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "NAME": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "OBJECTID": {
#                                         "type": "long"
#                                     },
#                                     "SOURCEDATA": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "SOURCEFEAT": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "SOURCEORIG": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STATEFP": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STATENS": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STATES": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STUSPS": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "Shape_Area": {
#                                         "type": "float"
#                                     },
#                                     "Shape_Leng": {
#                                         "type": "float"
#                                     },
#                                     "TNMID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "type": {
#                         "fields": {
#                             "keyword": {
#                                 "ignore_above": 256,
#                                 "type": "keyword"
#                             }
#                         },
#                         "type": "text"
#                     }
#                 }
#             }
#         }
#     }
# }
#
# Index mapping for: http://es:9200/triballands/_mapping/geojson?pretty
# 	Result: 200
# {
#     "triballands": {
#         "mappings": {
#             "geojson": {
#                 "properties": {
#                     "crs": {
#                         "properties": {
#                             "properties": {
#                                 "properties": {
#                                     "name": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "features": {
#                         "properties": {
#                             "geometry": {
#                                 "precision": "100.0m",
#                                 "strategy": "recursive",
#                                 "type": "geo_shape"
#                             },
#                             "properties": {
#                                 "properties": {
#                                     "AIANNHCE": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "AIANNHNS": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "AIANNHR": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "ALAND": {
#                                         "type": "float"
#                                     },
#                                     "AWATER": {
#                                         "type": "float"
#                                     },
#                                     "CLASSFP": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "COMPTYP": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "FUNCSTAT": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "GEOID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "INTPTLAT": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "INTPTLON": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "LSAD": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "MTFCC": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "MaxSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "MinSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "NAME": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "NAMELSAD": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "type": {
#                         "fields": {
#                             "keyword": {
#                                 "ignore_above": 256,
#                                 "type": "keyword"
#                             }
#                         },
#                         "type": "text"
#                     }
#                 }
#             }
#         }
#     }
# }
#
# Index mapping for: http://es:9200/usstates/_mapping/geojson?pretty
# 	Result: 200
# {
#     "usstates": {
#         "mappings": {
#             "geojson": {
#                 "properties": {
#                     "crs": {
#                         "properties": {
#                             "properties": {
#                                 "properties": {
#                                     "name": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "features": {
#                         "properties": {
#                             "geometry": {
#                                 "precision": "100.0m",
#                                 "strategy": "recursive",
#                                 "type": "geo_shape"
#                             },
#                             "properties": {
#                                 "properties": {
#                                     "AFFGEOID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "ALAND": {
#                                         "type": "float"
#                                     },
#                                     "AWATER": {
#                                         "type": "float"
#                                     },
#                                     "GEOID": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "LSAD": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "MaxSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "MinSimpTol": {
#                                         "type": "float"
#                                     },
#                                     "NAME": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STATEFP": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STATENS": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     },
#                                     "STUSPS": {
#                                         "fields": {
#                                             "keyword": {
#                                                 "ignore_above": 256,
#                                                 "type": "keyword"
#                                             }
#                                         },
#                                         "type": "text"
#                                     }
#                                 }
#                             },
#                             "type": {
#                                 "fields": {
#                                     "keyword": {
#                                         "ignore_above": 256,
#                                         "type": "keyword"
#                                     }
#                                 },
#                                 "type": "text"
#                             }
#                         }
#                     },
#                     "type": {
#                         "fields": {
#                             "keyword": {
#                                 "ignore_above": 256,
#                                 "type": "keyword"
#                             }
#                         },
#                         "type": "text"
#                     }
#                 }
#             }
#         }
#     }
# }
#
# Index mapping for: http://es:9200/nawrs/_mapping/geojson?pretty
# 	Result: 200
# {}

# %%
# Get the list of indices

requestURL = esHost+"/_all?pretty"
r=rq.get(requestURL)
print(r.text)
# Out:
# {
#   "usstates" : {
#     "aliases" : { },
#     "mappings" : {
#       "geojson" : {
#         "properties" : {
#           "crs" : {
#             "properties" : {
#               "properties" : {
#                 "properties" : {
#                   "name" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "features" : {
#             "properties" : {
#               "geometry" : {
#                 "type" : "geo_shape",
#                 "precision" : "100.0m",
#                 "strategy" : "recursive"
#               },
#               "properties" : {
#                 "properties" : {
#                   "AFFGEOID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "ALAND" : {
#                     "type" : "float"
#                   },
#                   "AWATER" : {
#                     "type" : "float"
#                   },
#                   "GEOID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "LSAD" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "MaxSimpTol" : {
#                     "type" : "float"
#                   },
#                   "MinSimpTol" : {
#                     "type" : "float"
#                   },
#                   "NAME" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STATEFP" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STATENS" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STUSPS" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "type" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           }
#         }
#       }
#     },
#     "settings" : {
#       "index" : {
#         "creation_date" : "1495726857807",
#         "number_of_shards" : "5",
#         "number_of_replicas" : "1",
#         "uuid" : "22ziNvMaTdy2NfMKcJnb0g",
#         "version" : {
#           "created" : "5010199"
#         },
#         "provided_name" : "usstates"
#       }
#     }
#   },
#   "watersheds" : {
#     "aliases" : { },
#     "mappings" : {
#       "geojson" : {
#         "properties" : {
#           "crs" : {
#             "properties" : {
#               "properties" : {
#                 "properties" : {
#                   "name" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "features" : {
#             "properties" : {
#               "geometry" : {
#                 "type" : "geo_shape",
#                 "precision" : "100.0m",
#                 "strategy" : "recursive"
#               },
#               "properties" : {
#                 "properties" : {
#                   "AFFGEOID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "ALAND" : {
#                     "type" : "float"
#                   },
#                   "AREAACRES" : {
#                     "type" : "float"
#                   },
#                   "AREASQKM" : {
#                     "type" : "float"
#                   },
#                   "AWATER" : {
#                     "type" : "float"
#                   },
#                   "GEOID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "GNIS_ID" : {
#                     "type" : "long"
#                   },
#                   "HUC2" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "LOADDATE" : {
#                     "type" : "date",
#                     "format" : "yyyy/MM/dd HH:mm:ss||yyyy/MM/dd||epoch_millis"
#                   },
#                   "LSAD" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "METASOURCE" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "MaxSimpTol" : {
#                     "type" : "float"
#                   },
#                   "MinSimpTol" : {
#                     "type" : "float"
#                   },
#                   "NAME" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "OBJECTID" : {
#                     "type" : "long"
#                   },
#                   "SOURCEDATA" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "SOURCEFEAT" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "SOURCEORIG" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STATEFP" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STATENS" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STATES" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "STUSPS" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "Shape_Area" : {
#                     "type" : "float"
#                   },
#                   "Shape_Leng" : {
#                     "type" : "float"
#                   },
#                   "TNMID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "type" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           }
#         }
#       }
#     },
#     "settings" : {
#       "index" : {
#         "creation_date" : "1495726857313",
#         "number_of_shards" : "5",
#         "number_of_replicas" : "1",
#         "uuid" : "Ag6gzBj-SAuKtvTKOKijwg",
#         "version" : {
#           "created" : "5010199"
#         },
#         "provided_name" : "watersheds"
#       }
#     }
#   },
#   "nawrs-test" : {
#     "aliases" : { },
#     "mappings" : {
#       "item" : {
#         "properties" : {
#           "centroid" : {
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "features" : {
#                 "properties" : {
#                   "geometry" : {
#                     "properties" : {
#                       "coordinates" : {
#                         "type" : "float"
#                       },
#                       "type" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "properties" : {
#                     "properties" : {
#                       "AIANNHCE" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHNS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHR" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "ALAND" : {
#                         "type" : "float"
#                       },
#                       "AWATER" : {
#                         "type" : "float"
#                       },
#                       "CLASSFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "COMPTYP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "FUNCSTAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLON" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "MTFCC" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "coverage" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "creator" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "date" : {
#             "type" : "date"
#           },
#           "description" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "identifier" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "polygon" : {
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "features" : {
#                 "properties" : {
#                   "geometry" : {
#                     "properties" : {
#                       "coordinates" : {
#                         "type" : "float"
#                       },
#                       "type" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "properties" : {
#                     "properties" : {
#                       "AIANNHCE" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHNS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHR" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "ALAND" : {
#                         "type" : "float"
#                       },
#                       "AWATER" : {
#                         "type" : "float"
#                       },
#                       "CLASSFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "COMPTYP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "FUNCSTAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLON" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "MTFCC" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "subject" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "title" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "type" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           }
#         }
#       }
#     },
#     "settings" : {
#       "index" : {
#         "creation_date" : "1493675843821",
#         "number_of_shards" : "5",
#         "number_of_replicas" : "1",
#         "uuid" : "soPs1R_2SpSX7xHlbtpjkQ",
#         "version" : {
#           "created" : "5010199"
#         },
#         "provided_name" : "nawrs-test"
#       }
#     }
#   },
#   "nawrs" : {
#     "aliases" : { },
#     "mappings" : {
#       "item" : {
#         "properties" : {
#           "centroid" : {
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "features" : {
#                 "properties" : {
#                   "geometry" : {
#                     "type" : "geo_shape"
#                   },
#                   "properties" : {
#                     "properties" : {
#                       "AFFGEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHCE" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHNS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHR" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "ALAND" : {
#                         "type" : "long"
#                       },
#                       "ALAND_1" : {
#                         "type" : "float"
#                       },
#                       "AWATER" : {
#                         "type" : "long"
#                       },
#                       "AWATER_1" : {
#                         "type" : "float"
#                       },
#                       "CLASSFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "COMPTYP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "FID_Arizon" : {
#                         "type" : "long"
#                       },
#                       "FID_Colora" : {
#                         "type" : "long"
#                       },
#                       "FID_DuckVa" : {
#                         "type" : "long"
#                       },
#                       "FID_Utes" : {
#                         "type" : "long"
#                       },
#                       "FID_ZuniH" : {
#                         "type" : "long"
#                       },
#                       "FID_nevada" : {
#                         "type" : "long"
#                       },
#                       "FUNCSTAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLON" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "MTFCC" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "OBJECTID" : {
#                         "type" : "long"
#                       },
#                       "STATEFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STATENS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STUSPS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "Shape_Area" : {
#                         "type" : "float"
#                       },
#                       "Shape_Leng" : {
#                         "type" : "float"
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "coverage" : {
#             "type" : "geo_point"
#           },
#           "creator" : {
#             "type" : "text"
#           },
#           "date" : {
#             "type" : "date"
#           },
#           "description" : {
#             "type" : "text"
#           },
#           "identifier" : {
#             "type" : "text"
#           },
#           "polygon" : {
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "features" : {
#                 "properties" : {
#                   "geometry" : {
#                     "type" : "geo_shape"
#                   },
#                   "properties" : {
#                     "properties" : {
#                       "AFFGEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHCE" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHNS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHR" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "ALAND" : {
#                         "type" : "long"
#                       },
#                       "ALAND_1" : {
#                         "type" : "float"
#                       },
#                       "AWATER" : {
#                         "type" : "long"
#                       },
#                       "AWATER_1" : {
#                         "type" : "float"
#                       },
#                       "CLASSFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "COMPTYP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "FID_Arizon" : {
#                         "type" : "long"
#                       },
#                       "FID_Colora" : {
#                         "type" : "long"
#                       },
#                       "FID_DuckVa" : {
#                         "type" : "long"
#                       },
#                       "FID_Utes" : {
#                         "type" : "long"
#                       },
#                       "FID_ZuniH" : {
#                         "type" : "long"
#                       },
#                       "FID_nevada" : {
#                         "type" : "long"
#                       },
#                       "FUNCSTAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLON" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "MTFCC" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME_1" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "OBJECTID" : {
#                         "type" : "long"
#                       },
#                       "STATEFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STATENS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STUSPS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "Shape_Area" : {
#                         "type" : "float"
#                       },
#                       "Shape_Leng" : {
#                         "type" : "float"
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "subject" : {
#             "type" : "text",
#             "fielddata" : true
#           },
#           "title" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           },
#           "type" : {
#             "type" : "text",
#             "fielddata" : true
#           }
#         }
#       },
#       "referencelayers" : {
#         "properties" : {
#           "boundary" : {
#             "type" : "nested",
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
# ...
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "OBJECTID" : {
#                         "type" : "long"
#                       },
#                       "STATEFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STATENS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STATES" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "STUSPS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "Shape_Area" : {
#                         "type" : "float"
#                       },
#                       "Shape_Leng" : {
#                         "type" : "float"
#                       },
#                       "TNMID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "hold" : {
#             "type" : "text"
#           }
#         }
#       },
#       "tribalboundaries" : {
#         "properties" : {
#           "boundary" : {
#             "type" : "nested",
#             "properties" : {
#               "crs" : {
#                 "properties" : {
#                   "properties" : {
#                     "properties" : {
#                       "name" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "features" : {
#                 "properties" : {
#                   "geometry" : {
#                     "type" : "geo_shape"
#                   },
#                   "properties" : {
#                     "properties" : {
#                       "AIANNHCE" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHNS" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "AIANNHR" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "ALAND" : {
#                         "type" : "float"
#                       },
#                       "AWATER" : {
#                         "type" : "float"
#                       },
#                       "CLASSFP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "COMPTYP" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "FUNCSTAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "GEOID" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLAT" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "INTPTLON" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "LSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "MTFCC" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAME" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       },
#                       "NAMELSAD" : {
#                         "type" : "text",
#                         "fields" : {
#                           "keyword" : {
#                             "type" : "keyword",
#                             "ignore_above" : 256
#                           }
#                         }
#                       }
#                     }
#                   },
#                   "type" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "hold" : {
#             "type" : "text"
#           }
#         }
#       }
#     },
#     "settings" : {
#       "index" : {
#         "creation_date" : "1482264492269",
#         "number_of_shards" : "5",
#         "number_of_replicas" : "1",
#         "uuid" : "cb1By4kcTaG003T-g0GAhg",
#         "version" : {
#           "created" : "5010199"
#         },
#         "provided_name" : "nawrs"
#       }
#     }
#   },
#   "triballands" : {
#     "aliases" : { },
#     "mappings" : {
#       "geojson" : {
#         "properties" : {
#           "crs" : {
#             "properties" : {
#               "properties" : {
#                 "properties" : {
#                   "name" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "features" : {
#             "properties" : {
#               "geometry" : {
#                 "type" : "geo_shape",
#                 "precision" : "100.0m",
#                 "strategy" : "recursive"
#               },
#               "properties" : {
#                 "properties" : {
#                   "AIANNHCE" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "AIANNHNS" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "AIANNHR" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "ALAND" : {
#                     "type" : "float"
#                   },
#                   "AWATER" : {
#                     "type" : "float"
#                   },
#                   "CLASSFP" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "COMPTYP" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "FUNCSTAT" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "GEOID" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "INTPTLAT" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "INTPTLON" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "LSAD" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "MTFCC" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "MaxSimpTol" : {
#                     "type" : "float"
#                   },
#                   "MinSimpTol" : {
#                     "type" : "float"
#                   },
#                   "NAME" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   },
#                   "NAMELSAD" : {
#                     "type" : "text",
#                     "fields" : {
#                       "keyword" : {
#                         "type" : "keyword",
#                         "ignore_above" : 256
#                       }
#                     }
#                   }
#                 }
#               },
#               "type" : {
#                 "type" : "text",
#                 "fields" : {
#                   "keyword" : {
#                     "type" : "keyword",
#                     "ignore_above" : 256
#                   }
#                 }
#               }
#             }
#           },
#           "type" : {
#             "type" : "text",
#             "fields" : {
#               "keyword" : {
#                 "type" : "keyword",
#                 "ignore_above" : 256
#               }
#             }
#           }
#         }
#       }
#     },
#     "settings" : {
#       "index" : {
#         "creation_date" : "1495726857554",
#         "number_of_shards" : "5",
#         "number_of_replicas" : "1",
#         "uuid" : "Hg0ISKWCSkKweCkM0CFGDg",
#         "version" : {
#           "created" : "5010199"
#         },
#         "provided_name" : "triballands"
#       }
#     }
#   }
# }

# %%
# Query and related indexed geo-shape search

index = "watersheds"
indexType = "geojson"
searchString = "Pacific"
fieldList = ["NAME"]

requestURL = esHost+"/"+index+"/"+indexType+"/_search"

print()
print(requestURL)

query = {
    "_source": "features.properties.NAME",
    "query"   : {
        "query_string": {
            "query"     : searchString
        }
    }
}

queryJSON = json.dumps(query)

print("\nQuery:")
print(queryJSON)

r=rq.get(requestURL, data=queryJSON, headers=headers)
hits = r.json()['hits']['hits']

#print(hits)

ids = []
for hit in hits:
    print('\nReturned Item:')
    print(hit)
    ids.append(hit['_id'])
print('\nItem IDs for index spatial searching:')
print(ids)
# Out:
# http://es:9200/watersheds/geojson/_search
#
# Query:
# {"_source": "features.properties.NAME", "query": {"query_string": {"query": "Pacific"}}}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'South Pacific Region'}}}, '_type': 'geojson', '_score': 1.4612197, '_id': '9', '_index': 'watersheds'}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Pacific Northwest Region'}}}, '_type': 'geojson', '_score': 1.34949, '_id': '4', '_index': 'watersheds'}
#
# Item IDs for index spatial searching:
# ['9', '4']

# %%
# Sequential Search with keyword followed by geometry based search based on keyword results

#startTime = datetime.

# Documents to be searched
docIndex = "nawrs"
docIndexType = "item"
docSearchString = "navajo"
docReturnFields = ["polygon.features.properties.NAME"]
docGeometryField = "polygon.features.geometry"

# Geometries to be searched using the document geometries
refIndex = "watersheds"
refIndexType = "geojson"
refReturnField = ["features.properties.NAME"]

#################################
## search for matching documents
requestURL = esHost+"/"+docIndex+"/"+docIndexType+"/_search"

print('\nRequest URL:')
print(requestURL)

query = {
    "_source": docReturnFields,
    "query"   : {
        "query_string": {
            "query"     : docSearchString
        }
    }
}

queryJSON = json.dumps(query)

print("\nQuery:")
print(queryJSON)

r=rq.get(requestURL, data=queryJSON, headers=headers)
hits = r.json()['hits']['hits']

#print(hits)

docIDs = []
for hit in hits:
    print('\nReturned Item:')
    print(hit)
    docIDs.append(hit['_id'])
print('\nItem IDs for index spatial searching:')
print(docIDs)


#########################################################################################
## search for reference geometries (returning document IDs) using IDs of found documents

geoQueryElements = []
for docID in docIDs:
    geoQueryElement = {
        "geo_shape": {
            "features.geometry": {
                "indexed_shape": {
                    "id": docID,
                    "type": docIndexType,
                    "index": docIndex,
                    "path": docGeometryField
                }
            }
        }
    }
    geoQueryElements.append(geoQueryElement)
    
spatialQuery = {
    "_source": refReturnField,
    "query": {
        "bool": {
            "should": geoQueryElements            
        }
    }
}

queryJSON = json.dumps(spatialQuery)

print("\nQuery:")
print(queryJSON)

requestURL = esHost+"/"+refIndex+"/"+refIndexType+"/_search"
r=rq.get(requestURL, data=queryJSON, headers=headers)
hits = r.json()['hits']['hits']
#print(hits)

refIDs = []
for hit in hits:
    print('\nReturned Item:')
    print(hit)
    refIDs.append(hit['_id'])
print('\nItem IDs for reference features ('+refIndex+') that match spatial search:')
print(refIDs)
# Out:
# Request URL:
# http://es:9200/nawrs/item/_search
#
# Query:
# {"_source": ["polygon.features.properties.NAME"], "query": {"query_string": {"query": "tribal"}}}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Fort Hall'}}]}}, '_type': 'item', '_score': 6.052186, '_id': 'AVsMkv5ZQe97V9ADs9zX', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Warm Springs'}}]}}, '_type': 'item', '_score': 4.219487, '_id': 'AVsMmQ2tQe97V9ADs9zk', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Fort Peck'}}]}}, '_type': 'item', '_score': 3.416521, '_id': 'AVsMknuTQe97V9ADs9zW', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Fort Hall'}}]}}, '_type': 'item', '_score': 2.8443482, '_id': 'AVsMk9T2Qe97V9ADs9zZ', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Colorado'}}]}}, '_type': 'item', '_score': 2.644789, '_id': 'AVsMlLZ7Qe97V9ADs9zb', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Fallon Paiute-Shoshone'}}]}}, '_type': 'item', '_score': 2.0913455, '_id': 'AVkeWQA0bTu-_lwLAcFc', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Crow'}}]}}, '_type': 'item', '_score': 1.8193369, '_id': 'AVsMo_2jQe97V9ADs9z1', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Arizona'}}]}}, '_type': 'item', '_score': 1.6143396, '_id': 'AVsMgOeZQe97V9ADs9y6', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Colorado'}}]}}, '_type': 'item', '_score': 1.5477221, '_id': 'AVsMlYWbQe97V9ADs9zd', '_index': 'nawrs'}
#
# Returned Item:
# {'_source': {'polygon': {'features': [{'properties': {'NAME': 'Fort Hall'}}]}}, '_type': 'item', '_score': 1.2061208, '_id': 'AVsMk1_2Qe97V9ADs9zY', '_index': 'nawrs'}
#
# Item IDs for index spatial searching:
# ['AVsMkv5ZQe97V9ADs9zX', 'AVsMmQ2tQe97V9ADs9zk', 'AVsMknuTQe97V9ADs9zW', 'AVsMk9T2Qe97V9ADs9zZ', 'AVsMlLZ7Qe97V9ADs9zb', 'AVkeWQA0bTu-_lwLAcFc', 'AVsMo_2jQe97V9ADs9z1', 'AVsMgOeZQe97V9ADs9y6', 'AVsMlYWbQe97V9ADs9zd', 'AVsMk1_2Qe97V9ADs9zY']
#
# Query:
# {"_source": ["features.properties.NAME"], "size": 100, "query": {"bool": {"should": [{"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMkv5ZQe97V9ADs9zX", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMmQ2tQe97V9ADs9zk", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMknuTQe97V9ADs9zW", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMk9T2Qe97V9ADs9zZ", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMlLZ7Qe97V9ADs9zb", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVkeWQA0bTu-_lwLAcFc", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMo_2jQe97V9ADs9z1", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMgOeZQe97V9ADs9y6", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMlYWbQe97V9ADs9zd", "path": "polygon.features.geometry"}}}}, {"geo_shape": {"features.geometry": {"indexed_shape": {"index": "nawrs", "type": "item", "id": "AVsMk1_2Qe97V9ADs9zY", "path": "polygon.features.geometry"}}}}]}}}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Pacific Northwest Region'}}}, '_type': 'geojson', '_score': 4.0, '_id': '4', '_index': 'watersheds'}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Missouri Region'}}}, '_type': 'geojson', '_score': 2.0, '_id': '21', '_index': 'watersheds'}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Upper Colorado Region'}}}, '_type': 'geojson', '_score': 2.0, '_id': '11', '_index': 'watersheds'}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Great Basin Region'}}}, '_type': 'geojson', '_score': 1.0, '_id': '14', '_index': 'watersheds'}
#
# Returned Item:
# {'_source': {'features': {'properties': {'NAME': 'Lower Colorado Region'}}}, '_type': 'geojson', '_score': 1.0, '_id': '12', '_index': 'watersheds'}
#
# Item IDs for reference features (watersheds) that match spatial search:
# ['4', '21', '11', '14', '12']
