# %% [markdown]
# Testing of the publicly accessible API for the production ORCID system
#
# API 2.0 reference (in GitHub): https://github.com/ORCID/ORCID-Source/tree/master/orcid-model/src/main/resources/record_2.0

# %%
import requests
import json
import datetime
import pandas

# %%
# Define variables for use throughout
publicTokenResponse= {"access_token":"4a587e47-b564-412b-81a5-175ed8a92fed","token_type":"bearer","refresh_token":"236ddbf7-867f-42cc-9e08-af32526c1ba3","expires_in":631138518,"scope":"/read-public","orcid":"null"}
publicToken = publicTokenResponse["access_token"]

host = "pub.orcid.org" #member API in sandbox
headers = {"Accept":"application/json", "Authorization":"Bearer %s"%(publicToken)}


# define some extraction functions for ORCID results
def getEmployment(orcidID):
    reqString = "https://%s/v2.0/%s/employments"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers )
    return(reqGet.json())

def getPerson(orcidID):
    reqString = "https://%s/v2.0/%s/person"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

def getPersonalDetails(orcidID):
    reqString = "https://%s/v2.0/%s/personal-details"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

def fullRecord(orcidID):
    reqString = "https://%s/v2.0/%s/record"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

# %%
# public production API testing with Karl's token/credentials

query = "affiliation-org-name:'University+of+New+Mexico'"
headers = {"Accept":"application/json", "Authorization":"Bearer %s"%(publicToken)}

records = 200

resultList = []

for i in range(2):
    start = i * records
    baseURL = "https://%s/v2.0/search?q=%s&rows=%s&start=%s"%(host,query,records,start)

    reqGet = requests.get(baseURL, headers=headers )
    reqGet.json()['result']

    print(json.dumps(reqGet.json()))

    j = 0
    for resultItem in reqGet.json()['result']:
        returnDict = {}
        returnDict['orcidID'] = resultItem['orcid-identifier']['path']

        # get the person's name
        result = getPersonalDetails(returnDict['orcidID'])

        try:
            returnDict['familyName'] = result['name']['family-name']['value']
        except:
            returnDict['familyName'] = "ERROR"

        try:
            returnDict['givenNames'] = result['name']['given-names']['value']
        except:
            returnDict['givenNames'] = "ERROR"

        try:
            returnDict['creditName'] = result['name']['credit-name']['value']
        except:
            returnDict['creditName'] = "ERROR"





        # get the person's employment information
        result = getEmployment(returnDict['orcidID'])

        employmentList = []
        for employmentItem in result['employment-summary']:
            employmentRecord = {}
            # print(json.dumps(employmentItem, indent=4, sort_keys=True))

            try:
                employmentRecord['department_name'] = employmentItem['department-name']
            except:
                employmentRecord['department_name'] = "ERROR"

            try:
                employmentRecord['start_date'] = {'year':employmentItem['start-date']['year']['value'], 'month':employmentItem['start-date']['month']['value'],'day':employmentItem['start-date']['day']['value']}
            except:
                employmentRecord['start_date'] = {}

            try:
                employmentRecord['end_date'] = {'year':employmentItem['end-date']['year']['value'], 'month':employmentItem['end-date']['month']['value'],'day':employmentItem['end-date']['day']['value']}
            except:
                employmentRecord['end_date'] = {}

            try:
                employmentRecord['role_title'] = employmentItem['role-title']
            except:
                employmentRecord['role_title'] = "ERROR"

            try:
                employmentRecord['organization'] = employmentItem['organization']['name']
            except:
                employmentRecord['organization'] = "ERROR"

            try:
                employmentRecord['address_city'] = employmentItem['organization']['address']['city']
            except:
                employmentRecord['address_city'] = "ERROR"

            try:
                employmentRecord['address_region'] = employmentItem['organization']['address']['region']
            except:
                employmentRecord['address_region'] = "ERROR"

            try:
                employmentRecord['address_country'] = employmentItem['organization']['address']['country']
            except:
                employmentRecord['address_country'] = "ERROR"

            employmentList.append(employmentRecord)


        returnDict['employment'] = employmentList



        resultList.append(returnDict)

        #j += 1
        #if j > 10: break

#for item in resultList:
#    print(json.dumps(item, indent=4, sort_keys=True))
# Out:
# {"num-found": 991418, "result": [{"orcid-identifier": {"path": "0000-0001-7886-638X", "uri": "http://orcid.org/0000-0001-7886-638X", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-6740-4590", "uri": "http://orcid.org/0000-0002-6740-4590", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3104-4447", "uri": "http://orcid.org/0000-0003-3104-4447", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-4415-3573", "uri": "http://orcid.org/0000-0002-4415-3573", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-0918-9041", "uri": "http://orcid.org/0000-0003-0918-9041", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-4047-3411", "uri": "http://orcid.org/0000-0003-4047-3411", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-7462-1609", "uri": "http://orcid.org/0000-0001-7462-1609", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-4040-9874", "uri": "http://orcid.org/0000-0003-4040-9874", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-8425-4686", "uri": "http://orcid.org/0000-0002-8425-4686", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-0689-3546", "uri": "http://orcid.org/0000-0002-0689-3546", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-0537-7558", "uri": "http://orcid.org/0000-0002-0537-7558", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3302-4546", "uri": "http://orcid.org/0000-0003-3302-4546", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9021-2845", "uri": "http://orcid.org/0000-0002-9021-2845", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-9353-5052", "uri": "http://orcid.org/0000-0001-9353-5052", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-6702-4264", "uri": "http://orcid.org/0000-0002-6702-4264", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-8113-8380", "uri": "http://orcid.org/0000-0002-8113-8380", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-1056-9466", "uri": "http://orcid.org/0000-0002-1056-9466", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-2107-9355", "uri": "http://orcid.org/0000-0003-2107-9355", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-7079-1117", "uri": "http://orcid.org/0000-0001-7079-1117", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-1572-9756", "uri": "http://orcid.org/0000-0002-1572-9756", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-8186-4350", "uri": "http://orcid.org/0000-0001-8186-4350", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-5934-2791", "uri": "http://orcid.org/0000-0001-5934-2791", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-2375-2198", "uri": "http://orcid.org/0000-0002-2375-2198", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-2460-8478", "uri": "http://orcid.org/0000-0003-2460-8478", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3811-1518", "uri": "http://orcid.org/0000-0003-3811-1518", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-4077-0184", "uri": "http://orcid.org/0000-0003-4077-0184", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3217-3486", "uri": "http://orcid.org/0000-0003-3217-3486", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9614-1769", "uri": "http://orcid.org/0000-0002-9614-1769", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-8716-2069", "uri": "http://orcid.org/0000-0001-8716-2069", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-1921-604X", "uri": "http://orcid.org/0000-0003-1921-604X", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-9305-5470", "uri": "http://orcid.org/0000-0001-9305-5470", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-0094-3784", "uri": "http://orcid.org/0000-0002-0094-3784", "host": "orcid.org"}}, {"orcid-identifier": {"path": " ...
# {"num-found": 991419, "result": [{"orcid-identifier": {"path": "0000-0001-9409-0067", "uri": "http://orcid.org/0000-0001-9409-0067", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-8774-582X", "uri": "http://orcid.org/0000-0001-8774-582X", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-6060-2199", "uri": "http://orcid.org/0000-0002-6060-2199", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-8106-9477", "uri": "http://orcid.org/0000-0002-8106-9477", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-3192-6434", "uri": "http://orcid.org/0000-0002-3192-6434", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-7131-3747", "uri": "http://orcid.org/0000-0002-7131-3747", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9109-2072", "uri": "http://orcid.org/0000-0002-9109-2072", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-3548-8726", "uri": "http://orcid.org/0000-0002-3548-8726", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-4846-2645", "uri": "http://orcid.org/0000-0003-4846-2645", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-1557-4790", "uri": "http://orcid.org/0000-0002-1557-4790", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3701-3430", "uri": "http://orcid.org/0000-0003-3701-3430", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-8951-7289", "uri": "http://orcid.org/0000-0002-8951-7289", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-7881-8131", "uri": "http://orcid.org/0000-0002-7881-8131", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-9955-0616", "uri": "http://orcid.org/0000-0001-9955-0616", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-3348-5932", "uri": "http://orcid.org/0000-0003-3348-5932", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-0566-4012", "uri": "http://orcid.org/0000-0002-0566-4012", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-0515-6613", "uri": "http://orcid.org/0000-0003-0515-6613", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-9065-7767", "uri": "http://orcid.org/0000-0001-9065-7767", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-0698-2343", "uri": "http://orcid.org/0000-0003-0698-2343", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9834-8296", "uri": "http://orcid.org/0000-0002-9834-8296", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9949-5407", "uri": "http://orcid.org/0000-0002-9949-5407", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-9421-5138", "uri": "http://orcid.org/0000-0002-9421-5138", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-1164-7566", "uri": "http://orcid.org/0000-0003-1164-7566", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0003-1575-1555", "uri": "http://orcid.org/0000-0003-1575-1555", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-2140-9759", "uri": "http://orcid.org/0000-0002-2140-9759", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-7343-0939", "uri": "http://orcid.org/0000-0002-7343-0939", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-7067-8859", "uri": "http://orcid.org/0000-0002-7067-8859", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-8295-550X", "uri": "http://orcid.org/0000-0002-8295-550X", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-4595-0953", "uri": "http://orcid.org/0000-0002-4595-0953", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-5350-0816", "uri": "http://orcid.org/0000-0001-5350-0816", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0001-9951-2222", "uri": "http://orcid.org/0000-0001-9951-2222", "host": "orcid.org"}}, {"orcid-identifier": {"path": "0000-0002-3764-0381", "uri": "http://orcid.org/0000-0002-3764-0381", "host": "orcid.org"}}, {"orcid-identifier": {"path": " ...

# %%
# flatten the resultList into a dict

flatList = []

for person in resultList:
    returnDict = {}
    #for empolyment in person['employment']:
    returnDict['familyName'] = person['familyName']
    returnDict['givenNames'] = person['givenNames']
    returnDict['creditName'] = person['creditName']
    returnDict['orcidID'] = person['orcidID']
    
    for employment in person['employment']:
        returnDict['organization'] = employment['organization']
        returnDict['department_name'] = employment['department_name']


    
        flatList.append(returnDict)




goodLuck = pandas.DataFrame(flatList)

# %%
print(goodLuck)
# Out:
#              creditName                                    department_name  \
# 0                 ERROR                         Mathematics and Statistics
# 1                 ERROR                                 Clinical Education
# 2                 ERROR                                        Archaeology
# 3                 ERROR                                        Archaeology
# 4                 ERROR                                      Cancer Center
# 5                 ERROR                                      Cancer Center
# 6                 ERROR                                      Cancer Center
# 7                 ERROR                                      Cancer Center
# 8                 ERROR                        Family and Consumer Science
# 9                 ERROR                                            Biology
# 10                ERROR                                 College of Nursing
# 11                ERROR                                 College of Nursing
# 12                ERROR                                 College of Nursing
# 13                ERROR                     Department of Computer Science
# 14                ERROR                                               None
# 15                ERROR                                               None
# 16                ERROR                    New Mexico Water Science Center
# 17                ERROR                              Physics and Astronomy
# 18                ERROR                              Physics and Astronomy
# 19                ERROR                              Physics and Astronomy
# 20                ERROR           Nanoscience and Microsystems Engineering
# 21                ERROR           Nanoscience and Microsystems Engineering
# 22                ERROR  Pharmacoeconomics, Epidemiology, Pharmaceutica...
# 23                ERROR  CCS-2: Computer, Computational, and Statistica...
# 24                ERROR  CCS-2: Computer, Computational, and Statistica...
# 25                ERROR  CCS-2: Computer, Computational, and Statistica...
# 26                ERROR                                            Biology
# 27                ERROR          National Center for Disaster Preparedness
# 28                ERROR                          Communication Engineering
# 29                ERROR      language, literacy, and Sociocultural Studies
# ..                  ...                                                ...
# 474               ERROR                                          Chemistry
# 475               ERROR                      Horticulture and Crop Science
# 476               ERROR                      Horticulture and Crop Science
# 477               ERROR                                       Neuroscience
# 478               ERROR                                       Neuroscience
# 479               ERROR                                       Neuroscience
# 480               ERROR                                       Neuroscience
# 481               ERROR                                            Biology
# 482               ERROR                                               None
# 483               ERROR                                               None
# 484               ERROR                                            Physics
# 485               ERROR                                            Physics
# 486               ERROR                                            Physics
# 487               ERROR                                            Physics
# 488  Timothy R Petersen                                       Anthropology
# 489  Timothy R Petersen                                       Anthropology
# 490               ERROR                               Chemical Engineering
# 491               ERROR                               Chemical Engineering
# 492               ERROR                               Chemical Engineering
# 493               ERROR  International and Area Studies & Modern Langua...
# 494               ERROR  International and Area Studies & Modern Langua...
# 495               ERROR                     I. H. Asper School of Business
# 496               ERROR                Geography and Environmental Studies
# 497               ERROR                                Geological Sciences
# 498               ERROR                                Biological Sciences
# 499               ERROR                   Psychological and Brain Sciences
# 500               ERROR                   Psychological and Brain Sciences
# 501               ERROR                            School of Communication
# 502               ERROR                            School of Communication
# 503               ERROR                  Graduate School of Energy Science
#
#            familyName     givenNames              orcidID  \
# 0              Degnan       James H.  0000-0001-7886-638X
# 1              Melada         Samuel  0000-0002-6740-4590
# 2               Combs         Angela  0000-0003-3104-4447
# 3               Combs         Angela  0000-0003-3104-4447
# 4                Kang        Huining  0000-0002-4415-3573
# 5                Kang        Huining  0000-0002-4415-3573
# 6                Kang        Huining  0000-0002-4415-3573
# 7                Kang        Huining  0000-0002-4415-3573
# 8               Marin       Merranda  0000-0003-0918-9041
# 9           Washburne           Alex  0000-0003-4047-3411
# 10              cohen          sally  0000-0001-7462-1609
# 11              cohen          sally  0000-0001-7462-1609
# 12              cohen          sally  0000-0001-7462-1609
# 13                 Lu             Qi  0000-0002-8425-4686
# 14              ERROR        Mohamed  0000-0002-0689-3546
# 15               Wang        Zhuoyao  0000-0002-0537-7558
# 16           Mitchell        Aurelia  0000-0003-3302-4546
# 17         Obenberger        Kenneth  0000-0002-6702-4264
# 18         Obenberger        Kenneth  0000-0002-6702-4264
# 19         Obenberger        Kenneth  0000-0002-6702-4264
# 20             Dorsey       Jonathan  0000-0002-8113-8380
# 21             Dorsey       Jonathan  0000-0002-8113-8380
# 22             Kharat         Akshay  0000-0002-1056-9466
# 23           O'Rourke        Patrick  0000-0003-2107-9355
# 24           O'Rourke        Patrick  0000-0003-2107-9355
# 25           O'Rourke        Patrick  0000-0003-2107-9355
# 26           Thibault          James  0000-0001-7079-1117
# 27           Chandler         Thomas  0000-0001-8186-4350
# 28              hasan           omar  0000-0001-5934-2791
# 29             Haridy     Abdelbaset  0000-0002-2375-2198
# ..                ...            ...                  ...
# 474              Enke       Christie  0000-0002-3607-0356
# 475  Mohseni-Moghadam         Mohsen  0000-0002-1562-5404
# 476  Mohseni-Moghadam         Mohsen  0000-0002-1562-5404
# 477          Janowich     Jacqueline  0000-0003-3443-589X
# 478          Janowich     Jacqueline  0000-0003-3443-589X
# 479          Janowich     Jacqueline  0000-0003-3443-589X
# 480          Janowich     Jacqueline  0000-0003-3443-589X
# 481         Baymiller        Maxwell  0000-0003-2438-243X
# 482             BROWN         ESTHER  0000-0003-2824-8887
# 483           KLINGER           ERIC  0000-0001-8390-2680
# 484            Prager          Henry  0000-0002-0658-6175
# 485            Prager          Henry  0000-0002-0658-6175
# 486            Prager          Henry  0000-0002-0658-6175
# 487            Prager          Henry  0000-0002-0658-6175
# 488          Petersen        Timothy  0000-0002-2483-5614
# 489          Petersen        Timothy  0000-0002-2483-5614
# 490             Reddy  Harvind Kumar  0000-0001-8373-8577
# 491             Reddy  Harvind Kumar  0000-0001-8373-8577
# 492             Reddy  Harvind Kumar  0000-0001-8373-8577
# 493             Mahdi         Waleed  0000-0003-2547-3659
# 494             Mahdi         Waleed  0000-0003-2547-3659
# 495          Prentice          Barry  0000-0002-1620-6498
# 496           Lippitt    Christopher  0000-0001-7979-7857
# 497             Nance      R. Damian  0000-0001-9431-0963
# 498            Hunter       M. Colby  0000-0002-9222-7039
# 499              Kohn        Gregory  0000-0002-3365-6212
# 500              Kohn        Gregory  0000-0002-3365-6212
# 501        Kirschbaum        Kristin  0000-0002-9700-4619
# 502        Kirschbaum        Kristin  0000-0002-9700-4619
# 503           Okumura       Hideyuki  0000-0002-2576-7510
#
#                                       organization
# 0                         University of New Mexico
# 1               University of New Mexico Hospitals
# 2                         University of New Mexico
# 3                         University of New Mexico
# 4                         University of New Mexico
# 5                         University of New Mexico
# 6                         University of New Mexico
# 7                         University of New Mexico
# 8                      New Mexico State University
# 9                                  Duke University
# 10                        University of New Mexico
# 11                        University of New Mexico
# 12                        University of New Mexico
# 13                        University of New Mexico
# 14                        University of New Mexico
# 15                        University of New Mexico
# 16                          U.S. Geological Survey
# 17                        University of New Mexico
# 18                        University of New Mexico
# 19                        University of New Mexico
# 20                        University of New Mexico
# 21                        University of New Mexico
# 22                    The University of New Mexico
# 23                  Los Alamos National Laboratory
# 24                  Los Alamos National Laboratory
# 25                  Los Alamos National Laboratory
# 26                        University of New Mexico
# 27                             Columbia University
# 28       Princess Sumaya University for Technology
# 29                        University of New Mexico
# ..                                             ...
# 474                       University of New Mexico
# 475               Ohio State University University
# 476               Ohio State University University
# 477         University of California San Francisco
# 478         University of California San Francisco
# 479         University of California San Francisco
# 480         University of California San Francisco
# 481  New Mexico Institute of Mining and Technology
# 482                 University of Colorado Boulder
# 483                 University of Colorado Boulder
# 484  New Mexico Institute of Mining and Technology
# 485  New Mexico Institute of Mining and Technology
# 486  New Mexico Institute of Mining and Technology
# 487  New Mexico Institute of Mining and Technology
# 488                       University of New Mexico
# 489                       University of New Mexico
# 490                    New Mexico State University
# 491                    New Mexico State University
# 492                    New Mexico State University
# 493                         University of Oklahoma
# 494                         University of Oklahoma
# 495                         University of Manitoba
# 496                       University of New Mexico
# 497                                Ohio University
# 498          Georgia Southwestern State University
# 499                 Indiana University Bloomington
# 500                 Indiana University Bloomington
# 501                       East Carolina University
# 502                       East Carolina University
# 503                               Kyoto University
#
# [504 rows x 6 columns]

# %%
fullRecord('0000-0002-2483-5614')
# Out:
# {'activities-summary': {'educations': {'education-summary': [{'created-date': {'value': 1386964384543},
#      'department-name': 'Anthropology (Biological)',
#      'end-date': {'day': None, 'month': None, 'year': {'value': '2010'}},
#      'last-modified-date': {'value': 1406005714835},
#      'organization': {'address': {'city': 'Albuquerque',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '1104',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'University of New Mexico'},
#      'path': '/0000-0002-2483-5614/education/28641',
#      'put-code': 28641,
#      'role-title': 'PhD',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Timothy R Petersen'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0002-2483-5614',
#        'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#      'start-date': None,
#      'visibility': 'PUBLIC'},
#     {'created-date': {'value': 1386964684684},
#      'department-name': None,
#      'end-date': {'day': None, 'month': None, 'year': {'value': '1994'}},
#      'last-modified-date': {'value': 1406005714835},
#      'organization': {'address': {'city': 'Houston',
#        'country': 'US',
#        'region': 'TX'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '3990',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'Rice University'},
#      'path': '/0000-0002-2483-5614/education/28656',
#      'put-code': 28656,
#      'role-title': 'BA',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Timothy R Petersen'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0002-2483-5614',
#        'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#      'start-date': None,
#      'visibility': 'PUBLIC'},
#     {'created-date': {'value': 1386964321201},
#      'department-name': 'Anthropology',
#      'end-date': {'day': None, 'month': None, 'year': {'value': '2000'}},
#      'last-modified-date': {'value': 1406005714836},
#      'organization': {'address': {'city': 'Houston',
#        'country': 'US',
#        'region': 'TX'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '14743',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'University of Houston'},
#      'path': '/0000-0002-2483-5614/education/28636',
#      'put-code': 28636,
#      'role-title': 'MA',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Timothy R Petersen'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0002-2483-5614',
#        'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#      'start-date': None,
#      'visibility': 'PUBLIC'}],
#    'last-modified-date': {'value': 1406005714836},
#    'path': '/0000-0002-2483-5614/educations'},
#   'employments': {'employment-summary': [{'created-date': {'value': 1386964478911},
#      'department-name': 'Anesthesiology',
#      'end-date': None,
#      'last-modified-date': {'value': 1448480939419},
#      'organization': {'address': {'city': 'Albuquerque',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '1104',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'University of New Mexico'},
#      'path': '/0000-0002-2483-5614/employment/28644',
#      'put-code': 28644,
#      'role-title': 'Research Information Specialist',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Timothy R Petersen'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0002-2483-5614',
#        'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#      'start-date': {'day': None, 'month': None, 'year': {'value': '2010'}},
#      'visibility': 'PUBLIC'},
#     {'created-date': {'value': 1386964628388},
#      'department-name': 'Anthropology',
#      'end-date': {'day': None, 'month': None, 'year': {'value': '2013'}},
#      'last-modified-date': {'value': 1406005714836},
#      'organization': {'address': {'city': 'Albuquerque',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '1104',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'University of New Mexico'},
#      'path': '/0000-0002-2483-5614/employment/28652',
#      'put-code': 28652,
#      'role-title': 'Adjunct Assistant Professor (Part-Time Faculty)',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Timothy R Petersen'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0002-2483-5614',
#        'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#      'start-date': {'day': None, 'month': None, 'year': {'value': '2008'}},
#      'visibility': 'PUBLIC'}],
#    'last-modified-date': {'value': 1448480939419},
#    'path': '/0000-0002-2483-5614/employments'},
#   'fundings': {'group': [{'external-ids': {'external-id': []},
#      'funding-summary': [{'created-date': {'value': 1397773819341},
#        'display-index': '0',
#        'end-date': {'day': None,
#         'month': {'value': '08'},
#         'year': {'value': '2005'}},
#        'external-ids': None,
#        'last-modified-date': {'value': 1397773819341},
#        'organization': {'address': {'city': 'Washington, DC',
#          'country': 'US',
#          'region': None},
#         'disambiguated-organization': None,
#         'name': 'National Science Foundation'},
#        'path': '/0000-0002-2483-5614/funding/8894',
#        'put-code': 8894,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'start-date': {'day': None,
#         'month': {'value': '06'},
#         'year': {'value': '2005'}},
#        'title': {'title': {'value': 'Taxonomic Implications of Basicranial Variation in Australopithecus africanus'},
#         'translated-title': None},
#        'type': 'GRANT',
#        'visibility': 'PUBLIC'}],
#      'last-modified-date': {'value': 1397773819341}}],
#    'last-modified-date': {'value': 1397773819341},
#    'path': '/0000-0002-2483-5614/fundings'},
#   'last-modified-date': {'value': 1448481314621},
#   'path': '/0000-0002-2483-5614/activities',
#   'peer-reviews': {'group': [],
#    'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/peer-reviews'},
#   'works': {'group': [{'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.7863/ultra.34.6.1019'}]},
#      'last-modified-date': {'value': 1448481176476},
#      'work-summary': [{'created-date': {'value': 1448481176476},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.7863/ultra.34.6.1019'}]},
#        'last-modified-date': {'value': 1448481176476},
#        'path': '/0000-0002-2483-5614/work/20519625',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '05'},
#         'year': {'value': '2015'}},
#        'put-code': 20519625,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'A Randomized Controlled Trial Evaluating the See, Tilt, Align, and Rotate (STAR) Maneuver on Skill Acquisition for Simulated Ultrasound-Guided Interventional Procedures'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1111/pan.12425'}]},
#      'last-modified-date': {'value': 1448481314621},
#      'work-summary': [{'created-date': {'value': 1448481314621},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1111/pan.12425'}]},
#        'last-modified-date': {'value': 1448481314621},
#        'path': '/0000-0002-2483-5614/work/20519674',
#        'publication-date': {'day': {'value': '07'},
#         'media-type': None,
#         'month': {'value': '07'},
#         'year': {'value': '2014'}},
#        'put-code': 20519674,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Response to Furstein and Sadhasivam regarding their comment on our paper ‘Ultrasound-guided parasacral approach to the sciatic nerve block in children’'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': None,
#         'external-id-value': '10.1016/j.annemergmed.2014.01.037'}]},
#      'last-modified-date': {'value': 1448481282423},
#      'work-summary': [{'created-date': {'value': 1448481282423},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': None,
#           'external-id-value': '10.1016/j.annemergmed.2014.01.037'}]},
#        'last-modified-date': {'value': 1448481282423},
#        'path': '/0000-0002-2483-5614/work/20519670',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '06'},
#         'year': {'value': '2014'}},
#        'put-code': 20519670,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Comparison of Bag-Valve-Mask Hand-Sealing Techniques in a Simulated Model'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.5812/aapm.11906'}]},
#      'last-modified-date': {'value': 1437416930445},
#      'work-summary': [{'created-date': {'value': 1388697498348},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.5812/aapm.11906'}]},
#        'last-modified-date': {'value': 1437416930445},
#        'path': '/0000-0002-2483-5614/work/11430774',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '02'},
#         'year': {'value': '2014'}},
#        'put-code': 11430774,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'Perioperative management of Acquired Hemophilia A'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'pmid',
#         'external-id-url': {'value': ''},
#         'external-id-value': '24866613'},
#        {'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.7863/ultra.33.6.1057'}]},
#      'last-modified-date': {'value': 1437525905125},
#      'work-summary': [{'created-date': {'value': 1403797484565},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'pmid',
#           'external-id-url': {'value': ''},
#           'external-id-value': '24866613'},
#          {'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.7863/ultra.33.6.1057'}]},
#        'last-modified-date': {'value': 1437525905125},
#        'path': '/0000-0002-2483-5614/work/13007321',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 13007321,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'A randomized clinical trial comparing the effectiveness of ultrasound guidance versus nerve stimulation for lateral popliteal-sciatic blocks in obese patients'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.1155/2014/324083'}]},
#      'last-modified-date': {'value': 1437495961285},
#      'work-summary': [{'created-date': {'value': 1397774083853},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.1155/2014/324083'}]},
#        'last-modified-date': {'value': 1437495961285},
#        'path': '/0000-0002-2483-5614/work/12363772',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 12363772,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'A triple-masked, randomized controlled trial comparing ultrasound-guided brachial plexus and distal peripheral nerve block anesthesia for outpatient hand surgery'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': []},
#      'last-modified-date': {'value': 1436382502504},
#      'work-summary': [{'created-date': {'value': 1397774518222},
#        'display-index': '0',
#        'external-ids': None,
#        'last-modified-date': {'value': 1436382502504},
#        'path': '/0000-0002-2483-5614/work/12363778',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 12363778,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': "How we do it: SAMBA's OSA consensus statement in practice at a busy outpatient surgery center"},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.1016/j.jclinane.2013.09.004'}]},
#      'last-modified-date': {'value': 1437495961306},
#      'work-summary': [{'created-date': {'value': 1397774317323},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.1016/j.jclinane.2013.09.004'}]},
#        'last-modified-date': {'value': 1437495961306},
#        'path': '/0000-0002-2483-5614/work/12363775',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2014'}},
#        'put-code': 12363775,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'Reply to "It is hard to get a grip on it"'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'issn',
#         'external-id-url': {'value': ''},
#         'external-id-value': '0952-8180'},
#        {'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.1016/j.jclinane.2012.10.009'}]},
#      'last-modified-date': {'value': 1437409385225},
#      'work-summary': [{'created-date': {'value': 1386965276079},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'issn',
#           'external-id-url': {'value': ''},
#           'external-id-value': '0952-8180'},
#          {'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.1016/j.jclinane.2012.10.009'}]},
#        'last-modified-date': {'value': 1437409385225},
#        'path': '/0000-0002-2483-5614/work/11258991',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2013'}},
#        'put-code': 11258991,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Efficacy of facemask ventilation techniques in novice providers'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.1111/pan.12194'},
#        {'external-id-relationship': 'SELF',
#         'external-id-type': 'issn',
#         'external-id-url': {'value': ''},
#         'external-id-value': '1155-5645'}]},
#      'last-modified-date': {'value': 1437409385151},
#      'work-summary': [{'created-date': {'value': 1386965235412},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.1111/pan.12194'},
#          {'external-id-relationship': 'SELF',
#           'external-id-type': 'issn',
#           'external-id-url': {'value': ''},
#           'external-id-value': '1155-5645'}]},
#        'last-modified-date': {'value': 1437409385151},
#        'path': '/0000-0002-2483-5614/work/11258988',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2013'}},
#        'put-code': 11258988,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Ultrasound-guided parasacral approach to the sciatic nerve block in children'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#         'external-id-type': 'issn',
#         'external-id-url': {'value': ''},
#         'external-id-value': '0003-4932'},
#        {'external-id-relationship': 'SELF',
#         'external-id-type': 'doi',
#         'external-id-url': {'value': ''},
#         'external-id-value': '10.1097/sla.0b013e318250504e'}]},
#      'last-modified-date': {'value': 1437409385054},
#      'work-summary': [{'created-date': {'value': 1386965096518},
#        'display-index': '0',
#        'external-ids': {'external-id': [{'external-id-relationship': 'SELF',
#           'external-id-type': 'issn',
#           'external-id-url': {'value': ''},
#           'external-id-value': '0003-4932'},
#          {'external-id-relationship': 'SELF',
#           'external-id-type': 'doi',
#           'external-id-url': {'value': ''},
#           'external-id-value': '10.1097/sla.0b013e318250504e'}]},
#        'last-modified-date': {'value': 1437409385054},
#        'path': '/0000-0002-2483-5614/work/11258983',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2012'}},
#        'put-code': 11258983,
#        'source': {'source-client-id': {'host': 'orcid.org',
#          'path': '0000-0002-3054-1567',
#          'uri': 'http://orcid.org/client/0000-0002-3054-1567'},
#         'source-name': {'value': 'CrossRef Metadata Search'},
#         'source-orcid': None},
#        'title': {'subtitle': None,
#         'title': {'value': 'Should More Patients Continue Aspirin Therapy Perioperatively?'},
#         'translated-title': None},
#        'type': 'JOURNAL_ARTICLE',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': []},
#      'last-modified-date': {'value': 1436287480618},
#      'work-summary': [{'created-date': {'value': 1378933275544},
#        'display-index': '0',
#        'external-ids': None,
#        'last-modified-date': {'value': 1436287480618},
#        'path': '/0000-0002-2483-5614/work/9931025',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2010'}},
#        'put-code': 9931025,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'Taxonomic implications of basicranial variation in Australopithecus africanus'},
#         'translated-title': None},
#        'type': 'DISSERTATION',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': []},
#      'last-modified-date': {'value': 1436287520401},
#      'work-summary': [{'created-date': {'value': 1378933110768},
#        'display-index': '0',
#        'external-ids': None,
#        'last-modified-date': {'value': 1436287520401},
#        'path': '/0000-0002-2483-5614/work/9931009',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': None,
#         'year': {'value': '2005'}},
#        'put-code': 9931009,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'Comment on: Plio-Pleistocene hominid limb proportions: Evolutionary reversals or estimation errors?'},
#         'translated-title': None},
#        'type': 'OTHER',
#        'visibility': 'PUBLIC'}]},
#     {'external-ids': {'external-id': []},
#      'last-modified-date': {'value': 1436287514331},
#      'work-summary': [{'created-date': {'value': 1378933215177},
#        'display-index': '0',
#        'external-ids': None,
#        'last-modified-date': {'value': 1436287514331},
#        'path': '/0000-0002-2483-5614/work/9931022',
#        'publication-date': {'day': None,
#         'media-type': None,
#         'month': {'value': '08'},
#         'year': {'value': '2000'}},
#        'put-code': 9931022,
#        'source': {'source-client-id': None,
#         'source-name': {'value': 'Timothy R Petersen'},
#         'source-orcid': {'host': 'orcid.org',
#          'path': '0000-0002-2483-5614',
#          'uri': 'http://orcid.org/0000-0002-2483-5614'}},
#        'title': {'subtitle': None,
#         'title': {'value': 'Skeletal robusticity at the ancient Maya sites of K’axob, Belize, and Copán, Honduras'},
#         'translated-title': None},
#        'type': 'SUPERVISED_STUDENT_PUBLICATION',
#        'visibility': 'PUBLIC'}]}],
#    'last-modified-date': {'value': 1448481314621},
#    'path': '/0000-0002-2483-5614/works'}},
#  'history': {'claimed': True,
#   'completion-date': {'value': 1378931413555},
#   'creation-method': 'WEBSITE',
#   'deactivation-date': None,
#   'last-modified-date': {'value': 1480348249186},
#   'source': None,
#   'submission-date': {'value': 1378931361835},
#   'verified-email': True,
#   'verified-primary-email': True},
#  'orcid-identifier': {'host': 'orcid.org',
#   'path': '0000-0002-2483-5614',
#   'uri': 'http://orcid.org/0000-0002-2483-5614'},
#  'path': '/0000-0002-2483-5614',
#  'person': {'addresses': {'address': [],
#    'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/address'},
#   'biography': {'content': '',
#    'created-date': {'value': 1460758033022},
#    'last-modified-date': {'value': 1460758033022},
#    'path': '/0000-0002-2483-5614/biography',
#    'visibility': 'PUBLIC'},
#   'emails': {'email': [],
#    'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/email'},
#   'external-identifiers': {'external-identifier': [],
#    'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/external-identifiers'},
#   'keywords': {'keyword': [],
#    'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/keywords'},
#   'last-modified-date': None,
#   'name': {'created-date': {'value': 1460758033019},
#    'credit-name': {'value': 'Timothy R Petersen'},
#    'family-name': {'value': 'Petersen'},
#    'given-names': {'value': 'Timothy'},
#    'last-modified-date': {'value': 1460758033019},
#    'path': '0000-0002-2483-5614',
#    'source': None,
#    'visibility': 'PUBLIC'},
#   'other-names': {'last-modified-date': None,
#    'other-name': [],
#    'path': '/0000-0002-2483-5614/other-names'},
#   'path': '/0000-0002-2483-5614/person',
#   'researcher-urls': {'last-modified-date': None,
#    'path': '/0000-0002-2483-5614/researcher-urls',
#    'researcher-url': []}},
#  'preferences': {'locale': 'EN'}}
