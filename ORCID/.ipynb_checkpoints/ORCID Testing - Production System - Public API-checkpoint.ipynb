# %% [markdown]
# Testing of the publicly accessible API for the production ORCID system
#
# API 2.0 reference (in GitHub): https://github.com/ORCID/ORCID-Source/tree/master/orcid-model/src/main/resources/record_2.0

# %%
import requests
import json
import datetime
import pandas

# %%
# Define variables for use throughout
publicTokenResponse= {"access_token":"4a587e47-b564-412b-81a5-175ed8a92fed","token_type":"bearer","refresh_token":"236ddbf7-867f-42cc-9e08-af32526c1ba3","expires_in":631138518,"scope":"/read-public","orcid":"null"}
publicToken = publicTokenResponse["access_token"]

host = "pub.orcid.org" #member API in sandbox
headers = {"Accept":"application/json", "Authorization":"Bearer %s"%(publicToken)}


# define some extraction functions for ORCID results
def getEmployment(orcidID):
    reqString = "https://%s/v2.0/%s/employments"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers )
    return(reqGet.json())

def getPerson(orcidID):
    reqString = "https://%s/v2.0/%s/person"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

def getPersonalDetails(orcidID):
    reqString = "https://%s/v2.0/%s/personal-details"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

def fullRecord(orcidID):
    reqString = "https://%s/v2.0/%s/record"%(host,orcidID)
    reqGet = requests.get(reqString, headers=headers)
    return(reqGet.json())

# %%
# public production API testing with Karl's token/credentials

query = "affiliation-org-name:'University+of+New+Mexico'"
headers = {"Accept":"application/json", "Authorization":"Bearer %s"%(publicToken)}

records = 200 # per request
request_no = 1 # number of requests

resultList = []

for i in range(request_no):
    start = i * records
    baseURL = "https://%s/v2.0/search?q=%s&rows=%s&start=%s"%(host,query,records,start)

    reqGet = requests.get(baseURL, headers=headers )
    reqGet.json()['result']

    print(json.dumps(reqGet.json()))

    j = 0
    for resultItem in reqGet.json()['result']:
        returnDict = {}
        returnDict['orcidID'] = resultItem['orcid-identifier']['path']

        # get the person's name
        result = getPersonalDetails(returnDict['orcidID'])

        try:
            returnDict['familyName'] = result['name']['family-name']['value']
        except:
            returnDict['familyName'] = "ERROR"

        try:
            returnDict['givenNames'] = result['name']['given-names']['value']
        except:
            returnDict['givenNames'] = "ERROR"

        try:
            returnDict['creditName'] = result['name']['credit-name']['value']
        except:
            returnDict['creditName'] = "ERROR"





        # get the person's employment information
        result = getEmployment(returnDict['orcidID'])

        employmentList = []
        for employmentItem in result['employment-summary']:
            employmentRecord = {}
            # print(json.dumps(employmentItem, indent=4, sort_keys=True))

            try:
                employmentRecord['department_name'] = employmentItem['department-name']
            except:
                employmentRecord['department_name'] = "ERROR"

            try:
                employmentRecord['start_date'] = {'year':employmentItem['start-date']['year']['value'], 'month':employmentItem['start-date']['month']['value'],'day':employmentItem['start-date']['day']['value']}
            except:
                employmentRecord['start_date'] = {}

            try:
                employmentRecord['end_date'] = {'year':employmentItem['end-date']['year']['value'], 'month':employmentItem['end-date']['month']['value'],'day':employmentItem['end-date']['day']['value']}
            except:
                employmentRecord['end_date'] = {}

            try:
                employmentRecord['role_title'] = employmentItem['role-title']
            except:
                employmentRecord['role_title'] = "ERROR"

            try:
                employmentRecord['organization'] = employmentItem['organization']['name']
            except:
                employmentRecord['organization'] = "ERROR"

            try:
                employmentRecord['address_city'] = employmentItem['organization']['address']['city']
            except:
                employmentRecord['address_city'] = "ERROR"

            try:
                employmentRecord['address_region'] = employmentItem['organization']['address']['region']
            except:
                employmentRecord['address_region'] = "ERROR"

            try:
                employmentRecord['address_country'] = employmentItem['organization']['address']['country']
            except:
                employmentRecord['address_country'] = "ERROR"

            employmentList.append(employmentRecord)


        returnDict['employment'] = employmentList



        resultList.append(returnDict)

        #j += 1
        #if j > 10: break

#for item in resultList:
#    print(json.dumps(item, indent=4, sort_keys=True))
# Out:
# {"num-found": 1024620, "result": [{"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-7886-638X", "path": "0000-0001-7886-638X"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-6740-4590", "path": "0000-0002-6740-4590"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3104-4447", "path": "0000-0003-3104-4447"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-4415-3573", "path": "0000-0002-4415-3573"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0918-9041", "path": "0000-0003-0918-9041"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-4047-3411", "path": "0000-0003-4047-3411"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-7462-1609", "path": "0000-0001-7462-1609"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-4040-9874", "path": "0000-0003-4040-9874"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-8425-4686", "path": "0000-0002-8425-4686"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-0537-7558", "path": "0000-0002-0537-7558"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-0689-3546", "path": "0000-0002-0689-3546"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3302-4546", "path": "0000-0003-3302-4546"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-9021-2845", "path": "0000-0002-9021-2845"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9353-5052", "path": "0000-0001-9353-5052"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-6702-4264", "path": "0000-0002-6702-4264"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-8113-8380", "path": "0000-0002-8113-8380"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-1056-9466", "path": "0000-0002-1056-9466"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-2107-9355", "path": "0000-0003-2107-9355"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-7079-1117", "path": "0000-0001-7079-1117"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-1572-9756", "path": "0000-0002-1572-9756"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-5934-2791", "path": "0000-0001-5934-2791"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-8186-4350", "path": "0000-0001-8186-4350"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-2375-2198", "path": "0000-0002-2375-2198"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-2460-8478", "path": "0000-0003-2460-8478"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3811-1518", "path": "0000-0003-3811-1518"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-4077-0184", "path": "0000-0003-4077-0184"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3217-3486", "path": "0000-0003-3217-3486"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-9614-1769", "path": "0000-0002-9614-1769"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-8716-2069", "path": "0000-0001-8716-2069"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-1921-604X", "path": "0000-0003-1921-604X"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9305-5470", "path": "0000-0001-9305-5470"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-0094-3784", "path": "0000-0002-0094-3784"}}, {"orcid-identifier": {"host":  ...
# {"num-found": 1024622, "result": [{"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0363-1361", "path": "0000-0003-0363-1361"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3944-8323", "path": "0000-0003-3944-8323"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-7915-3274", "path": "0000-0002-7915-3274"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-1634-9103", "path": "0000-0003-1634-9103"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0473-2957", "path": "0000-0003-0473-2957"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-8374-2656", "path": "0000-0001-8374-2656"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0133-3627", "path": "0000-0003-0133-3627"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-3192-6434", "path": "0000-0002-3192-6434"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-1288-6673", "path": "0000-0003-1288-6673"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9663-4355", "path": "0000-0001-9663-4355"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9409-0067", "path": "0000-0001-9409-0067"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-5362-3576", "path": "0000-0001-5362-3576"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-8774-582X", "path": "0000-0001-8774-582X"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-9109-2072", "path": "0000-0002-9109-2072"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-8106-9477", "path": "0000-0002-8106-9477"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-5365-2553", "path": "0000-0001-5365-2553"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-6060-2199", "path": "0000-0002-6060-2199"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-3548-8726", "path": "0000-0002-3548-8726"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-7131-3747", "path": "0000-0002-7131-3747"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-4846-2645", "path": "0000-0003-4846-2645"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-1557-4790", "path": "0000-0002-1557-4790"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3701-3430", "path": "0000-0003-3701-3430"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-8951-7289", "path": "0000-0002-8951-7289"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9955-0616", "path": "0000-0001-9955-0616"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-7881-8131", "path": "0000-0002-7881-8131"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3348-5932", "path": "0000-0003-3348-5932"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-9065-7767", "path": "0000-0001-9065-7767"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-0566-4012", "path": "0000-0002-0566-4012"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-2981-3203", "path": "0000-0002-2981-3203"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0143-4786", "path": "0000-0003-0143-4786"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0698-2343", "path": "0000-0003-0698-2343"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-9949-5407", "path": "0000-0002-9949-5407"}}, {"orcid-identifier": {"host":  ...

# %%
# flatten the resultList into a dict

flatList = []

for person in resultList:
    returnDict = {}
    #for empolyment in person['employment']:
    returnDict['familyName'] = person['familyName']
    returnDict['givenNames'] = person['givenNames']
    returnDict['creditName'] = person['creditName']
    returnDict['orcidID'] = person['orcidID']
    
    for employment in person['employment']:
        returnDict['organization'] = employment['organization']
        returnDict['department_name'] = employment['department_name']


    
        flatList.append(returnDict)




goodLuck = pandas.DataFrame(flatList)

# %%
print(goodLuck)
# Out:
#     creditName                                    department_name  \
# 0        ERROR                         Mathematics and Statistics
# 1        ERROR                                 Clinical Education
# 2        ERROR                                        Archaeology
# 3        ERROR                                        Archaeology
# 4        ERROR                                      Cancer Center
# 5        ERROR                                      Cancer Center
# 6        ERROR                                      Cancer Center
# 7        ERROR                                      Cancer Center
# 8        ERROR                        Family and Consumer Science
# 9        ERROR                                            Biology
# 10       ERROR                                 College of Nursing
# 11       ERROR                                 College of Nursing
# 12       ERROR                                 College of Nursing
# 13       ERROR                     Department of Computer Science
# 14       ERROR                                               None
# 15       ERROR                                               None
# 16       ERROR                    New Mexico Water Science Center
# 17       ERROR                              Physics and Astronomy
# 18       ERROR                              Physics and Astronomy
# 19       ERROR                              Physics and Astronomy
# 20       ERROR           Nanoscience and Microsystems Engineering
# 21       ERROR           Nanoscience and Microsystems Engineering
# 22       ERROR  Pharmacoeconomics, Epidemiology, Pharmaceutica...
# 23       ERROR  CCS-2: Computer, Computational, and Statistica...
# 24       ERROR  CCS-2: Computer, Computational, and Statistica...
# 25       ERROR  CCS-2: Computer, Computational, and Statistica...
# 26       ERROR                                            Biology
# 27       ERROR                          Communication Engineering
# 28       ERROR          National Center for Disaster Preparedness
# 29       ERROR      language, literacy, and Sociocultural Studies
# ..         ...                                                ...
# 476      ERROR                                            English
# 477      ERROR                                               Fish
# 478      ERROR                                               Fish
# 479      ERROR                                               Fish
# 480      ERROR                              School of Visual Arts
# 481      ERROR  Individual, Family & Community Education | Nut...
# 482      ERROR                                          Neurology
# 483      ERROR                                               None
# 484      ERROR                                               News
# 485      ERROR                                            Biology
# 486      ERROR                          Lynch School of Education
# 487      ERROR                                  School of Nursing
# 488      ERROR  International Biological Chemical Threat Reduc...
# 489      ERROR                                         Psychology
# 490      ERROR                                         Psychology
# 491      ERROR                                         Psychology
# 492      ERROR                                         Pediatrics
# 493      ERROR                     Marine and Ecological Sciences
# 494      ERROR               Department of Spanish and Portuguese
# 495      ERROR                                            Biology
# 496      ERROR  Program of Organization, Information, and Lear...
# 497      ERROR                                          Chemistry
# 498      ERROR                                          Chemistry
# 499      ERROR                                          Chemistry
# 500      ERROR                      Horticulture and Crop Science
# 501      ERROR                      Horticulture and Crop Science
# 502      ERROR                                       Neuroscience
# 503      ERROR                                       Neuroscience
# 504      ERROR                                       Neuroscience
# 505      ERROR                                       Neuroscience
#
#            familyName  givenNames              orcidID  \
# 0              Degnan    James H.  0000-0001-7886-638X
# 1              Melada      Samuel  0000-0002-6740-4590
# 2               Combs      Angela  0000-0003-3104-4447
# 3               Combs      Angela  0000-0003-3104-4447
# 4                Kang     Huining  0000-0002-4415-3573
# 5                Kang     Huining  0000-0002-4415-3573
# 6                Kang     Huining  0000-0002-4415-3573
# 7                Kang     Huining  0000-0002-4415-3573
# 8               Marin    Merranda  0000-0003-0918-9041
# 9           Washburne        Alex  0000-0003-4047-3411
# 10              cohen       sally  0000-0001-7462-1609
# 11              cohen       sally  0000-0001-7462-1609
# 12              cohen       sally  0000-0001-7462-1609
# 13                 Lu          Qi  0000-0002-8425-4686
# 14               Wang     Zhuoyao  0000-0002-0537-7558
# 15              ERROR     Mohamed  0000-0002-0689-3546
# 16           Mitchell     Aurelia  0000-0003-3302-4546
# 17         Obenberger     Kenneth  0000-0002-6702-4264
# 18         Obenberger     Kenneth  0000-0002-6702-4264
# 19         Obenberger     Kenneth  0000-0002-6702-4264
# 20             Dorsey    Jonathan  0000-0002-8113-8380
# 21             Dorsey    Jonathan  0000-0002-8113-8380
# 22             Kharat      Akshay  0000-0002-1056-9466
# 23           O'Rourke     Patrick  0000-0003-2107-9355
# 24           O'Rourke     Patrick  0000-0003-2107-9355
# 25           O'Rourke     Patrick  0000-0003-2107-9355
# 26           Thibault       James  0000-0001-7079-1117
# 27              hasan        omar  0000-0001-5934-2791
# 28           Chandler      Thomas  0000-0001-8186-4350
# 29             Haridy  Abdelbaset  0000-0002-2375-2198
# ..                ...         ...                  ...
# 476           Higgins       Shawn  0000-0001-5564-2412
# 477         Steinberg    Rosemary  0000-0002-6153-2743
# 478         Steinberg    Rosemary  0000-0002-6153-2743
# 479         Steinberg    Rosemary  0000-0002-6153-2743
# 480          Borowski     Michael  0000-0002-3326-1210
# 481            Pribis       Peter  0000-0003-1551-3194
# 482              Ford       Corey  0000-0003-3840-3000
# 483           Babuska       Tomas  0000-0001-7192-0400
# 484          Vizcaino      Johnny  0000-0002-1234-5896
# 485             Adema        Coen  0000-0002-6250-5499
# 486     Luna Bazaldua       Diego  0000-0002-8535-7775
# 487           Doshier       Sally  0000-0003-1650-998X
# 488                Ko       Randy  0000-0002-3947-1956
# 489            gagnon       bruno  0000-0002-6962-7747
# 490            gagnon       bruno  0000-0002-6962-7747
# 491            gagnon       bruno  0000-0002-6962-7747
# 492          Penaloza       Linda  0000-0002-3051-8308
# 493           Parsons     Michael  0000-0003-4268-567X
# 494          Meireles     Daniela  0000-0001-9440-1654
# 495         Baymiller     Maxwell  0000-0003-2438-243X
# 496               Law      Victor  0000-0003-3504-2764
# 497              Enke    Christie  0000-0002-3607-0356
# 498              Enke    Christie  0000-0002-3607-0356
# 499              Enke    Christie  0000-0002-3607-0356
# 500  Mohseni-Moghadam      Mohsen  0000-0002-1562-5404
# 501  Mohseni-Moghadam      Mohsen  0000-0002-1562-5404
# 502          Janowich  Jacqueline  0000-0003-3443-589X
# 503          Janowich  Jacqueline  0000-0003-3443-589X
# 504          Janowich  Jacqueline  0000-0003-3443-589X
# 505          Janowich  Jacqueline  0000-0003-3443-589X
#
#                                           organization
# 0                             University of New Mexico
# 1                   University of New Mexico Hospitals
# 2                             University of New Mexico
# 3                             University of New Mexico
# 4                             University of New Mexico
# 5                             University of New Mexico
# 6                             University of New Mexico
# 7                             University of New Mexico
# 8                          New Mexico State University
# 9                                      Duke University
# 10                            University of New Mexico
# 11                            University of New Mexico
# 12                            University of New Mexico
# 13                            University of New Mexico
# 14                            University of New Mexico
# 15                            University of New Mexico
# 16                              U.S. Geological Survey
# 17                            University of New Mexico
# 18                            University of New Mexico
# 19                            University of New Mexico
# 20                            University of New Mexico
# 21                            University of New Mexico
# 22                        The University of New Mexico
# 23                      Los Alamos National Laboratory
# 24                      Los Alamos National Laboratory
# 25                      Los Alamos National Laboratory
# 26                            University of New Mexico
# 27           Princess Sumaya University for Technology
# 28                                 Columbia University
# 29                            University of New Mexico
# ..                                                 ...
# 476                  University of Connecticut, Storrs
# 477                               Clark's Pet Emporium
# 478                               Clark's Pet Emporium
# 479                               Clark's Pet Emporium
# 480  Virginia Polytechnic Institute and State Unive...
# 481                           University of New Mexico
# 482    University of New Mexico Health Sciences Center
# 483                       Sandia National Laboratories
# 484                                         Daily Lobo
# 485                           University of New Mexico
# 486                                     Boston College
# 487                        Northern Arizona University
# 488                       Sandia National Laboratories
# 489                           University of New Mexico
# 490                           University of New Mexico
# 491                           University of New Mexico
# 492        University of New Mexico School of Medicine
# 493                      Florida Gulf Coast University
# 494                      University of Texas at Austin
# 495      New Mexico Institute of Mining and Technology
# 496                           University of New Mexico
# 497                           University of New Mexico
# 498                           University of New Mexico
# 499                           University of New Mexico
# 500                   Ohio State University University
# 501                   Ohio State University University
# 502             University of California San Francisco
# 503             University of California San Francisco
# 504             University of California San Francisco
# 505             University of California San Francisco
#
# [506 rows x 6 columns]

# %%
fullRecord('0000-0003-0918-9041')
# Out:
# {'activities-summary': {'educations': {'education-summary': [{'created-date': {'value': 1493672467716},
#      'department-name': 'Counseling and Educational Psychology',
#      'end-date': {'day': {'value': '20'},
#       'month': {'value': '08'},
#       'year': {'value': '2007'}},
#      'last-modified-date': {'value': 1493672467716},
#      'organization': {'address': {'city': 'Las Cruces',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '4423',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'New Mexico State University'},
#      'path': '/0000-0003-0918-9041/education/3772754',
#      'put-code': 3772754,
#      'role-title': 'Ph.D. Counseling Psychology',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Merranda Marin'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-0918-9041',
#        'uri': 'http://orcid.org/0000-0003-0918-9041'}},
#      'start-date': {'day': {'value': '22'},
#       'month': {'value': '07'},
#       'year': {'value': '2002'}},
#      'visibility': 'PUBLIC'},
#     {'created-date': {'value': 1493672401793},
#      'department-name': 'Family and Consumer Science',
#      'end-date': {'day': {'value': '25'},
#       'month': {'value': '05'},
#       'year': {'value': '1999'}},
#      'last-modified-date': {'value': 1493672401793},
#      'organization': {'address': {'city': 'Las Cruces',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '4423',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'New Mexico State University'},
#      'path': '/0000-0003-0918-9041/education/3772750',
#      'put-code': 3772750,
#      'role-title': 'Master of Science Marriage and Family Therapy',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Merranda Marin'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-0918-9041',
#        'uri': 'http://orcid.org/0000-0003-0918-9041'}},
#      'start-date': {'day': {'value': '15'},
#       'month': {'value': '01'},
#       'year': {'value': '1997'}},
#      'visibility': 'PUBLIC'},
#     {'created-date': {'value': 1493672316117},
#      'department-name': 'Psychology',
#      'end-date': {'day': {'value': '25'},
#       'month': {'value': '05'},
#       'year': {'value': '1996'}},
#      'last-modified-date': {'value': 1493672316117},
#      'organization': {'address': {'city': 'Portales',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '6666',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'Eastern New Mexico University'},
#      'path': '/0000-0003-0918-9041/education/3772747',
#      'put-code': 3772747,
#      'role-title': 'Bachelor of Science',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Merranda Marin'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-0918-9041',
#        'uri': 'http://orcid.org/0000-0003-0918-9041'}},
#      'start-date': {'day': {'value': '15'},
#       'month': {'value': '08'},
#       'year': {'value': '1992'}},
#      'visibility': 'PUBLIC'}],
#    'last-modified-date': {'value': 1493672467716},
#    'path': '/0000-0003-0918-9041/educations'},
#   'employments': {'employment-summary': [{'created-date': {'value': 1493672514337},
#      'department-name': 'Family and Consumer Science',
#      'end-date': None,
#      'last-modified-date': {'value': 1493672514337},
#      'organization': {'address': {'city': 'Las Cruces',
#        'country': 'US',
#        'region': 'NM'},
#       'disambiguated-organization': {'disambiguated-organization-identifier': '4423',
#        'disambiguation-source': 'RINGGOLD'},
#       'name': 'New Mexico State University'},
#      'path': '/0000-0003-0918-9041/employment/3772756',
#      'put-code': 3772756,
#      'role-title': 'Associate Professor',
#      'source': {'source-client-id': None,
#       'source-name': {'value': 'Merranda Marin'},
#       'source-orcid': {'host': 'orcid.org',
#        'path': '0000-0003-0918-9041',
#        'uri': 'http://orcid.org/0000-0003-0918-9041'}},
#      'start-date': {'day': {'value': '10'},
#       'month': {'value': '08'},
#       'year': {'value': '2012'}},
#      'visibility': 'PUBLIC'}],
#    'last-modified-date': {'value': 1493672514337},
#    'path': '/0000-0003-0918-9041/employments'},
#   'fundings': {'group': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/fundings'},
#   'last-modified-date': {'value': 1493672514337},
#   'path': '/0000-0003-0918-9041/activities',
#   'peer-reviews': {'group': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/peer-reviews'},
#   'works': {'group': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/works'}},
#  'history': {'claimed': True,
#   'completion-date': None,
#   'creation-method': 'DIRECT',
#   'deactivation-date': None,
#   'last-modified-date': {'value': 1494944885799},
#   'source': None,
#   'submission-date': {'value': 1493672174476},
#   'verified-email': True,
#   'verified-primary-email': True},
#  'orcid-identifier': {'host': 'orcid.org',
#   'path': '0000-0003-0918-9041',
#   'uri': 'http://orcid.org/0000-0003-0918-9041'},
#  'path': '/0000-0003-0918-9041',
#  'person': {'addresses': {'address': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/address'},
#   'biography': None,
#   'emails': {'email': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/email'},
#   'external-identifiers': {'external-identifier': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/external-identifiers'},
#   'keywords': {'keyword': [],
#    'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/keywords'},
#   'last-modified-date': None,
#   'name': {'created-date': {'value': 1493672174476},
#    'credit-name': None,
#    'family-name': {'value': 'Marin'},
#    'given-names': {'value': 'Merranda'},
#    'last-modified-date': {'value': 1493672174699},
#    'path': '0000-0003-0918-9041',
#    'source': None,
#    'visibility': 'PUBLIC'},
#   'other-names': {'last-modified-date': None,
#    'other-name': [],
#    'path': '/0000-0003-0918-9041/other-names'},
#   'path': '/0000-0003-0918-9041/person',
#   'researcher-urls': {'last-modified-date': None,
#    'path': '/0000-0003-0918-9041/researcher-urls',
#    'researcher-url': []}},
#  'preferences': {'locale': 'EN'}}

# %%
# pull the full profile
# public production API testing with Karl's token/credentials

query = "affiliation-org-name:'University+of+New+Mexico'"
headers = {"Accept":"application/json", "Authorization":"Bearer %s"%(publicToken)}

records = 5
requests_no = 1

full_result_list = []

for i in range(requests_no):
    start = i * records
    baseURL = "https://%s/v2.0/search?q=%s&rows=%s&start=%s"%(host,query,records,start)

    reqGet = requests.get(baseURL, headers=headers )
    reqGet.json()['result']

    print(json.dumps(reqGet.json()))

    j = 0
    for resultItem in reqGet.json()['result']:
        returnDict = {}
        returnDict['orcidID'] = resultItem['orcid-identifier']['path']

        # get the full public user profile
        result = fullRecord(returnDict['orcidID'])

        # grab the person's name information
        try:
            returnDict['familyName'] = result['person']['name']['family-name']['value']
        except:
            returnDict['familyName'] = "ERROR"

        try:
            returnDict['givenNames'] = result['person']['name']['given-names']['value']
        except:
            returnDict['givenNames'] = "ERROR"

        try:
            returnDict['creditName'] = result['person']['name']['credit-name']['value']
        except:
            returnDict['creditName'] = "ERROR"


        # get the person's employment information
        employmentList = []
        
        for employmentItem in result['activities-summary']['employments']['employment-summary']:
            employmentRecord = {}
            # print(json.dumps(employmentItem, indent=4, sort_keys=True))

            try:
                employmentRecord['department_name'] = employmentItem['department-name']
            except:
                employmentRecord['department_name'] = "ERROR"

            try:
                employmentRecord['start_date'] = {'year':employmentItem['start-date']['year']['value'], 'month':employmentItem['start-date']['month']['value'],'day':employmentItem['start-date']['day']['value']}
            except:
                employmentRecord['start_date'] = {}

            try:
                employmentRecord['end_date'] = {'year':employmentItem['end-date']['year']['value'], 'month':employmentItem['end-date']['month']['value'],'day':employmentItem['end-date']['day']['value']}
            except:
                employmentRecord['end_date'] = {}

            try:
                employmentRecord['role_title'] = employmentItem['role-title']
            except:
                employmentRecord['role_title'] = "ERROR"

            try:
                employmentRecord['organization'] = employmentItem['organization']['name']
            except:
                employmentRecord['organization'] = "ERROR"

            try:
                employmentRecord['address_city'] = employmentItem['organization']['address']['city']
            except:
                employmentRecord['address_city'] = "ERROR"

            try:
                employmentRecord['address_region'] = employmentItem['organization']['address']['region']
            except:
                employmentRecord['address_region'] = "ERROR"

            try:
                employmentRecord['address_country'] = employmentItem['organization']['address']['country']
            except:
                employmentRecord['address_country'] = "ERROR"

            employmentList.append(employmentRecord)
            
        returnDict['employment'] = employmentList

        # get the person's education information
        educationList = []
        
        for educationItem in result['activities-summary']['educations']['education-summary']:
            educationRecord = {}
            # print(json.dumps(employmentItem, indent=4, sort_keys=True))

            try:
                educationRecord['department_name'] = educationItem['department-name']
            except:
                educationRecord['department_name'] = "ERROR"

            try:
                educationRecord['start_date'] = {'year':educationItem['start-date']['year']['value'], 'month':educationItem['start-date']['month']['value'],'day':educationItem['start-date']['day']['value']}
            except:
                educationRecord['start_date'] = {}

            try:
                educationRecord['end_date'] = {'year':educationItem['end-date']['year']['value'], 'month':educationItem['end-date']['month']['value'],'day':educationItem['end-date']['day']['value']}
            except:
                educationRecord['end_date'] = {}

            try:
                educationRecord['organization'] = educationItem['organization']['name']
            except:
                educationRecord['organization'] = "ERROR"

            try:
                educationRecord['degree'] = educationItem['role-title']
            except:
                educationRecord['degree'] = "ERROR"
                
            educationList.append(educationRecord)
            
        returnDict['education'] = educationList



        # get the person's funding information
        fundingList = []
        
        for fundingGroup in result['activities-summary']['fundings']['group']:
            fundingRecord = {}
            
            for fundingItem in fundingGroup['funding-summary']:

                try:
                    fundingRecord['external_id'] = fundingItem['external-ids']
                except:
                    fundingRecord['external_id'] = "ERROR"

                try:
                    fundingRecord['title'] = fundingItem['title']
                except:
                    fundingRecord['title'] = "ERROR"

                try:
                    fundingRecord['start_date'] = {'year':fundingItem['start-date']['year']['value'], 'month':fundingItem['start-date']['month']['value'],'day':fundingItem['start-date']['day']['value']}
                except:
                    fundingRecord['start_date'] = {}

                try:
                    fundingRecord['end_date'] = {'year':fundingItem['end-date']['year']['value'], 'month':fundingItem['end-date']['month']['value'],'day':fundingItem['end-date']['day']['value']}
                except:
                    fundingRecord['end_date'] = {}

                try:
                    fundingRecord['organization'] = fundingItem['organization']['name']
                except:
                    fundingRecord['organization'] = "ERROR"

                fundingList.append(fundingRecord)
            
        returnDict['funding'] = fundingList

        # get the person's works information
        worksList = []
        
        for worksGroup in result['activities-summary']['works']['group']:
            worksRecord = {}
            
            for workItem in worksGroup['work-summary']:

                try:
                    worksRecord['external_id'] = workItem['external-ids']
                except:
                    worksRecord['external_id'] = "ERROR"

                try:
                    worksRecord['title'] = workItem['title']['title']['value']
                except:
                    worksRecord['title'] = "ERROR"

                try:
                    worksRecord['journal_title'] = workItem['journal-title']
                except:
                    worksRecord['journal_title'] = "ERROR"

                try:
                    worksRecord['citation'] = workItem['citation']['value']
                except:
                    worksRecord['citation'] = "ERROR"


                try:
                    worksRecord['pub_date'] = {'year':workItem['publication-date']['year']['value'], 'month':workItem['publication-date']['month']['value'],'day':workItem['publication-date']['day']['value']}
                except:
                    worksRecord['pub_date'] = {}



                worksList.append(worksRecord)
            
        returnDict['works'] = worksList


        full_result_list.append(returnDict)
# Out:
# {"num-found": 1024671, "result": [{"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0001-7886-638X", "path": "0000-0001-7886-638X"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-6740-4590", "path": "0000-0002-6740-4590"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-3104-4447", "path": "0000-0003-3104-4447"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0002-4415-3573", "path": "0000-0002-4415-3573"}}, {"orcid-identifier": {"host": "orcid.org", "uri": "http://orcid.org/0000-0003-0918-9041", "path": "0000-0003-0918-9041"}}]}

# %%
full_result_list
# Out:
# [{'creditName': 'ERROR',
#   'employment': [{'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'New Mexico',
#     'department_name': 'Mathematics and Statistics',
#     'end_date': {},
#     'organization': 'University of New Mexico',
#     'role_title': 'Assistant Professor',
#     'start_date': {'day': '01', 'month': '01', 'year': '2014'}}],
#   'familyName': 'Degnan',
#   'givenNames': 'James H.',
#   'orcidID': '0000-0001-7886-638X'},
#  {'creditName': 'ERROR',
#   'employment': [{'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'New Mexico',
#     'department_name': 'Clinical Education',
#     'end_date': {},
#     'organization': 'University of New Mexico Hospitals',
#     'role_title': 'Neuroscience Educator',
#     'start_date': {'day': '28', 'month': '09', 'year': '2015'}}],
#   'familyName': 'Melada',
#   'givenNames': 'Samuel',
#   'orcidID': '0000-0002-6740-4590'},
#  {'creditName': 'ERROR',
#   'employment': [{'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Psychology Clinical Neuroscience Center',
#     'end_date': {},
#     'organization': 'University of New Mexico',
#     'role_title': 'Research Assistant',
#     'start_date': {}},
#    {'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Archaeology',
#     'end_date': {},
#     'organization': 'University of New Mexico',
#     'role_title': 'Intern',
#     'start_date': {}}],
#   'familyName': 'Combs',
#   'givenNames': 'Angela',
#   'orcidID': '0000-0003-3104-4447'},
#  {'creditName': 'ERROR',
#   'employment': [{'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Internal Medicine',
#     'end_date': {},
#     'organization': 'University of New Mexico',
#     'role_title': 'Associate Professor',
#     'start_date': {'day': '01', 'month': '07', 'year': '2013'}},
#    {'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Internal Medicine',
#     'end_date': {'day': '31', 'month': '06', 'year': '2013'},
#     'organization': 'University of New Mexico',
#     'role_title': 'Assistant Professor',
#     'start_date': {'day': '01', 'month': '04', 'year': '2007'}},
#    {'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Internal Medicine',
#     'end_date': {'day': '31', 'month': '03', 'year': '2007'},
#     'organization': 'University of New Mexico',
#     'role_title': 'Research Assistant Professor',
#     'start_date': {'day': '01', 'month': '11', 'year': '2006'}},
#    {'address_city': 'Albuquerque',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Cancer Center',
#     'end_date': {'day': '31', 'month': '10', 'year': '2006'},
#     'organization': 'University of New Mexico',
#     'role_title': 'Senior Statistician',
#     'start_date': {'day': '23', 'month': '08', 'year': '2004'}}],
#   'familyName': 'Kang',
#   'givenNames': 'Huining',
#   'orcidID': '0000-0002-4415-3573'},
#  {'creditName': 'ERROR',
#   'employment': [{'address_city': 'Las Cruces',
#     'address_country': 'US',
#     'address_region': 'NM',
#     'department_name': 'Family and Consumer Science',
#     'end_date': {},
#     'organization': 'New Mexico State University',
#     'role_title': 'Associate Professor',
#     'start_date': {'day': '10', 'month': '08', 'year': '2012'}}],
#   'familyName': 'Marin',
#   'givenNames': 'Merranda',
#   'orcidID': '0000-0003-0918-9041'}]
